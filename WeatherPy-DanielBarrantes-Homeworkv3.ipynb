# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from requests.exceptions import HTTPError
import openweathermapy.core as owm
import time

# Import API key
from config2 import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

api_key
# Out:
# '9586ef608bbf0838f9b387e9d8d4b1da'

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities ok
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
cities
# Out:
# ['butaritari',
#  'itoman',
#  'praya',
#  'mehamn',
#  'tuktoyaktuk',
#  'umm durman',
#  'souillac',
#  'qaqortoq',
#  'oranjemund',
#  'castro',
#  'east london',
#  'black diamond',
#  'te anau',
#  'saint-philippe',
#  'khatanga',
#  'port alfred',
#  'chokurdakh',
#  'pacific grove',
#  'ushuaia',
#  'hobart',
#  'rikitea',
#  'tiksi',
#  'jamestown',
#  'port elizabeth',
#  'sajanan',
#  'sukhothai',
#  'nome',
#  'cayenne',
#  'vaini',
#  'hithadhoo',
#  'san jeronimo',
#  'kita',
#  'busselton',
#  'kapaa',
#  'yumen',
#  'twentynine palms',
#  'kaeng khlo',
#  'taolanaro',
#  'saskylakh',
#  'bluff',
#  'punta arenas',
#  'cherskiy',
#  'bac can',
#  'manggar',
#  'codrington',
#  'kidal',
#  'oytal',
#  'belaya gora',
#  'skalistyy',
#  'kieta',
#  'chumikan',
#  'chuy',
#  'puro',
#  'leh',
#  'cape town',
#  'sitka',
#  'puerto ayora',
#  'nuuk',
#  'sao joao da barra',
#  'aklavik',
#  'hermanus',
#  'santiago',
#  'anamur',
#  'ilulissat',
#  'umzimvubu',
#  'albany',
#  'venado tuerto',
#  'comodoro rivadavia',
#  'georgetown',
#  'avarua',
#  'provideniya',
#  'fortuna',
#  'cockburn town',
#  'acarau',
#  'hals',
#  'dolores',
#  'lolua',
#  'bathsheba',
#  'kalmunai',
#  'itarema',
#  'lompoc',
#  'geraldton',
#  'nagpur',
#  'port hardy',
#  'soyo',
#  'flinders',
#  'ogulin',
#  'mys shmidta',
#  'ribeira grande',
#  'portree',
#  'rungata',
#  'toliary',
#  'monrovia',
#  'sesheke',
#  'sindor',
#  'hilo',
#  'samarai',
#  'upernavik',
#  'muros',
#  'illoqqortoormiut',
#  'neuquen',
#  'qaanaaq',
#  'agogo',
#  'tucumcari',
#  'botwood',
#  'norman wells',
#  'mataura',
#  'yellowknife',
#  'luderitz',
#  'salalah',
#  'mogoytuy',
#  'hamilton',
#  'beboto',
#  'ulladulla',
#  'clyde river',
#  'erzin',
#  'mount isa',
#  'uinskoye',
#  'san cristobal',
#  'smithers',
#  'vostok',
#  'esmeraldas',
#  'almeirim',
#  'zhigansk',
#  'kurilsk',
#  'kuche',
#  'bredasdorp',
#  'mahebourg',
#  'kenai',
#  'roald',
#  'kiunga',
#  'kirakira',
#  'marcona',
#  'kodiak',
#  'bethel',
#  'hokitika',
#  'kajaani',
#  'lata',
#  'iqaluit',
#  'bilma',
#  'san andres',
#  'doctor pedro p. pena',
#  'leningradskiy',
#  'massaguet',
#  'santa eulalia del rio',
#  'tsihombe',
#  'klamath falls',
#  'waddan',
#  'tuatapere',
#  'nikolskoye',
#  'kibala',
#  'oksfjord',
#  'vila velha',
#  'rezekne',
#  'meyungs',
#  'vilhena',
#  'talara',
#  'redlands',
#  'kargala',
#  'rawannawi',
#  'saldanha',
#  'new norfolk',
#  'ostersund',
#  'kijang',
#  'suluq',
#  'kahului',
#  'chifeng',
#  'samusu',
#  'biak',
#  'cedar city',
#  'asau',
#  'severo-kurilsk',
#  'rangapara',
#  'nizhneyansk',
#  'bajna',
#  'khandyga',
#  'jalu',
#  'beihai',
#  'college',
#  'ahar',
#  'sentyabrskiy',
#  'abu samrah',
#  'bambanglipuro',
#  'shubarkuduk',
#  'tautira',
#  'bengkulu',
#  'nadym',
#  'nyrob',
#  'husavik',
#  'tasiilaq',
#  'sidi ali',
#  'isangel',
#  'cabo san lucas',
#  'le port',
#  'riyadh',
#  'atambua',
#  'namibe',
#  'miles city',
#  'lebu',
#  'rach gia',
#  'hofn',
#  'lar gerd',
#  'airai',
#  'olutanga',
#  'hovd',
#  'grand gaube',
#  'bull savanna',
#  'kununurra',
#  'valdivia',
#  'bambous virieux',
#  'wschowa',
#  'minden',
#  'omboue',
#  'goderich',
#  'thompson',
#  'scarborough',
#  'koslan',
#  'mahadday weyne',
#  'dikson',
#  'grindavik',
#  'ponta do sol',
#  'san patricio',
#  'kruisfontein',
#  'olinda',
#  'port hedland',
#  'charleston',
#  'bilibino',
#  'ahumada',
#  'kabinda',
#  'banamba',
#  'belushya guba',
#  'aswan',
#  'bubaque',
#  'puerto maldonado',
#  'talnakh',
#  'salina',
#  'jyvaskyla',
#  'naryan-mar',
#  'robertsport',
#  'dingle',
#  'kadaya',
#  'vysokogornyy',
#  'batagay',
#  'flin flon',
#  'mitsamiouli',
#  'severo-yeniseyskiy',
#  'kingston',
#  'halalo',
#  'ulundi',
#  'mersing',
#  'yarmouth',
#  'mar del plata',
#  'kachug',
#  'tootsi',
#  'vao',
#  'bulgan',
#  'barrow',
#  'harper',
#  'almaznyy',
#  'marawi',
#  'balabac',
#  'poya',
#  'kamenskoye',
#  'carnarvon',
#  'anadyr',
#  'gannan',
#  'zlatoustovsk',
#  'zhitikara',
#  'saleaula',
#  'diamantino',
#  'inderborskiy',
#  'port macquarie',
#  'samalaeulu',
#  'milkovo',
#  'saint george',
#  'ahipara',
#  'paso de carrasco',
#  'laguna',
#  'markivka',
#  'ketchikan',
#  'victoria',
#  'camacha',
#  'mount gambier',
#  'atuona',
#  'barstow',
#  'paamiut',
#  'aflu',
#  'bolungarvik',
#  'riverton',
#  'vercelli',
#  'kresttsy',
#  'malpur',
#  'gigant',
#  'izumo',
#  'arraial do cabo',
#  'poum',
#  'sokolo',
#  'constitucion',
#  'maceio',
#  'shaunavon',
#  'guliston',
#  'masunga',
#  'pevek',
#  'amderma',
#  'rampura',
#  'antofagasta',
#  'awjilah',
#  'nemuro',
#  'sobolevo',
#  'komsomolskiy',
#  'qui nhon',
#  'dodoma',
#  'tabas',
#  'yambio',
#  'nara',
#  'san carlos de bariloche',
#  'attawapiskat',
#  'qasigiannguit',
#  'yanan',
#  'preobrazheniye',
#  'ancud',
#  'vaitupu',
#  'strezhevoy',
#  'daxian',
#  'pangnirtung',
#  'grand river south east',
#  'zaysan',
#  'auki',
#  'tumannyy',
#  'sola',
#  'tura',
#  'chagda',
#  'kobryn',
#  'orbetello',
#  'saint anthony',
#  'phalodi',
#  'rocha',
#  'forestville',
#  'sao filipe',
#  'aktau',
#  'port-gentil',
#  'kokopo',
#  'san luis',
#  'bandarbeyla',
#  'kampong thum',
#  'goure',
#  'faya',
#  'torbay',
#  'cabedelo',
#  'moree',
#  'imeni babushkina',
#  'uvalde',
#  'benguela',
#  'tubruq',
#  'mezen',
#  'broken hill',
#  'dayong',
#  'pimentel',
#  'broome',
#  'vila franca do campo',
#  'chapais',
#  'tabatinga',
#  'kavieng',
#  'saint-joseph',
#  'esperance',
#  'lakeside',
#  'baykit',
#  'lufilufi',
#  'fethiye',
#  'abu dhabi',
#  'lorengau',
#  'namatanai',
#  'balad',
#  'marsh harbour',
#  'alexandria',
#  'bratsk',
#  'fort nelson',
#  'sheridan',
#  'vaitape',
#  'hualmay',
#  'esik',
#  'sinkat',
#  'kapchorwa',
#  'ixtapa',
#  'corinto',
#  'mandalgovi',
#  'lodja',
#  'abilene',
#  'marzuq',
#  'meulaboh',
#  'topolobampo',
#  'caravelas',
#  'koroni',
#  'hohhot',
#  'hearst',
#  'egvekinot',
#  'kovdor',
#  'mabaruma',
#  'chara',
#  'zhezkazgan',
#  'the valley',
#  'inta',
#  'aquiraz',
#  'calama',
#  'tomatlan',
#  'avera',
#  'mende',
#  'zaykovo',
#  'port lincoln',
#  'kashary',
#  'port moresby',
#  'amapa',
#  'ostrovnoy',
#  'cidreira',
#  'sterling',
#  'ransang',
#  'keshorai patan',
#  'coquimbo',
#  'vwawa',
#  'umm qays',
#  'troitsko-pechorsk',
#  'vidim',
#  'dunedin',
#  'conde',
#  'katsuura',
#  'iquique',
#  'maniitsoq',
#  'remanso',
#  'chokwe',
#  'galveston',
#  'ko samui',
#  'tombouctou',
#  'klaksvik',
#  'haines junction',
#  'lagoa',
#  'svetlogorsk',
#  'iwaki',
#  'kiama',
#  'atessa',
#  'kremsmunster',
#  'wladyslawowo',
#  'kaitangata',
#  'raudeberg',
#  'khonuu',
#  'barra do garcas',
#  'tostamaa',
#  'ivanava',
#  'bonavista',
#  'makakilo city',
#  'henties bay',
#  'taburi',
#  'darab',
#  'bereda',
#  'curillo',
#  'asfi',
#  'ust-nera',
#  'ugoofaaru',
#  'orgun',
#  'chuguyevka',
#  'metro',
#  'san vicente',
#  'faanui',
#  'trincomalee',
#  'meridian',
#  'alofi',
#  'bayan',
#  'verkhoyansk',
#  'narsaq',
#  'necochea',
#  'kintinku',
#  'sorland',
#  'mogadishu',
#  'koungou',
#  'lashio',
#  'tingo maria',
#  'thap than',
#  'kismayo',
#  'murgab',
#  'yar-sale',
#  'lavrentiya',
#  'pisco',
#  'pingzhuang',
#  'dongsheng',
#  'deputatskiy',
#  'troutdale',
#  'takoradi',
#  'sanming',
#  'yate',
#  'russell',
#  'kultuk',
#  'kulunda',
#  'barentsburg',
#  'palembang',
#  'pueblo nuevo',
#  'bud',
#  'tilichiki',
#  'mehran',
#  'abu kamal',
#  'breves',
#  'naples',
#  'solnechnyy',
#  'halmstad',
#  'hasaki',
#  'juba',
#  'lewisville',
#  'daokou',
#  'sambava',
#  'enshi',
#  'silyanah',
#  'hervey bay',
#  'palmer',
#  'marsa matruh',
#  'tebingtinggi',
#  'papetoai',
#  'ballina',
#  'stranda',
#  'katangli',
#  'hambantota',
#  'valparaiso',
#  'ahuimanu',
#  'ghatsila',
#  'nanortalik',
#  'sassandra',
#  'disna',
#  'berlevag',
#  'itigi',
#  'serebryansk',
#  'kavarskas',
#  'loubomo',
#  'cafarnaum',
#  'yabrud',
#  'tiarei',
#  'high prairie',
#  'sangin',
#  'toamasina',
#  'kralendijk',
#  'muravlenko',
#  'skibbereen',
#  'quibdo',
#  'northam',
#  'thinadhoo',
#  'andijon',
#  'vestmannaeyjar',
#  'innisfail',
#  'clovis',
#  'taoudenni',
#  'catuday',
#  'aquin',
#  'cabras',
#  'senneterre',
#  'ampanihy',
#  'afyonkarahisar',
#  'saint-pierre',
#  'ascension',
#  'tahe',
#  'joensuu',
#  'yanam',
#  'warmbad',
#  'tateyama',
#  'aybak',
#  'lezajsk',
#  'luba',
#  'trairi',
#  'kampil',
#  'neiafu',
#  'san luis de gaceno',
#  'vardo',
#  'adrar',
#  'karkaralinsk',
#  'nhulunbuy',
#  'hammerfest',
#  'portland',
#  'acajutla',
#  'wahran',
#  'marsaxlokk',
#  'papara',
#  'agaro',
#  'shadrinsk',
#  'sur',
#  'mareeba',
#  'springdale',
#  'peleduy',
#  'black river',
#  'morgan city',
#  'malpe',
#  'puerto escondido',
#  'severnyy-kospashskiy',
#  'nancha',
#  'chalmette',
#  'puerto carreno',
#  'abha',
#  'abdulino',
#  'astoria',
#  'bosaso',
#  'pauini',
#  'tual',
#  'wawa',
#  'vila do maio',
#  'skelleftea',
#  'sungaipenuh',
#  'antalaha',
#  'kuldur',
#  'katherine',
#  'yulara',
#  'roma',
#  'zambezi',
#  'noumea',
#  'fort-shevchenko',
#  'westport',
#  'richards bay',
#  'libourne',
#  'zabaykalsk',
#  'griffith',
#  'orsha',
#  'asosa',
#  'bay saint louis',
#  'hennigsdorf',
#  'beringovskiy',
#  'clearwater',
#  'jumla',
#  'urla',
#  'catalina']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information. OK
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# %%
# Build partial query URL OK
query_url = f"{url}appid={api_key}&units={units}&q="
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q='

# %%
settings = {"units": "metric", "appid": api_key}
total_cities = len(cities)
weather_py = []
lat=[]
lon=[]
temp=[]
cit=[]
temp_max=[]
humidity=[]
wind=[]
date=[]
cloudiness=[]
country=[]
count=1

print('Processing Data Retrieval')
print('-----------------------------')


for city in cities:
   print(f"processing Record {count} of Set {total_cities} | " + city )
   try:
       weather_data = [owm.get_current(city, **settings)]
       lat.append(weather_py[0]["coord"]["lat"])
       lon.append(weather_py[0]["coord"]["lon"])
       temp.append(weather_py[0]["main"]["temp"])
       cit.append(weather_py[0]["name"])
       humidity.append(weather_py[0]["main"]["humidity"])
       temp_max.append(weather_py[0]["main"]["temp_max"])
       country.append(weather_py[0]["sys"]["country"])
       cloudiness.append(weather_py[0]["clouds"]["all"])
       date.append(weather_py[0]["dt"])
       wind.append(weather_py[0]["wind"]["speed"])
       print(query_url + city)   
       count=count + 1
   except Exception as e:
               print(f"no data available for city {city},because of {e}")
               #del cities[count-1]
   #except HTTPError as http_err:
    #           print(f'HTTP error occurred: {http_err}')  # Python 3.6
  # except Exception as err:
   #            print(f'Other error occurred: {err}')  # Python 3.6
  #             print(query_url)
# Out:
# Processing Data Retrieval
# -----------------------------
# processing Record 1 of Set 622 | butaritari
# no data available for city butaritari,because of list index out of range
# processing Record 1 of Set 622 | itoman
# no data available for city itoman,because of list index out of range
# processing Record 1 of Set 622 | praya
# no data available for city praya,because of list index out of range
# processing Record 1 of Set 622 | mehamn
# no data available for city mehamn,because of list index out of range
# processing Record 1 of Set 622 | tuktoyaktuk
# no data available for city tuktoyaktuk,because of list index out of range
# processing Record 1 of Set 622 | umm durman
# no data available for city umm durman,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | souillac
# no data available for city souillac,because of list index out of range
# processing Record 1 of Set 622 | qaqortoq
# no data available for city qaqortoq,because of list index out of range
# processing Record 1 of Set 622 | oranjemund
# no data available for city oranjemund,because of list index out of range
# processing Record 1 of Set 622 | castro
# no data available for city castro,because of list index out of range
# processing Record 1 of Set 622 | east london
# no data available for city east london,because of list index out of range
# processing Record 1 of Set 622 | black diamond
# no data available for city black diamond,because of list index out of range
# processing Record 1 of Set 622 | te anau
# no data available for city te anau,because of list index out of range
# processing Record 1 of Set 622 | saint-philippe
# no data available for city saint-philippe,because of list index out of range
# processing Record 1 of Set 622 | khatanga
# no data available for city khatanga,because of list index out of range
# processing Record 1 of Set 622 | port alfred
# no data available for city port alfred,because of list index out of range
# processing Record 1 of Set 622 | chokurdakh
# no data available for city chokurdakh,because of list index out of range
# processing Record 1 of Set 622 | pacific grove
# no data available for city pacific grove,because of list index out of range
# processing Record 1 of Set 622 | ushuaia
# no data available for city ushuaia,because of list index out of range
# processing Record 1 of Set 622 | hobart
# no data available for city hobart,because of list index out of range
# processing Record 1 of Set 622 | rikitea
# no data available for city rikitea,because of list index out of range
# processing Record 1 of Set 622 | tiksi
# no data available for city tiksi,because of list index out of range
# processing Record 1 of Set 622 | jamestown
# no data available for city jamestown,because of list index out of range
# processing Record 1 of Set 622 | port elizabeth
# no data available for city port elizabeth,because of list index out of range
# processing Record 1 of Set 622 | sajanan
# no data available for city sajanan,because of list index out of range
# processing Record 1 of Set 622 | sukhothai
# no data available for city sukhothai,because of list index out of range
# processing Record 1 of Set 622 | nome
# no data available for city nome,because of list index out of range
# processing Record 1 of Set 622 | cayenne
# no data available for city cayenne,because of list index out of range
# processing Record 1 of Set 622 | vaini
# no data available for city vaini,because of list index out of range
# processing Record 1 of Set 622 | hithadhoo
# no data available for city hithadhoo,because of list index out of range
# processing Record 1 of Set 622 | san jeronimo
# no data available for city san jeronimo,because of list index out of range
# processing Record 1 of Set 622 | kita
# no data available for city kita,because of list index out of range
# processing Record 1 of Set 622 | busselton
# no data available for city busselton,because of list index out of range
# processing Record 1 of Set 622 | kapaa
# no data available for city kapaa,because of list index out of range
# processing Record 1 of Set 622 | yumen
# no data available for city yumen,because of list index out of range
# processing Record 1 of Set 622 | twentynine palms
# no data available for city twentynine palms,because of list index out of range
# processing Record 1 of Set 622 | kaeng khlo
# no data available for city kaeng khlo,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | taolanaro
# no data available for city taolanaro,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | saskylakh
# no data available for city saskylakh,because of list index out of range
# processing Record 1 of Set 622 | bluff
# no data available for city bluff,because of list index out of range
# processing Record 1 of Set 622 | punta arenas
# no data available for city punta arenas,because of list index out of range
# processing Record 1 of Set 622 | cherskiy
# no data available for city cherskiy,because of list index out of range
# processing Record 1 of Set 622 | bac can
# no data available for city bac can,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | manggar
# no data available for city manggar,because of list index out of range
# processing Record 1 of Set 622 | codrington
# no data available for city codrington,because of list index out of range
# processing Record 1 of Set 622 | kidal
# no data available for city kidal,because of list index out of range
# processing Record 1 of Set 622 | oytal
# no data available for city oytal,because of list index out of range
# processing Record 1 of Set 622 | belaya gora
# no data available for city belaya gora,because of list index out of range
# processing Record 1 of Set 622 | skalistyy
# no data available for city skalistyy,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | kieta
# no data available for city kieta,because of list index out of range
# processing Record 1 of Set 622 | chumikan
# no data available for city chumikan,because of list index out of range
# processing Record 1 of Set 622 | chuy
# no data available for city chuy,because of list index out of range
# processing Record 1 of Set 622 | puro
# no data available for city puro,because of list index out of range
# processing Record 1 of Set 622 | leh
# no data available for city leh,because of list index out of range
# processing Record 1 of Set 622 | cape town
# no data available for city cape town,because of list index out of range
# processing Record 1 of Set 622 | sitka
# no data available for city sitka,because of list index out of range
# processing Record 1 of Set 622 | puerto ayora
# no data available for city puerto ayora,because of list index out of range
# processing Record 1 of Set 622 | nuuk
# no data available for city nuuk,because of list index out of range
# processing Record 1 of Set 622 | sao joao da barra
# no data available for city sao joao da barra,because of list index out of range
# processing Record 1 of Set 622 | aklavik
# no data available for city aklavik,because of list index out of range
# processing Record 1 of Set 622 | hermanus
# no data available for city hermanus,because of list index out of range
# processing Record 1 of Set 622 | santiago
# no data available for city santiago,because of list index out of range
# processing Record 1 of Set 622 | anamur
# no data available for city anamur,because of list index out of range
# processing Record 1 of Set 622 | ilulissat
# no data available for city ilulissat,because of list index out of range
# processing Record 1 of Set 622 | umzimvubu
# no data available for city umzimvubu,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | albany
# no data available for city albany,because of list index out of range
# processing Record 1 of Set 622 | venado tuerto
# no data available for city venado tuerto,because of list index out of range
# processing Record 1 of Set 622 | comodoro rivadavia
# no data available for city comodoro rivadavia,because of list index out of range
# processing Record 1 of Set 622 | georgetown
# no data available for city georgetown,because of list index out of range
# processing Record 1 of Set 622 | avarua
# no data available for city avarua,because of list index out of range
# processing Record 1 of Set 622 | provideniya
# no data available for city provideniya,because of list index out of range
# processing Record 1 of Set 622 | fortuna
# no data available for city fortuna,because of list index out of range
# processing Record 1 of Set 622 | cockburn town
# no data available for city cockburn town,because of list index out of range
# processing Record 1 of Set 622 | acarau
# no data available for city acarau,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | hals
# no data available for city hals,because of list index out of range
# processing Record 1 of Set 622 | dolores
# no data available for city dolores,because of list index out of range
# processing Record 1 of Set 622 | lolua
# no data available for city lolua,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | bathsheba
# no data available for city bathsheba,because of list index out of range
# processing Record 1 of Set 622 | kalmunai
# no data available for city kalmunai,because of list index out of range
# processing Record 1 of Set 622 | itarema
# no data available for city itarema,because of list index out of range
# processing Record 1 of Set 622 | lompoc
# no data available for city lompoc,because of list index out of range
# processing Record 1 of Set 622 | geraldton
# no data available for city geraldton,because of list index out of range
# processing Record 1 of Set 622 | nagpur
# no data available for city nagpur,because of list index out of range
# processing Record 1 of Set 622 | port hardy
# no data available for city port hardy,because of list index out of range
# processing Record 1 of Set 622 | soyo
# no data available for city soyo,because of list index out of range
# processing Record 1 of Set 622 | flinders
# no data available for city flinders,because of list index out of range
# processing Record 1 of Set 622 | ogulin
# no data available for city ogulin,because of list index out of range
# processing Record 1 of Set 622 | mys shmidta
# no data available for city mys shmidta,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | ribeira grande
# no data available for city ribeira grande,because of list index out of range
# processing Record 1 of Set 622 | portree
# no data available for city portree,because of list index out of range
# processing Record 1 of Set 622 | rungata
# no data available for city rungata,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | toliary
# no data available for city toliary,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | monrovia
# no data available for city monrovia,because of list index out of range
# processing Record 1 of Set 622 | sesheke
# no data available for city sesheke,because of list index out of range
# processing Record 1 of Set 622 | sindor
# no data available for city sindor,because of list index out of range
# processing Record 1 of Set 622 | hilo
# no data available for city hilo,because of list index out of range
# processing Record 1 of Set 622 | samarai
# no data available for city samarai,because of list index out of range
# processing Record 1 of Set 622 | upernavik
# no data available for city upernavik,because of list index out of range
# processing Record 1 of Set 622 | muros
# no data available for city muros,because of list index out of range
# processing Record 1 of Set 622 | illoqqortoormiut
# no data available for city illoqqortoormiut,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | neuquen
# no data available for city neuquen,because of list index out of range
# processing Record 1 of Set 622 | qaanaaq
# no data available for city qaanaaq,because of list index out of range
# processing Record 1 of Set 622 | agogo
# no data available for city agogo,because of list index out of range
# processing Record 1 of Set 622 | tucumcari
# no data available for city tucumcari,because of list index out of range
# processing Record 1 of Set 622 | botwood
# no data available for city botwood,because of list index out of range
# processing Record 1 of Set 622 | norman wells
# no data available for city norman wells,because of list index out of range
# processing Record 1 of Set 622 | mataura
# no data available for city mataura,because of list index out of range
# processing Record 1 of Set 622 | yellowknife
# no data available for city yellowknife,because of list index out of range
# processing Record 1 of Set 622 | luderitz
# no data available for city luderitz,because of list index out of range
# processing Record 1 of Set 622 | salalah
# no data available for city salalah,because of list index out of range
# processing Record 1 of Set 622 | mogoytuy
# no data available for city mogoytuy,because of list index out of range
# processing Record 1 of Set 622 | hamilton
# no data available for city hamilton,because of list index out of range
# processing Record 1 of Set 622 | beboto
# no data available for city beboto,because of list index out of range
# processing Record 1 of Set 622 | ulladulla
# no data available for city ulladulla,because of list index out of range
# processing Record 1 of Set 622 | clyde river
# no data available for city clyde river,because of list index out of range
# processing Record 1 of Set 622 | erzin
# no data available for city erzin,because of list index out of range
# processing Record 1 of Set 622 | mount isa
# no data available for city mount isa,because of list index out of range
# processing Record 1 of Set 622 | uinskoye
# no data available for city uinskoye,because of list index out of range
# processing Record 1 of Set 622 | san cristobal
# no data available for city san cristobal,because of list index out of range
# processing Record 1 of Set 622 | smithers
# no data available for city smithers,because of list index out of range
# processing Record 1 of Set 622 | vostok
# no data available for city vostok,because of list index out of range
# processing Record 1 of Set 622 | esmeraldas
# no data available for city esmeraldas,because of list index out of range
# processing Record 1 of Set 622 | almeirim
# no data available for city almeirim,because of list index out of range
# processing Record 1 of Set 622 | zhigansk
# no data available for city zhigansk,because of list index out of range
# processing Record 1 of Set 622 | kurilsk
# no data available for city kurilsk,because of list index out of range
# processing Record 1 of Set 622 | kuche
# no data available for city kuche,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | bredasdorp
# no data available for city bredasdorp,because of list index out of range
# processing Record 1 of Set 622 | mahebourg
# no data available for city mahebourg,because of list index out of range
# processing Record 1 of Set 622 | kenai
# no data available for city kenai,because of list index out of range
# processing Record 1 of Set 622 | roald
# no data available for city roald,because of list index out of range
# processing Record 1 of Set 622 | kiunga
# no data available for city kiunga,because of list index out of range
# processing Record 1 of Set 622 | kirakira
# no data available for city kirakira,because of list index out of range
# processing Record 1 of Set 622 | marcona
# no data available for city marcona,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | kodiak
# no data available for city kodiak,because of list index out of range
# processing Record 1 of Set 622 | bethel
# no data available for city bethel,because of list index out of range
# processing Record 1 of Set 622 | hokitika
# no data available for city hokitika,because of list index out of range
# processing Record 1 of Set 622 | kajaani
# no data available for city kajaani,because of list index out of range
# processing Record 1 of Set 622 | lata
# no data available for city lata,because of list index out of range
# processing Record 1 of Set 622 | iqaluit
# no data available for city iqaluit,because of list index out of range
# processing Record 1 of Set 622 | bilma
# no data available for city bilma,because of list index out of range
# processing Record 1 of Set 622 | san andres
# no data available for city san andres,because of list index out of range
# processing Record 1 of Set 622 | doctor pedro p. pena
# no data available for city doctor pedro p. pena,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | leningradskiy
# no data available for city leningradskiy,because of list index out of range
# processing Record 1 of Set 622 | massaguet
# no data available for city massaguet,because of list index out of range
# processing Record 1 of Set 622 | santa eulalia del rio
# no data available for city santa eulalia del rio,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | tsihombe
# no data available for city tsihombe,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | klamath falls
# no data available for city klamath falls,because of list index out of range
# processing Record 1 of Set 622 | waddan
# no data available for city waddan,because of list index out of range
# processing Record 1 of Set 622 | tuatapere
# no data available for city tuatapere,because of list index out of range
# processing Record 1 of Set 622 | nikolskoye
# no data available for city nikolskoye,because of list index out of range
# processing Record 1 of Set 622 | kibala
# no data available for city kibala,because of list index out of range
# processing Record 1 of Set 622 | oksfjord
# no data available for city oksfjord,because of list index out of range
# processing Record 1 of Set 622 | vila velha
# no data available for city vila velha,because of list index out of range
# processing Record 1 of Set 622 | rezekne
# no data available for city rezekne,because of list index out of range
# processing Record 1 of Set 622 | meyungs
# no data available for city meyungs,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | vilhena
# no data available for city vilhena,because of list index out of range
# processing Record 1 of Set 622 | talara
# no data available for city talara,because of list index out of range
# processing Record 1 of Set 622 | redlands
# no data available for city redlands,because of list index out of range
# processing Record 1 of Set 622 | kargala
# no data available for city kargala,because of list index out of range
# processing Record 1 of Set 622 | rawannawi
# no data available for city rawannawi,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | saldanha
# no data available for city saldanha,because of list index out of range
# processing Record 1 of Set 622 | new norfolk
# no data available for city new norfolk,because of list index out of range
# processing Record 1 of Set 622 | ostersund
# no data available for city ostersund,because of list index out of range
# processing Record 1 of Set 622 | kijang
# no data available for city kijang,because of list index out of range
# processing Record 1 of Set 622 | suluq
# no data available for city suluq,because of list index out of range
# processing Record 1 of Set 622 | kahului
# no data available for city kahului,because of list index out of range
# processing Record 1 of Set 622 | chifeng
# no data available for city chifeng,because of list index out of range
# processing Record 1 of Set 622 | samusu
# no data available for city samusu,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | biak
# no data available for city biak,because of list index out of range
# processing Record 1 of Set 622 | cedar city
# no data available for city cedar city,because of list index out of range
# processing Record 1 of Set 622 | asau
# no data available for city asau,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | severo-kurilsk
# no data available for city severo-kurilsk,because of list index out of range
# processing Record 1 of Set 622 | rangapara
# no data available for city rangapara,because of list index out of range
# processing Record 1 of Set 622 | nizhneyansk
# no data available for city nizhneyansk,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | bajna
# no data available for city bajna,because of list index out of range
# processing Record 1 of Set 622 | khandyga
# no data available for city khandyga,because of list index out of range
# processing Record 1 of Set 622 | jalu
# no data available for city jalu,because of list index out of range
# processing Record 1 of Set 622 | beihai
# no data available for city beihai,because of list index out of range
# processing Record 1 of Set 622 | college
# no data available for city college,because of list index out of range
# processing Record 1 of Set 622 | ahar
# no data available for city ahar,because of list index out of range
# processing Record 1 of Set 622 | sentyabrskiy
# no data available for city sentyabrskiy,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | abu samrah
# no data available for city abu samrah,because of list index out of range
# processing Record 1 of Set 622 | bambanglipuro
# no data available for city bambanglipuro,because of list index out of range
# processing Record 1 of Set 622 | shubarkuduk
# no data available for city shubarkuduk,because of list index out of range
# processing Record 1 of Set 622 | tautira
# no data available for city tautira,because of list index out of range
# processing Record 1 of Set 622 | bengkulu
# no data available for city bengkulu,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | nadym
# no data available for city nadym,because of list index out of range
# processing Record 1 of Set 622 | nyrob
# no data available for city nyrob,because of list index out of range
# processing Record 1 of Set 622 | husavik
# no data available for city husavik,because of list index out of range
# processing Record 1 of Set 622 | tasiilaq
# no data available for city tasiilaq,because of list index out of range
# processing Record 1 of Set 622 | sidi ali
# no data available for city sidi ali,because of list index out of range
# processing Record 1 of Set 622 | isangel
# no data available for city isangel,because of list index out of range
# processing Record 1 of Set 622 | cabo san lucas
# no data available for city cabo san lucas,because of list index out of range
# processing Record 1 of Set 622 | le port
# no data available for city le port,because of list index out of range
# processing Record 1 of Set 622 | riyadh
# no data available for city riyadh,because of list index out of range
# processing Record 1 of Set 622 | atambua
# no data available for city atambua,because of list index out of range
# processing Record 1 of Set 622 | namibe
# no data available for city namibe,because of list index out of range
# processing Record 1 of Set 622 | miles city
# no data available for city miles city,because of list index out of range
# processing Record 1 of Set 622 | lebu
# no data available for city lebu,because of list index out of range
# processing Record 1 of Set 622 | rach gia
# no data available for city rach gia,because of list index out of range
# processing Record 1 of Set 622 | hofn
# no data available for city hofn,because of list index out of range
# processing Record 1 of Set 622 | lar gerd
# no data available for city lar gerd,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | airai
# no data available for city airai,because of list index out of range
# processing Record 1 of Set 622 | olutanga
# no data available for city olutanga,because of list index out of range
# processing Record 1 of Set 622 | hovd
# no data available for city hovd,because of list index out of range
# processing Record 1 of Set 622 | grand gaube
# no data available for city grand gaube,because of list index out of range
# processing Record 1 of Set 622 | bull savanna
# no data available for city bull savanna,because of list index out of range
# processing Record 1 of Set 622 | kununurra
# no data available for city kununurra,because of list index out of range
# processing Record 1 of Set 622 | valdivia
# no data available for city valdivia,because of list index out of range
# processing Record 1 of Set 622 | bambous virieux
# no data available for city bambous virieux,because of list index out of range
# processing Record 1 of Set 622 | wschowa
# no data available for city wschowa,because of list index out of range
# processing Record 1 of Set 622 | minden
# no data available for city minden,because of list index out of range
# processing Record 1 of Set 622 | omboue
# no data available for city omboue,because of list index out of range
# processing Record 1 of Set 622 | goderich
# no data available for city goderich,because of list index out of range
# processing Record 1 of Set 622 | thompson
# no data available for city thompson,because of list index out of range
# processing Record 1 of Set 622 | scarborough
# no data available for city scarborough,because of list index out of range
# processing Record 1 of Set 622 | koslan
# no data available for city koslan,because of list index out of range
# processing Record 1 of Set 622 | mahadday weyne
# no data available for city mahadday weyne,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | dikson
# no data available for city dikson,because of list index out of range
# processing Record 1 of Set 622 | grindavik
# no data available for city grindavik,because of list index out of range
# processing Record 1 of Set 622 | ponta do sol
# no data available for city ponta do sol,because of list index out of range
# processing Record 1 of Set 622 | san patricio
# no data available for city san patricio,because of list index out of range
# processing Record 1 of Set 622 | kruisfontein
# no data available for city kruisfontein,because of list index out of range
# processing Record 1 of Set 622 | olinda
# no data available for city olinda,because of list index out of range
# processing Record 1 of Set 622 | port hedland
# no data available for city port hedland,because of list index out of range
# processing Record 1 of Set 622 | charleston
# no data available for city charleston,because of list index out of range
# processing Record 1 of Set 622 | bilibino
# no data available for city bilibino,because of list index out of range
# processing Record 1 of Set 622 | ahumada
# no data available for city ahumada,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | kabinda
# no data available for city kabinda,because of list index out of range
# processing Record 1 of Set 622 | banamba
# no data available for city banamba,because of list index out of range
# processing Record 1 of Set 622 | belushya guba
# no data available for city belushya guba,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | aswan
# no data available for city aswan,because of list index out of range
# processing Record 1 of Set 622 | bubaque
# no data available for city bubaque,because of list index out of range
# processing Record 1 of Set 622 | puerto maldonado
# no data available for city puerto maldonado,because of list index out of range
# processing Record 1 of Set 622 | talnakh
# no data available for city talnakh,because of list index out of range
# processing Record 1 of Set 622 | salina
# no data available for city salina,because of list index out of range
# processing Record 1 of Set 622 | jyvaskyla
# no data available for city jyvaskyla,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | naryan-mar
# no data available for city naryan-mar,because of list index out of range
# processing Record 1 of Set 622 | robertsport
# no data available for city robertsport,because of list index out of range
# processing Record 1 of Set 622 | dingle
# no data available for city dingle,because of list index out of range
# processing Record 1 of Set 622 | kadaya
# no data available for city kadaya,because of list index out of range
# processing Record 1 of Set 622 | vysokogornyy
# no data available for city vysokogornyy,because of list index out of range
# processing Record 1 of Set 622 | batagay
# no data available for city batagay,because of list index out of range
# processing Record 1 of Set 622 | flin flon
# no data available for city flin flon,because of list index out of range
# processing Record 1 of Set 622 | mitsamiouli
# no data available for city mitsamiouli,because of list index out of range
# processing Record 1 of Set 622 | severo-yeniseyskiy
# no data available for city severo-yeniseyskiy,because of list index out of range
# processing Record 1 of Set 622 | kingston
# no data available for city kingston,because of list index out of range
# processing Record 1 of Set 622 | halalo
# no data available for city halalo,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | ulundi
# no data available for city ulundi,because of list index out of range
# processing Record 1 of Set 622 | mersing
# no data available for city mersing,because of list index out of range
# processing Record 1 of Set 622 | yarmouth
# no data available for city yarmouth,because of list index out of range
# processing Record 1 of Set 622 | mar del plata
# no data available for city mar del plata,because of list index out of range
# processing Record 1 of Set 622 | kachug
# no data available for city kachug,because of list index out of range
# processing Record 1 of Set 622 | tootsi
# no data available for city tootsi,because of list index out of range
# processing Record 1 of Set 622 | vao
# no data available for city vao,because of list index out of range
# processing Record 1 of Set 622 | bulgan
# no data available for city bulgan,because of list index out of range
# processing Record 1 of Set 622 | barrow
# no data available for city barrow,because of list index out of range
# processing Record 1 of Set 622 | harper
# no data available for city harper,because of list index out of range
# processing Record 1 of Set 622 | almaznyy
# no data available for city almaznyy,because of list index out of range
# processing Record 1 of Set 622 | marawi
# no data available for city marawi,because of list index out of range
# processing Record 1 of Set 622 | balabac
# no data available for city balabac,because of list index out of range
# processing Record 1 of Set 622 | poya
# no data available for city poya,because of list index out of range
# processing Record 1 of Set 622 | kamenskoye
# no data available for city kamenskoye,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | carnarvon
# no data available for city carnarvon,because of list index out of range
# processing Record 1 of Set 622 | anadyr
# no data available for city anadyr,because of list index out of range
# processing Record 1 of Set 622 | gannan
# no data available for city gannan,because of list index out of range
# processing Record 1 of Set 622 | zlatoustovsk
# no data available for city zlatoustovsk,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | zhitikara
# no data available for city zhitikara,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | saleaula
# no data available for city saleaula,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | diamantino
# no data available for city diamantino,because of list index out of range
# processing Record 1 of Set 622 | inderborskiy
# no data available for city inderborskiy,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | port macquarie
# no data available for city port macquarie,because of list index out of range
# processing Record 1 of Set 622 | samalaeulu
# no data available for city samalaeulu,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | milkovo
# no data available for city milkovo,because of list index out of range
# processing Record 1 of Set 622 | saint george
# no data available for city saint george,because of list index out of range
# processing Record 1 of Set 622 | ahipara
# no data available for city ahipara,because of list index out of range
# processing Record 1 of Set 622 | paso de carrasco
# no data available for city paso de carrasco,because of list index out of range
# processing Record 1 of Set 622 | laguna
# no data available for city laguna,because of list index out of range
# processing Record 1 of Set 622 | markivka
# no data available for city markivka,because of list index out of range
# processing Record 1 of Set 622 | ketchikan
# no data available for city ketchikan,because of list index out of range
# processing Record 1 of Set 622 | victoria
# no data available for city victoria,because of list index out of range
# processing Record 1 of Set 622 | camacha
# no data available for city camacha,because of list index out of range
# processing Record 1 of Set 622 | mount gambier
# no data available for city mount gambier,because of list index out of range
# processing Record 1 of Set 622 | atuona
# no data available for city atuona,because of list index out of range
# processing Record 1 of Set 622 | barstow
# no data available for city barstow,because of list index out of range
# processing Record 1 of Set 622 | paamiut
# no data available for city paamiut,because of list index out of range
# processing Record 1 of Set 622 | aflu
# no data available for city aflu,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | bolungarvik
# no data available for city bolungarvik,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | riverton
# no data available for city riverton,because of list index out of range
# processing Record 1 of Set 622 | vercelli
# no data available for city vercelli,because of list index out of range
# processing Record 1 of Set 622 | kresttsy
# no data available for city kresttsy,because of list index out of range
# processing Record 1 of Set 622 | malpur
# no data available for city malpur,because of list index out of range
# processing Record 1 of Set 622 | gigant
# no data available for city gigant,because of list index out of range
# processing Record 1 of Set 622 | izumo
# no data available for city izumo,because of list index out of range
# processing Record 1 of Set 622 | arraial do cabo
# no data available for city arraial do cabo,because of list index out of range
# processing Record 1 of Set 622 | poum
# no data available for city poum,because of list index out of range
# processing Record 1 of Set 622 | sokolo
# no data available for city sokolo,because of list index out of range
# processing Record 1 of Set 622 | constitucion
# no data available for city constitucion,because of list index out of range
# processing Record 1 of Set 622 | maceio
# no data available for city maceio,because of list index out of range
# processing Record 1 of Set 622 | shaunavon
# no data available for city shaunavon,because of list index out of range
# processing Record 1 of Set 622 | guliston
# no data available for city guliston,because of list index out of range
# processing Record 1 of Set 622 | masunga
# no data available for city masunga,because of list index out of range
# processing Record 1 of Set 622 | pevek
# no data available for city pevek,because of list index out of range
# processing Record 1 of Set 622 | amderma
# no data available for city amderma,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | rampura
# no data available for city rampura,because of list index out of range
# processing Record 1 of Set 622 | antofagasta
# no data available for city antofagasta,because of list index out of range
# processing Record 1 of Set 622 | awjilah
# no data available for city awjilah,because of list index out of range
# processing Record 1 of Set 622 | nemuro
# no data available for city nemuro,because of list index out of range
# processing Record 1 of Set 622 | sobolevo
# no data available for city sobolevo,because of list index out of range
# processing Record 1 of Set 622 | komsomolskiy
# no data available for city komsomolskiy,because of list index out of range
# processing Record 1 of Set 622 | qui nhon
# no data available for city qui nhon,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | dodoma
# no data available for city dodoma,because of list index out of range
# processing Record 1 of Set 622 | tabas
# no data available for city tabas,because of list index out of range
# processing Record 1 of Set 622 | yambio
# no data available for city yambio,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | nara
# no data available for city nara,because of list index out of range
# processing Record 1 of Set 622 | san carlos de bariloche
# no data available for city san carlos de bariloche,because of list index out of range
# processing Record 1 of Set 622 | attawapiskat
# no data available for city attawapiskat,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | qasigiannguit
# no data available for city qasigiannguit,because of list index out of range
# processing Record 1 of Set 622 | yanan
# no data available for city yanan,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | preobrazheniye
# no data available for city preobrazheniye,because of list index out of range
# processing Record 1 of Set 622 | ancud
# no data available for city ancud,because of list index out of range
# processing Record 1 of Set 622 | vaitupu
# no data available for city vaitupu,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | strezhevoy
# no data available for city strezhevoy,because of list index out of range
# processing Record 1 of Set 622 | daxian
# no data available for city daxian,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | pangnirtung
# no data available for city pangnirtung,because of list index out of range
# processing Record 1 of Set 622 | grand river south east
# no data available for city grand river south east,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | zaysan
# no data available for city zaysan,because of list index out of range
# processing Record 1 of Set 622 | auki
# no data available for city auki,because of list index out of range
# processing Record 1 of Set 622 | tumannyy
# no data available for city tumannyy,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | sola
# no data available for city sola,because of list index out of range
# processing Record 1 of Set 622 | tura
# no data available for city tura,because of list index out of range
# processing Record 1 of Set 622 | chagda
# no data available for city chagda,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | kobryn
# no data available for city kobryn,because of list index out of range
# processing Record 1 of Set 622 | orbetello
# no data available for city orbetello,because of list index out of range
# processing Record 1 of Set 622 | saint anthony
# no data available for city saint anthony,because of list index out of range
# processing Record 1 of Set 622 | phalodi
# no data available for city phalodi,because of list index out of range
# processing Record 1 of Set 622 | rocha
# no data available for city rocha,because of list index out of range
# processing Record 1 of Set 622 | forestville
# no data available for city forestville,because of list index out of range
# processing Record 1 of Set 622 | sao filipe
# no data available for city sao filipe,because of list index out of range
# processing Record 1 of Set 622 | aktau
# no data available for city aktau,because of list index out of range
# processing Record 1 of Set 622 | port-gentil
# no data available for city port-gentil,because of list index out of range
# processing Record 1 of Set 622 | kokopo
# no data available for city kokopo,because of list index out of range
# processing Record 1 of Set 622 | san luis
# no data available for city san luis,because of list index out of range
# processing Record 1 of Set 622 | bandarbeyla
# no data available for city bandarbeyla,because of list index out of range
# processing Record 1 of Set 622 | kampong thum
# no data available for city kampong thum,because of list index out of range
# processing Record 1 of Set 622 | goure
# no data available for city goure,because of list index out of range
# processing Record 1 of Set 622 | faya
# no data available for city faya,because of list index out of range
# processing Record 1 of Set 622 | torbay
# no data available for city torbay,because of list index out of range
# processing Record 1 of Set 622 | cabedelo
# no data available for city cabedelo,because of list index out of range
# processing Record 1 of Set 622 | moree
# no data available for city moree,because of list index out of range
# processing Record 1 of Set 622 | imeni babushkina
# no data available for city imeni babushkina,because of list index out of range
# processing Record 1 of Set 622 | uvalde
# no data available for city uvalde,because of list index out of range
# processing Record 1 of Set 622 | benguela
# no data available for city benguela,because of list index out of range
# processing Record 1 of Set 622 | tubruq
# no data available for city tubruq,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | mezen
# no data available for city mezen,because of list index out of range
# processing Record 1 of Set 622 | broken hill
# no data available for city broken hill,because of list index out of range
# processing Record 1 of Set 622 | dayong
# no data available for city dayong,because of list index out of range
# processing Record 1 of Set 622 | pimentel
# no data available for city pimentel,because of list index out of range
# processing Record 1 of Set 622 | broome
# no data available for city broome,because of list index out of range
# processing Record 1 of Set 622 | vila franca do campo
# no data available for city vila franca do campo,because of list index out of range
# processing Record 1 of Set 622 | chapais
# no data available for city chapais,because of list index out of range
# processing Record 1 of Set 622 | tabatinga
# no data available for city tabatinga,because of list index out of range
# processing Record 1 of Set 622 | kavieng
# no data available for city kavieng,because of list index out of range
# processing Record 1 of Set 622 | saint-joseph
# no data available for city saint-joseph,because of list index out of range
# processing Record 1 of Set 622 | esperance
# no data available for city esperance,because of list index out of range
# processing Record 1 of Set 622 | lakeside
# no data available for city lakeside,because of list index out of range
# processing Record 1 of Set 622 | baykit
# no data available for city baykit,because of list index out of range
# processing Record 1 of Set 622 | lufilufi
# no data available for city lufilufi,because of list index out of range
# processing Record 1 of Set 622 | fethiye
# no data available for city fethiye,because of list index out of range
# processing Record 1 of Set 622 | abu dhabi
# no data available for city abu dhabi,because of list index out of range
# processing Record 1 of Set 622 | lorengau
# no data available for city lorengau,because of list index out of range
# processing Record 1 of Set 622 | namatanai
# no data available for city namatanai,because of list index out of range
# processing Record 1 of Set 622 | balad
# no data available for city balad,because of list index out of range
# processing Record 1 of Set 622 | marsh harbour
# no data available for city marsh harbour,because of list index out of range
# processing Record 1 of Set 622 | alexandria
# no data available for city alexandria,because of list index out of range
# processing Record 1 of Set 622 | bratsk
# no data available for city bratsk,because of list index out of range
# processing Record 1 of Set 622 | fort nelson
# no data available for city fort nelson,because of list index out of range
# processing Record 1 of Set 622 | sheridan
# no data available for city sheridan,because of list index out of range
# processing Record 1 of Set 622 | vaitape
# no data available for city vaitape,because of list index out of range
# processing Record 1 of Set 622 | hualmay
# no data available for city hualmay,because of list index out of range
# processing Record 1 of Set 622 | esik
# no data available for city esik,because of list index out of range
# processing Record 1 of Set 622 | sinkat
# no data available for city sinkat,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | kapchorwa
# no data available for city kapchorwa,because of list index out of range
# processing Record 1 of Set 622 | ixtapa
# no data available for city ixtapa,because of list index out of range
# processing Record 1 of Set 622 | corinto
# no data available for city corinto,because of list index out of range
# processing Record 1 of Set 622 | mandalgovi
# no data available for city mandalgovi,because of list index out of range
# processing Record 1 of Set 622 | lodja
# no data available for city lodja,because of list index out of range
# processing Record 1 of Set 622 | abilene
# no data available for city abilene,because of list index out of range
# processing Record 1 of Set 622 | marzuq
# no data available for city marzuq,because of list index out of range
# processing Record 1 of Set 622 | meulaboh
# no data available for city meulaboh,because of list index out of range
# processing Record 1 of Set 622 | topolobampo
# no data available for city topolobampo,because of list index out of range
# processing Record 1 of Set 622 | caravelas
# no data available for city caravelas,because of list index out of range
# processing Record 1 of Set 622 | koroni
# no data available for city koroni,because of list index out of range
# processing Record 1 of Set 622 | hohhot
# no data available for city hohhot,because of list index out of range
# processing Record 1 of Set 622 | hearst
# no data available for city hearst,because of list index out of range
# processing Record 1 of Set 622 | egvekinot
# no data available for city egvekinot,because of list index out of range
# processing Record 1 of Set 622 | kovdor
# no data available for city kovdor,because of list index out of range
# processing Record 1 of Set 622 | mabaruma
# no data available for city mabaruma,because of list index out of range
# processing Record 1 of Set 622 | chara
# no data available for city chara,because of list index out of range
# processing Record 1 of Set 622 | zhezkazgan
# no data available for city zhezkazgan,because of list index out of range
# processing Record 1 of Set 622 | the valley
# no data available for city the valley,because of list index out of range
# processing Record 1 of Set 622 | inta
# no data available for city inta,because of list index out of range
# processing Record 1 of Set 622 | aquiraz
# no data available for city aquiraz,because of list index out of range
# processing Record 1 of Set 622 | calama
# no data available for city calama,because of list index out of range
# processing Record 1 of Set 622 | tomatlan
# no data available for city tomatlan,because of list index out of range
# processing Record 1 of Set 622 | avera
# no data available for city avera,because of list index out of range
# processing Record 1 of Set 622 | mende
# no data available for city mende,because of list index out of range
# processing Record 1 of Set 622 | zaykovo
# no data available for city zaykovo,because of list index out of range
# processing Record 1 of Set 622 | port lincoln
# no data available for city port lincoln,because of list index out of range
# processing Record 1 of Set 622 | kashary
# no data available for city kashary,because of list index out of range
# processing Record 1 of Set 622 | port moresby
# no data available for city port moresby,because of list index out of range
# processing Record 1 of Set 622 | amapa
# no data available for city amapa,because of list index out of range
# processing Record 1 of Set 622 | ostrovnoy
# no data available for city ostrovnoy,because of list index out of range
# processing Record 1 of Set 622 | cidreira
# no data available for city cidreira,because of list index out of range
# processing Record 1 of Set 622 | sterling
# no data available for city sterling,because of list index out of range
# processing Record 1 of Set 622 | ransang
# no data available for city ransang,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | keshorai patan
# no data available for city keshorai patan,because of list index out of range
# processing Record 1 of Set 622 | coquimbo
# no data available for city coquimbo,because of list index out of range
# processing Record 1 of Set 622 | vwawa
# no data available for city vwawa,because of list index out of range
# processing Record 1 of Set 622 | umm qays
# no data available for city umm qays,because of list index out of range
# processing Record 1 of Set 622 | troitsko-pechorsk
# no data available for city troitsko-pechorsk,because of list index out of range
# processing Record 1 of Set 622 | vidim
# ...
# processing Record 1 of Set 622 | pingzhuang
# no data available for city pingzhuang,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | dongsheng
# no data available for city dongsheng,because of list index out of range
# processing Record 1 of Set 622 | deputatskiy
# no data available for city deputatskiy,because of list index out of range
# processing Record 1 of Set 622 | troutdale
# no data available for city troutdale,because of list index out of range
# processing Record 1 of Set 622 | takoradi
# no data available for city takoradi,because of list index out of range
# processing Record 1 of Set 622 | sanming
# no data available for city sanming,because of list index out of range
# processing Record 1 of Set 622 | yate
# no data available for city yate,because of list index out of range
# processing Record 1 of Set 622 | russell
# no data available for city russell,because of list index out of range
# processing Record 1 of Set 622 | kultuk
# no data available for city kultuk,because of list index out of range
# processing Record 1 of Set 622 | kulunda
# no data available for city kulunda,because of list index out of range
# processing Record 1 of Set 622 | barentsburg
# no data available for city barentsburg,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | palembang
# no data available for city palembang,because of list index out of range
# processing Record 1 of Set 622 | pueblo nuevo
# no data available for city pueblo nuevo,because of list index out of range
# processing Record 1 of Set 622 | bud
# no data available for city bud,because of list index out of range
# processing Record 1 of Set 622 | tilichiki
# no data available for city tilichiki,because of list index out of range
# processing Record 1 of Set 622 | mehran
# no data available for city mehran,because of list index out of range
# processing Record 1 of Set 622 | abu kamal
# no data available for city abu kamal,because of list index out of range
# processing Record 1 of Set 622 | breves
# no data available for city breves,because of list index out of range
# processing Record 1 of Set 622 | naples
# no data available for city naples,because of list index out of range
# processing Record 1 of Set 622 | solnechnyy
# no data available for city solnechnyy,because of list index out of range
# processing Record 1 of Set 622 | halmstad
# no data available for city halmstad,because of list index out of range
# processing Record 1 of Set 622 | hasaki
# no data available for city hasaki,because of list index out of range
# processing Record 1 of Set 622 | juba
# no data available for city juba,because of list index out of range
# processing Record 1 of Set 622 | lewisville
# no data available for city lewisville,because of list index out of range
# processing Record 1 of Set 622 | daokou
# no data available for city daokou,because of list index out of range
# processing Record 1 of Set 622 | sambava
# no data available for city sambava,because of list index out of range
# processing Record 1 of Set 622 | enshi
# no data available for city enshi,because of list index out of range
# processing Record 1 of Set 622 | silyanah
# no data available for city silyanah,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | hervey bay
# no data available for city hervey bay,because of list index out of range
# processing Record 1 of Set 622 | palmer
# no data available for city palmer,because of list index out of range
# processing Record 1 of Set 622 | marsa matruh
# no data available for city marsa matruh,because of list index out of range
# processing Record 1 of Set 622 | tebingtinggi
# no data available for city tebingtinggi,because of list index out of range
# processing Record 1 of Set 622 | papetoai
# no data available for city papetoai,because of list index out of range
# processing Record 1 of Set 622 | ballina
# no data available for city ballina,because of list index out of range
# processing Record 1 of Set 622 | stranda
# no data available for city stranda,because of list index out of range
# processing Record 1 of Set 622 | katangli
# no data available for city katangli,because of list index out of range
# processing Record 1 of Set 622 | hambantota
# no data available for city hambantota,because of list index out of range
# processing Record 1 of Set 622 | valparaiso
# no data available for city valparaiso,because of list index out of range
# processing Record 1 of Set 622 | ahuimanu
# no data available for city ahuimanu,because of list index out of range
# processing Record 1 of Set 622 | ghatsila
# no data available for city ghatsila,because of list index out of range
# processing Record 1 of Set 622 | nanortalik
# no data available for city nanortalik,because of list index out of range
# processing Record 1 of Set 622 | sassandra
# no data available for city sassandra,because of list index out of range
# processing Record 1 of Set 622 | disna
# no data available for city disna,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | berlevag
# no data available for city berlevag,because of list index out of range
# processing Record 1 of Set 622 | itigi
# no data available for city itigi,because of list index out of range
# processing Record 1 of Set 622 | serebryansk
# no data available for city serebryansk,because of list index out of range
# processing Record 1 of Set 622 | kavarskas
# no data available for city kavarskas,because of list index out of range
# processing Record 1 of Set 622 | loubomo
# no data available for city loubomo,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | cafarnaum
# no data available for city cafarnaum,because of list index out of range
# processing Record 1 of Set 622 | yabrud
# no data available for city yabrud,because of list index out of range
# processing Record 1 of Set 622 | tiarei
# no data available for city tiarei,because of list index out of range
# processing Record 1 of Set 622 | high prairie
# no data available for city high prairie,because of list index out of range
# processing Record 1 of Set 622 | sangin
# no data available for city sangin,because of list index out of range
# processing Record 1 of Set 622 | toamasina
# no data available for city toamasina,because of list index out of range
# processing Record 1 of Set 622 | kralendijk
# no data available for city kralendijk,because of list index out of range
# processing Record 1 of Set 622 | muravlenko
# no data available for city muravlenko,because of list index out of range
# processing Record 1 of Set 622 | skibbereen
# no data available for city skibbereen,because of list index out of range
# processing Record 1 of Set 622 | quibdo
# no data available for city quibdo,because of list index out of range
# processing Record 1 of Set 622 | northam
# no data available for city northam,because of list index out of range
# processing Record 1 of Set 622 | thinadhoo
# no data available for city thinadhoo,because of list index out of range
# processing Record 1 of Set 622 | andijon
# no data available for city andijon,because of list index out of range
# processing Record 1 of Set 622 | vestmannaeyjar
# no data available for city vestmannaeyjar,because of list index out of range
# processing Record 1 of Set 622 | innisfail
# no data available for city innisfail,because of list index out of range
# processing Record 1 of Set 622 | clovis
# no data available for city clovis,because of list index out of range
# processing Record 1 of Set 622 | taoudenni
# no data available for city taoudenni,because of list index out of range
# processing Record 1 of Set 622 | catuday
# no data available for city catuday,because of list index out of range
# processing Record 1 of Set 622 | aquin
# no data available for city aquin,because of list index out of range
# processing Record 1 of Set 622 | cabras
# no data available for city cabras,because of list index out of range
# processing Record 1 of Set 622 | senneterre
# no data available for city senneterre,because of list index out of range
# processing Record 1 of Set 622 | ampanihy
# no data available for city ampanihy,because of list index out of range
# processing Record 1 of Set 622 | afyonkarahisar
# no data available for city afyonkarahisar,because of list index out of range
# processing Record 1 of Set 622 | saint-pierre
# no data available for city saint-pierre,because of list index out of range
# processing Record 1 of Set 622 | ascension
# no data available for city ascension,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | tahe
# no data available for city tahe,because of list index out of range
# processing Record 1 of Set 622 | joensuu
# no data available for city joensuu,because of list index out of range
# processing Record 1 of Set 622 | yanam
# no data available for city yanam,because of list index out of range
# processing Record 1 of Set 622 | warmbad
# no data available for city warmbad,because of list index out of range
# processing Record 1 of Set 622 | tateyama
# no data available for city tateyama,because of list index out of range
# processing Record 1 of Set 622 | aybak
# no data available for city aybak,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | lezajsk
# no data available for city lezajsk,because of list index out of range
# processing Record 1 of Set 622 | luba
# no data available for city luba,because of list index out of range
# processing Record 1 of Set 622 | trairi
# no data available for city trairi,because of list index out of range
# processing Record 1 of Set 622 | kampil
# no data available for city kampil,because of list index out of range
# processing Record 1 of Set 622 | neiafu
# no data available for city neiafu,because of list index out of range
# processing Record 1 of Set 622 | san luis de gaceno
# no data available for city san luis de gaceno,because of list index out of range
# processing Record 1 of Set 622 | vardo
# no data available for city vardo,because of list index out of range
# processing Record 1 of Set 622 | adrar
# no data available for city adrar,because of list index out of range
# processing Record 1 of Set 622 | karkaralinsk
# no data available for city karkaralinsk,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | nhulunbuy
# no data available for city nhulunbuy,because of list index out of range
# processing Record 1 of Set 622 | hammerfest
# no data available for city hammerfest,because of list index out of range
# processing Record 1 of Set 622 | portland
# no data available for city portland,because of list index out of range
# processing Record 1 of Set 622 | acajutla
# no data available for city acajutla,because of list index out of range
# processing Record 1 of Set 622 | wahran
# no data available for city wahran,because of HTTP Error 404: Not Found
# processing Record 1 of Set 622 | marsaxlokk
# no data available for city marsaxlokk,because of list index out of range
# processing Record 1 of Set 622 | papara
# no data available for city papara,because of list index out of range
# processing Record 1 of Set 622 | agaro
# no data available for city agaro,because of list index out of range
# processing Record 1 of Set 622 | shadrinsk
# no data available for city shadrinsk,because of list index out of range
# processing Record 1 of Set 622 | sur
# no data available for city sur,because of list index out of range
# processing Record 1 of Set 622 | mareeba
# no data available for city mareeba,because of list index out of range
# processing Record 1 of Set 622 | springdale
# no data available for city springdale,because of list index out of range
# processing Record 1 of Set 622 | peleduy
# no data available for city peleduy,because of list index out of range
# processing Record 1 of Set 622 | black river
# no data available for city black river,because of list index out of range
# processing Record 1 of Set 622 | morgan city
# no data available for city morgan city,because of list index out of range
# processing Record 1 of Set 622 | malpe
# no data available for city malpe,because of list index out of range
# processing Record 1 of Set 622 | puerto escondido
# no data available for city puerto escondido,because of list index out of range
# processing Record 1 of Set 622 | severnyy-kospashskiy
# no data available for city severnyy-kospashskiy,because of list index out of range
# processing Record 1 of Set 622 | nancha
# no data available for city nancha,because of list index out of range
# processing Record 1 of Set 622 | chalmette
# no data available for city chalmette,because of list index out of range
# processing Record 1 of Set 622 | puerto carreno
# no data available for city puerto carreno,because of list index out of range
# processing Record 1 of Set 622 | abha
# no data available for city abha,because of list index out of range
# processing Record 1 of Set 622 | abdulino
# no data available for city abdulino,because of list index out of range
# processing Record 1 of Set 622 | astoria
# no data available for city astoria,because of list index out of range
# processing Record 1 of Set 622 | bosaso
# no data available for city bosaso,because of list index out of range
# processing Record 1 of Set 622 | pauini
# no data available for city pauini,because of list index out of range
# processing Record 1 of Set 622 | tual
# no data available for city tual,because of list index out of range
# processing Record 1 of Set 622 | wawa
# no data available for city wawa,because of list index out of range
# processing Record 1 of Set 622 | vila do maio
# no data available for city vila do maio,because of list index out of range
# processing Record 1 of Set 622 | skelleftea
# no data available for city skelleftea,because of list index out of range
# processing Record 1 of Set 622 | sungaipenuh
# no data available for city sungaipenuh,because of list index out of range
# processing Record 1 of Set 622 | antalaha
# no data available for city antalaha,because of list index out of range
# processing Record 1 of Set 622 | kuldur
# no data available for city kuldur,because of list index out of range
# processing Record 1 of Set 622 | katherine
# no data available for city katherine,because of list index out of range
# processing Record 1 of Set 622 | yulara
# no data available for city yulara,because of list index out of range
# processing Record 1 of Set 622 | roma
# no data available for city roma,because of list index out of range
# processing Record 1 of Set 622 | zambezi
# no data available for city zambezi,because of list index out of range
# processing Record 1 of Set 622 | noumea
# no data available for city noumea,because of list index out of range
# processing Record 1 of Set 622 | fort-shevchenko
# no data available for city fort-shevchenko,because of list index out of range
# processing Record 1 of Set 622 | westport
# no data available for city westport,because of list index out of range
# processing Record 1 of Set 622 | richards bay
# no data available for city richards bay,because of list index out of range
# processing Record 1 of Set 622 | libourne
# no data available for city libourne,because of list index out of range
# processing Record 1 of Set 622 | zabaykalsk
# no data available for city zabaykalsk,because of list index out of range
# processing Record 1 of Set 622 | griffith
# no data available for city griffith,because of list index out of range
# processing Record 1 of Set 622 | orsha
# no data available for city orsha,because of list index out of range
# processing Record 1 of Set 622 | asosa
# no data available for city asosa,because of list index out of range
# processing Record 1 of Set 622 | bay saint louis
# no data available for city bay saint louis,because of list index out of range
# processing Record 1 of Set 622 | hennigsdorf
# no data available for city hennigsdorf,because of list index out of range
# processing Record 1 of Set 622 | beringovskiy
# no data available for city beringovskiy,because of list index out of range
# processing Record 1 of Set 622 | clearwater
# no data available for city clearwater,because of list index out of range
# processing Record 1 of Set 622 | jumla
# no data available for city jumla,because of list index out of range
# processing Record 1 of Set 622 | urla
# no data available for city urla,because of list index out of range
# processing Record 1 of Set 622 | catalina
# no data available for city catalina,because of list index out of range

# %%
weather_py.count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-23e58044a7fc> in <module>
# ----> 1 weather_py.count()
#
# TypeError: count() takes exactly one argument (0 given)

# %%
#Pandas can read unix epoch time, use unit parameter

pd.to_datetime('1562120045', unit = 's')

#Timestamp('2017-12-20 06:56:40')
#Timestamp
# Out:
# Timestamp('2019-07-03 02:14:05')

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# build a dataframe from the cities, lon,and pressure lists


city_data = {"city": cit, 
                "Cloudiness": cloudiness, 
                "Country": country, 
                "Date": date, 
                "Humidity": humidity, 
                "Latitude": lat, 
                "Lng": lon, 
                "Max Temp": temp_max,  
                "Wind Speed": speed, 
                "Temperature": temp
            }
city_data = pd.DataFrame(city_data)
city_data

# %%
city_data.count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-be7f5f6416d6> in <module>
# ----> 1 city_data.count()
#
# AttributeError: 'dict' object has no attribute 'count'

# %%
# Save as a csv  OK
# Note to avoid any issues later, use encoding="utf-8"
weather_data.to_csv("weatherpy.csv", encoding="utf-8", index=False)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
 # Build a scatter plot for each data type
plt.scatter(city_data["Max Temp"], city_data["Latitude"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max Temp"+"(F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude vs Max Temperature.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(city_data["Humidity"], city_data["Latitude"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity" +"(%)")
plt.xlabel("Latitude")
plt.grid(True)

# Set the y-limits of the current axes to 100 Fahrenheit

ylim=(0, 100)

# Save the figure
plt.savefig("Latitude vs Humidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_data["Cloudiness"], city_data["Latitude"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness ")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

# Set the y-limits of the current axes to 100 Fahrenheit

xlim=(-80,100)
ylim=(0, 100)


# Save the figure
plt.savefig("City Latitude vs Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_data["Wind Speed"], city_data["Latitude"], marker="o")

# Incorporate the other graph properties
plt.title("Wind Speed (mph) vs. Latitude")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Wind Speed vs Latitude.png")

# Show plot
plt.show()

# %%
 # Build a scatter plot for each data type
plt.scatter(city_data["Temperature"], city_data["Latitude"], marker="o")

# Incorporate the other graph properties
plt.title("Temperature (F) vs. Latitude")
plt.ylabel("Latitude")
plt.xlabel("Temperature")
plt.grid(True)

# Save the figure
plt.savefig("Temperature vrs Latitude.png")

# Show plot
plt.show()

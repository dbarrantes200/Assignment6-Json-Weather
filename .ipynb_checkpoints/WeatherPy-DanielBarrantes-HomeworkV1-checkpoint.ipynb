# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from requests.exceptions import HTTPError
import openweathermapy.core as owm
import time
import datetime

# Import API key
from config2 import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

#api_key

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities ok
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 625

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# %%
# Build partial query URL OK
query_url = f"{url}appid={api_key}&units={units}&q="
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q='

# %%
# Getting weather data by city
settings = {"units": "imperial", "appid": api_key}
total_cities = len(cities)
weather_data = []
lat=[]
lon=[]
temp=[]
cit=[]
temp_max=[]
humidity=[]
wind=[]
date=[]
cloudiness=[]
country=[]
count=1

print('Processing Data Retrieval')
print('-----------------------------')


for city in cities:
   print(f"processing Record {count} of Set {total_cities} | " + city )
   try:
       weather_data = [owm.get_current(city, **settings)]
       lat.append(weather_data[0]["coord"]["lat"])
       lon.append(weather_data[0]["coord"]["lon"])
       temp.append(weather_data[0]["main"]["temp"])
       cit.append(weather_data[0]["name"])
       humidity.append(weather_data[0]["main"]["humidity"])
       temp_max.append(weather_data[0]["main"]["temp_max"])
       country.append(weather_data[0]["sys"]["country"])
       cloudiness.append(weather_data[0]["clouds"]["all"])
       date.append(weather_data[0]["dt"])
       wind.append(weather_data[0]["wind"]["speed"])
       print(query_url + city)   
       
    
       count=count + 1
   except Exception as e:
               print(f"no data available for city {city},because of {e}")
# Out:
# Processing Data Retrieval
# -----------------------------
# processing Record 1 of Set 625 | tuy hoa
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=tuy hoa
# processing Record 2 of Set 625 | airai
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=airai
# processing Record 3 of Set 625 | kodiak
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=kodiak
# processing Record 4 of Set 625 | jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=jamestown
# processing Record 5 of Set 625 | mae ramat
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=mae ramat
# processing Record 6 of Set 625 | meadow lake
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=meadow lake
# processing Record 7 of Set 625 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=saskylakh
# processing Record 8 of Set 625 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=ushuaia
# processing Record 9 of Set 625 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=mahebourg
# processing Record 10 of Set 625 | zyryanka
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=zyryanka
# processing Record 11 of Set 625 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=nikolskoye
# processing Record 12 of Set 625 | ancud
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=ancud
# processing Record 13 of Set 625 | kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=kapaa
# processing Record 14 of Set 625 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=puerto ayora
# processing Record 15 of Set 625 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=komsomolskiy
# processing Record 16 of Set 625 | pangkalanbuun
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=pangkalanbuun
# processing Record 17 of Set 625 | rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=rikitea
# processing Record 18 of Set 625 | orcopampa
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=orcopampa
# processing Record 19 of Set 625 | xai-xai
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=xai-xai
# processing Record 20 of Set 625 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=san cristobal
# processing Record 21 of Set 625 | markdorf
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=markdorf
# processing Record 22 of Set 625 | hobart
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=hobart
# processing Record 23 of Set 625 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=bambous virieux
# processing Record 24 of Set 625 | castro
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=castro
# processing Record 25 of Set 625 | miles city
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=miles city
# processing Record 26 of Set 625 | kasongo-lunda
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=kasongo-lunda
# processing Record 27 of Set 625 | kipushi
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=kipushi
# processing Record 28 of Set 625 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=new norfolk
# processing Record 29 of Set 625 | sao felix do xingu
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=sao felix do xingu
# processing Record 30 of Set 625 | tezu
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=tezu
# processing Record 31 of Set 625 | cabedelo
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=cabedelo
# processing Record 32 of Set 625 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=carnarvon
# processing Record 33 of Set 625 | samusu
# no data available for city samusu,because of HTTP Error 404: Not Found
# processing Record 33 of Set 625 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=nanortalik
# processing Record 34 of Set 625 | fevralsk
# no data available for city fevralsk,because of HTTP Error 404: Not Found
# processing Record 34 of Set 625 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=saint-philippe
# processing Record 35 of Set 625 | muros
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=muros
# processing Record 36 of Set 625 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=sao filipe
# processing Record 37 of Set 625 | east london
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=east london
# processing Record 38 of Set 625 | kulhudhuffushi
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=kulhudhuffushi
# processing Record 39 of Set 625 | linares
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=linares
# processing Record 40 of Set 625 | cape town
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=cape town
# processing Record 41 of Set 625 | tiksi
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=tiksi
# processing Record 42 of Set 625 | otane
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=otane
# processing Record 43 of Set 625 | karatau
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=karatau
# processing Record 44 of Set 625 | saint george
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=saint george
# processing Record 45 of Set 625 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=bathsheba
# processing Record 46 of Set 625 | busselton
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=busselton
# processing Record 47 of Set 625 | newport
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=newport
# processing Record 48 of Set 625 | marienburg
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=marienburg
# processing Record 49 of Set 625 | vilhena
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=vilhena
# processing Record 50 of Set 625 | diamantino
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=diamantino
# processing Record 51 of Set 625 | nizhneyansk
# no data available for city nizhneyansk,because of HTTP Error 404: Not Found
# processing Record 51 of Set 625 | vaini
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=vaini
# processing Record 52 of Set 625 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=punta arenas
# processing Record 53 of Set 625 | barentsburg
# no data available for city barentsburg,because of HTTP Error 404: Not Found
# processing Record 53 of Set 625 | atuona
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=atuona
# processing Record 54 of Set 625 | seddon
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=seddon
# processing Record 55 of Set 625 | porto novo
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=porto novo
# processing Record 56 of Set 625 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=kaitangata
# processing Record 57 of Set 625 | pingliang
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=pingliang
# processing Record 58 of Set 625 | vanimo
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=vanimo
# processing Record 59 of Set 625 | thompson
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=thompson
# processing Record 60 of Set 625 | khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=khatanga
# processing Record 61 of Set 625 | coro
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=coro
# processing Record 62 of Set 625 | provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=provideniya
# processing Record 63 of Set 625 | port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=port alfred
# processing Record 64 of Set 625 | phimai
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=phimai
# processing Record 65 of Set 625 | pevek
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=pevek
# processing Record 66 of Set 625 | sao bento do sul
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=sao bento do sul
# processing Record 67 of Set 625 | mogadishu
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=mogadishu
# processing Record 68 of Set 625 | vao
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=vao
# processing Record 69 of Set 625 | taolanaro
# no data available for city taolanaro,because of HTTP Error 404: Not Found
# processing Record 69 of Set 625 | chicama
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=chicama
# processing Record 70 of Set 625 | ondjiva
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=ondjiva
# processing Record 71 of Set 625 | misratah
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=misratah
# processing Record 72 of Set 625 | mataura
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=mataura
# processing Record 73 of Set 625 | codrington
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=codrington
# processing Record 74 of Set 625 | enid
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=enid
# processing Record 75 of Set 625 | marana
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=marana
# processing Record 76 of Set 625 | sitka
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=sitka
# processing Record 77 of Set 625 | el fuerte
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=el fuerte
# processing Record 78 of Set 625 | karratha
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=karratha
# processing Record 79 of Set 625 | burica
# no data available for city burica,because of HTTP Error 404: Not Found
# processing Record 79 of Set 625 | koumac
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=koumac
# processing Record 80 of Set 625 | narsaq
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=narsaq
# processing Record 81 of Set 625 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=iqaluit
# processing Record 82 of Set 625 | tsihombe
# no data available for city tsihombe,because of HTTP Error 404: Not Found
# processing Record 82 of Set 625 | leshukonskoye
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=leshukonskoye
# processing Record 83 of Set 625 | wuwei
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=wuwei
# processing Record 84 of Set 625 | caravelas
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=caravelas
# processing Record 85 of Set 625 | aasiaat
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=aasiaat
# processing Record 86 of Set 625 | plettenberg bay
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=plettenberg bay
# processing Record 87 of Set 625 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=hithadhoo
# processing Record 88 of Set 625 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=klaksvik
# processing Record 89 of Set 625 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=yellowknife
# processing Record 90 of Set 625 | lorengau
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=lorengau
# processing Record 91 of Set 625 | ubauro
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=ubauro
# processing Record 92 of Set 625 | mahon
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=mahon
# processing Record 93 of Set 625 | kawalu
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=kawalu
# processing Record 94 of Set 625 | souillac
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=souillac
# processing Record 95 of Set 625 | aki
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=aki
# processing Record 96 of Set 625 | vardo
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=vardo
# processing Record 97 of Set 625 | lemesos
# no data available for city lemesos,because of HTTP Error 404: Not Found
# processing Record 97 of Set 625 | grand river south east
# no data available for city grand river south east,because of HTTP Error 404: Not Found
# processing Record 97 of Set 625 | tautira
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=tautira
# processing Record 98 of Set 625 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=sinnamary
# processing Record 99 of Set 625 | nuuk
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=nuuk
# processing Record 100 of Set 625 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=tasiilaq
# processing Record 101 of Set 625 | attawapiskat
# no data available for city attawapiskat,because of HTTP Error 404: Not Found
# processing Record 101 of Set 625 | luang prabang
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=luang prabang
# processing Record 102 of Set 625 | axim
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=axim
# processing Record 103 of Set 625 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=cockburn town
# processing Record 104 of Set 625 | surenavan
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=surenavan
# processing Record 105 of Set 625 | acapulco
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=acapulco
# processing Record 106 of Set 625 | hilsa
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=hilsa
# processing Record 107 of Set 625 | karmana
# no data available for city karmana,because of HTTP Error 404: Not Found
# processing Record 107 of Set 625 | auki
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=auki
# processing Record 108 of Set 625 | vila velha
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=vila velha
# processing Record 109 of Set 625 | daxian
# no data available for city daxian,because of HTTP Error 404: Not Found
# processing Record 109 of Set 625 | avarua
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=avarua
# processing Record 110 of Set 625 | atbasar
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=atbasar
# processing Record 111 of Set 625 | bluff
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=bluff
# processing Record 112 of Set 625 | kirsanov
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=kirsanov
# processing Record 113 of Set 625 | sawakin
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=sawakin
# processing Record 114 of Set 625 | albany
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=albany
# processing Record 115 of Set 625 | porto santo
# no data available for city porto santo,because of HTTP Error 404: Not Found
# processing Record 115 of Set 625 | lompoc
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=lompoc
# processing Record 116 of Set 625 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=arraial do cabo
# processing Record 117 of Set 625 | san vicente
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=san vicente
# processing Record 118 of Set 625 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=ribeira grande
# processing Record 119 of Set 625 | margate
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=margate
# processing Record 120 of Set 625 | araouane
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=araouane
# processing Record 121 of Set 625 | hobyo
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=hobyo
# processing Record 122 of Set 625 | ratnagiri
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=ratnagiri
# processing Record 123 of Set 625 | dunedin
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=dunedin
# processing Record 124 of Set 625 | mudgee
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=mudgee
# processing Record 125 of Set 625 | hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=hermanus
# processing Record 126 of Set 625 | upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=upernavik
# processing Record 127 of Set 625 | portland
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=portland
# processing Record 128 of Set 625 | victoria
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=victoria
# processing Record 129 of Set 625 | saldanha
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=saldanha
# processing Record 130 of Set 625 | ballina
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=ballina
# processing Record 131 of Set 625 | tefe
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=tefe
# processing Record 132 of Set 625 | pisco
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=pisco
# processing Record 133 of Set 625 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=bredasdorp
# processing Record 134 of Set 625 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=tuktoyaktuk
# processing Record 135 of Set 625 | tabuk
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=tabuk
# processing Record 136 of Set 625 | matay
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=matay
# processing Record 137 of Set 625 | talnakh
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=talnakh
# processing Record 138 of Set 625 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=ponta do sol
# processing Record 139 of Set 625 | sangmelima
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=sangmelima
# processing Record 140 of Set 625 | illoqqortoormiut
# no data available for city illoqqortoormiut,because of HTTP Error 404: Not Found
# processing Record 140 of Set 625 | saleaula
# no data available for city saleaula,because of HTTP Error 404: Not Found
# processing Record 140 of Set 625 | turukhansk
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=turukhansk
# processing Record 141 of Set 625 | srandakan
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=srandakan
# processing Record 142 of Set 625 | lamu
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=lamu
# processing Record 143 of Set 625 | erenhot
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=erenhot
# processing Record 144 of Set 625 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=chokurdakh
# processing Record 145 of Set 625 | san luis
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=san luis
# processing Record 146 of Set 625 | havelock
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=havelock
# processing Record 147 of Set 625 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=beringovskiy
# processing Record 148 of Set 625 | tecolutla
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=tecolutla
# processing Record 149 of Set 625 | torbay
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=torbay
# processing Record 150 of Set 625 | lata
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=lata
# processing Record 151 of Set 625 | mys shmidta
# no data available for city mys shmidta,because of HTTP Error 404: Not Found
# processing Record 151 of Set 625 | calama
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=calama
# processing Record 152 of Set 625 | northam
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=northam
# processing Record 153 of Set 625 | kavieng
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=kavieng
# processing Record 154 of Set 625 | lasa
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=lasa
# processing Record 155 of Set 625 | aklavik
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=aklavik
# processing Record 156 of Set 625 | changtu
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=changtu
# processing Record 157 of Set 625 | butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=butaritari
# processing Record 158 of Set 625 | santiago
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=santiago
# processing Record 159 of Set 625 | pemberton
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=pemberton
# processing Record 160 of Set 625 | hasaki
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=hasaki
# processing Record 161 of Set 625 | livingston
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=livingston
# processing Record 162 of Set 625 | port hardy
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=port hardy
# processing Record 163 of Set 625 | salalah
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=salalah
# processing Record 164 of Set 625 | hilo
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=hilo
# processing Record 165 of Set 625 | llanes
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=llanes
# processing Record 166 of Set 625 | chirilagua
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=chirilagua
# processing Record 167 of Set 625 | banjar
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=banjar
# processing Record 168 of Set 625 | korla
# no data available for city korla,because of HTTP Error 404: Not Found
# processing Record 168 of Set 625 | poddorye
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=poddorye
# processing Record 169 of Set 625 | dikson
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=dikson
# processing Record 170 of Set 625 | faya
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=faya
# processing Record 171 of Set 625 | half moon bay
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=half moon bay
# processing Record 172 of Set 625 | geraldton
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=geraldton
# processing Record 173 of Set 625 | xingyi
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=xingyi
# processing Record 174 of Set 625 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=taoudenni
# processing Record 175 of Set 625 | burriana
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=burriana
# processing Record 176 of Set 625 | maceio
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=maceio
# processing Record 177 of Set 625 | camacupa
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=camacupa
# processing Record 178 of Set 625 | cidreira
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=cidreira
# processing Record 179 of Set 625 | tiarei
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=tiarei
# processing Record 180 of Set 625 | paita
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=paita
# processing Record 181 of Set 625 | mackay
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=mackay
# processing Record 182 of Set 625 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=leningradskiy
# processing Record 183 of Set 625 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=guerrero negro
# processing Record 184 of Set 625 | inta
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=inta
# processing Record 185 of Set 625 | tarbes
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=tarbes
# processing Record 186 of Set 625 | jasper
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=jasper
# processing Record 187 of Set 625 | santa cruz
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=santa cruz
# processing Record 188 of Set 625 | petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=petropavlovsk-kamchatskiy
# processing Record 189 of Set 625 | barrow
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=barrow
# processing Record 190 of Set 625 | sayhat
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=sayhat
# processing Record 191 of Set 625 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=coquimbo
# processing Record 192 of Set 625 | sorland
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=sorland
# processing Record 193 of Set 625 | tutoia
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=tutoia
# processing Record 194 of Set 625 | alikalia
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=alikalia
# processing Record 195 of Set 625 | namibe
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=namibe
# processing Record 196 of Set 625 | polyarnyy
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=polyarnyy
# processing Record 197 of Set 625 | nantucket
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=nantucket
# processing Record 198 of Set 625 | banda aceh
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=banda aceh
# processing Record 199 of Set 625 | esmeraldas
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=esmeraldas
# processing Record 200 of Set 625 | ikom
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=ikom
# processing Record 201 of Set 625 | alto araguaia
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=alto araguaia
# processing Record 202 of Set 625 | shingu
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=shingu
# processing Record 203 of Set 625 | palabuhanratu
# no data available for city palabuhanratu,because of HTTP Error 404: Not Found
# processing Record 203 of Set 625 | tarudant
# no data available for city tarudant,because of HTTP Error 404: Not Found
# processing Record 203 of Set 625 | alassio
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=alassio
# processing Record 204 of Set 625 | keti bandar
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=keti bandar
# processing Record 205 of Set 625 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=port lincoln
# processing Record 206 of Set 625 | narasannapeta
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=narasannapeta
# processing Record 207 of Set 625 | gat
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=gat
# processing Record 208 of Set 625 | saint anthony
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=saint anthony
# processing Record 209 of Set 625 | santa fe
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=santa fe
# processing Record 210 of Set 625 | bartica
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=bartica
# processing Record 211 of Set 625 | bitung
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=bitung
# processing Record 212 of Set 625 | zonguldak
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=zonguldak
# processing Record 213 of Set 625 | kailua
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=kailua
# processing Record 214 of Set 625 | tura
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=tura
# processing Record 215 of Set 625 | lerwick
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=lerwick
# processing Record 216 of Set 625 | danville
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=danville
# processing Record 217 of Set 625 | bagnacavallo
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=bagnacavallo
# processing Record 218 of Set 625 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=cap malheureux
# processing Record 219 of Set 625 | wanxian
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=wanxian
# processing Record 220 of Set 625 | funadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=funadhoo
# processing Record 221 of Set 625 | patiya
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=patiya
# processing Record 222 of Set 625 | mayo
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=mayo
# processing Record 223 of Set 625 | zaragoza
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=zaragoza
# processing Record 224 of Set 625 | marawi
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=marawi
# processing Record 225 of Set 625 | porlamar
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=porlamar
# processing Record 226 of Set 625 | bilma
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=bilma
# processing Record 227 of Set 625 | ambon
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=ambon
# processing Record 228 of Set 625 | lingao
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=lingao
# processing Record 229 of Set 625 | olinda
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=olinda
# processing Record 230 of Set 625 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=longyearbyen
# processing Record 231 of Set 625 | ranong
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=ranong
# processing Record 232 of Set 625 | formoso do araguaia
# no data available for city formoso do araguaia,because of HTTP Error 404: Not Found
# processing Record 232 of Set 625 | bilibino
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=bilibino
# processing Record 233 of Set 625 | belgrade
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=belgrade
# processing Record 234 of Set 625 | saint-francois
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=saint-francois
# processing Record 235 of Set 625 | sentyabrskiy
# no data available for city sentyabrskiy,because of HTTP Error 404: Not Found
# processing Record 235 of Set 625 | kapuskasing
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=kapuskasing
# processing Record 236 of Set 625 | krasnoselkup
# no data available for city krasnoselkup,because of HTTP Error 404: Not Found
# processing Record 236 of Set 625 | ibra
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=ibra
# processing Record 237 of Set 625 | egvekinot
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=egvekinot
# processing Record 238 of Set 625 | masallatah
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=masallatah
# processing Record 239 of Set 625 | norman wells
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=norman wells
# processing Record 240 of Set 625 | dien bien
# no data available for city dien bien,because of HTTP Error 404: Not Found
# processing Record 240 of Set 625 | mantua
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=mantua
# processing Record 241 of Set 625 | hualmay
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=hualmay
# processing Record 242 of Set 625 | solnechnyy
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=solnechnyy
# processing Record 243 of Set 625 | basco
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=basco
# processing Record 244 of Set 625 | satitoa
# no data available for city satitoa,because of HTTP Error 404: Not Found
# processing Record 244 of Set 625 | tambacounda
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=tambacounda
# processing Record 245 of Set 625 | urengoy
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=urengoy
# processing Record 246 of Set 625 | lazaro cardenas
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=lazaro cardenas
# processing Record 247 of Set 625 | kamenka
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=kamenka
# processing Record 248 of Set 625 | arlit
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=arlit
# processing Record 249 of Set 625 | havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=havre-saint-pierre
# processing Record 250 of Set 625 | fortuna
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=fortuna
# processing Record 251 of Set 625 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=port elizabeth
# processing Record 252 of Set 625 | san patricio
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=san patricio
# processing Record 253 of Set 625 | anloga
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=anloga
# processing Record 254 of Set 625 | westport
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=westport
# processing Record 255 of Set 625 | faanui
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=faanui
# processing Record 256 of Set 625 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=cherskiy
# processing Record 257 of Set 625 | ayan
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=ayan
# processing Record 258 of Set 625 | bethel
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=bethel
# processing Record 259 of Set 625 | san matias
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=san matias
# processing Record 260 of Set 625 | puerto ayacucho
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=puerto ayacucho
# processing Record 261 of Set 625 | te anau
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=te anau
# processing Record 262 of Set 625 | port-gentil
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=port-gentil
# processing Record 263 of Set 625 | sarandi
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=sarandi
# processing Record 264 of Set 625 | vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=vestmannaeyjar
# processing Record 265 of Set 625 | halifax
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=halifax
# processing Record 266 of Set 625 | nadym
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=nadym
# processing Record 267 of Set 625 | poyarkovo
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=poyarkovo
# processing Record 268 of Set 625 | trat
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=trat
# processing Record 269 of Set 625 | nicoya
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=nicoya
# processing Record 270 of Set 625 | karaul
# no data available for city karaul,because of HTTP Error 404: Not Found
# processing Record 270 of Set 625 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=lavrentiya
# processing Record 271 of Set 625 | xuddur
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=xuddur
# processing Record 272 of Set 625 | turayf
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=turayf
# processing Record 273 of Set 625 | illapel
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=illapel
# processing Record 274 of Set 625 | clyde river
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=clyde river
# processing Record 275 of Set 625 | deep river
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=deep river
# processing Record 276 of Set 625 | kuching
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=kuching
# processing Record 277 of Set 625 | vaitupu
# no data available for city vaitupu,because of HTTP Error 404: Not Found
# processing Record 277 of Set 625 | sur
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=sur
# processing Record 278 of Set 625 | zolochiv
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=zolochiv
# processing Record 279 of Set 625 | mitchell
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=mitchell
# processing Record 280 of Set 625 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=cabo san lucas
# processing Record 281 of Set 625 | suntar
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=suntar
# processing Record 282 of Set 625 | sola
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=sola
# processing Record 283 of Set 625 | bajil
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=bajil
# processing Record 284 of Set 625 | luanda
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=luanda
# processing Record 285 of Set 625 | nazret
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=nazret
# processing Record 286 of Set 625 | ulety
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=ulety
# processing Record 287 of Set 625 | bukachacha
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=bukachacha
# processing Record 288 of Set 625 | evensk
# ...
# processing Record 477 of Set 625 | swansea
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=swansea
# processing Record 478 of Set 625 | hammerfest
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=hammerfest
# processing Record 479 of Set 625 | areni
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=areni
# processing Record 480 of Set 625 | khatassy
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=khatassy
# processing Record 481 of Set 625 | araripina
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=araripina
# processing Record 482 of Set 625 | shahr-e babak
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=shahr-e babak
# processing Record 483 of Set 625 | ustek
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=ustek
# processing Record 484 of Set 625 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=pangnirtung
# processing Record 485 of Set 625 | jumla
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=jumla
# processing Record 486 of Set 625 | new bedford
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=new bedford
# processing Record 487 of Set 625 | methoni
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=methoni
# processing Record 488 of Set 625 | vilyuysk
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=vilyuysk
# processing Record 489 of Set 625 | port shepstone
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=port shepstone
# processing Record 490 of Set 625 | praia
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=praia
# processing Record 491 of Set 625 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=bandarbeyla
# processing Record 492 of Set 625 | oriximina
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=oriximina
# processing Record 493 of Set 625 | elko
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=elko
# processing Record 494 of Set 625 | high rock
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=high rock
# processing Record 495 of Set 625 | pangoa
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=pangoa
# processing Record 496 of Set 625 | bogale
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=bogale
# processing Record 497 of Set 625 | ann arbor
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=ann arbor
# processing Record 498 of Set 625 | mareeba
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=mareeba
# processing Record 499 of Set 625 | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=praia da vitoria
# processing Record 500 of Set 625 | aldan
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=aldan
# processing Record 501 of Set 625 | kaduqli
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=kaduqli
# processing Record 502 of Set 625 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=ostrovnoy
# processing Record 503 of Set 625 | kenai
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=kenai
# processing Record 504 of Set 625 | kasongo
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=kasongo
# processing Record 505 of Set 625 | conde
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=conde
# processing Record 506 of Set 625 | jabiru
# no data available for city jabiru,because of HTTP Error 404: Not Found
# processing Record 506 of Set 625 | kasulu
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=kasulu
# processing Record 507 of Set 625 | lagos
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=lagos
# processing Record 508 of Set 625 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=yar-sale
# processing Record 509 of Set 625 | kargasok
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=kargasok
# processing Record 510 of Set 625 | bambari
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=bambari
# processing Record 511 of Set 625 | somerset
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=somerset
# processing Record 512 of Set 625 | svetlogorsk
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=svetlogorsk
# processing Record 513 of Set 625 | zhob
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=zhob
# processing Record 514 of Set 625 | dzhusaly
# no data available for city dzhusaly,because of HTTP Error 404: Not Found
# processing Record 514 of Set 625 | san juan
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=san juan
# processing Record 515 of Set 625 | melbourne
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=melbourne
# processing Record 516 of Set 625 | hokitika
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=hokitika
# processing Record 517 of Set 625 | magnitogorsk
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=magnitogorsk
# processing Record 518 of Set 625 | aflu
# no data available for city aflu,because of HTTP Error 404: Not Found
# processing Record 518 of Set 625 | taltal
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=taltal
# processing Record 519 of Set 625 | velikiy ustyug
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=velikiy ustyug
# processing Record 520 of Set 625 | bulawayo
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=bulawayo
# processing Record 521 of Set 625 | saint-georges
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=saint-georges
# processing Record 522 of Set 625 | borovoy
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=borovoy
# processing Record 523 of Set 625 | chernyshevsk
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=chernyshevsk
# processing Record 524 of Set 625 | stephenville
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=stephenville
# processing Record 525 of Set 625 | pimenta bueno
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=pimenta bueno
# processing Record 526 of Set 625 | atambua
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=atambua
# processing Record 527 of Set 625 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=srednekolymsk
# processing Record 528 of Set 625 | lakes entrance
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=lakes entrance
# processing Record 529 of Set 625 | gwadar
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=gwadar
# processing Record 530 of Set 625 | neiafu
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=neiafu
# processing Record 531 of Set 625 | itoman
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=itoman
# processing Record 532 of Set 625 | port-cartier
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=port-cartier
# processing Record 533 of Set 625 | kloulklubed
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=kloulklubed
# processing Record 534 of Set 625 | waingapu
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=waingapu
# processing Record 535 of Set 625 | tzucacab
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=tzucacab
# processing Record 536 of Set 625 | toppenish
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=toppenish
# processing Record 537 of Set 625 | arosa
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=arosa
# processing Record 538 of Set 625 | port augusta
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=port augusta
# processing Record 539 of Set 625 | grabouw
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=grabouw
# processing Record 540 of Set 625 | akyab
# no data available for city akyab,because of HTTP Error 404: Not Found
# processing Record 540 of Set 625 | duki
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=duki
# processing Record 541 of Set 625 | siguiri
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=siguiri
# processing Record 542 of Set 625 | la concordia
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=la concordia
# processing Record 543 of Set 625 | abnub
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=abnub
# processing Record 544 of Set 625 | tigil
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=tigil
# processing Record 545 of Set 625 | cartagena
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=cartagena
# processing Record 546 of Set 625 | acajutla
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=acajutla
# processing Record 547 of Set 625 | coffs harbour
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=coffs harbour
# processing Record 548 of Set 625 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=nouadhibou
# processing Record 549 of Set 625 | berdigestyakh
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=berdigestyakh
# processing Record 550 of Set 625 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=fairbanks
# processing Record 551 of Set 625 | cap-aux-meules
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=cap-aux-meules
# processing Record 552 of Set 625 | lagoa
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=lagoa
# processing Record 553 of Set 625 | alice springs
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=alice springs
# processing Record 554 of Set 625 | marzuq
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=marzuq
# processing Record 555 of Set 625 | ahipara
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=ahipara
# processing Record 556 of Set 625 | mecca
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=mecca
# processing Record 557 of Set 625 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=kruisfontein
# processing Record 558 of Set 625 | manicore
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=manicore
# processing Record 559 of Set 625 | mayumba
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=mayumba
# processing Record 560 of Set 625 | sheridan
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=sheridan
# processing Record 561 of Set 625 | santa maria
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=santa maria
# processing Record 562 of Set 625 | tecoanapa
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=tecoanapa
# processing Record 563 of Set 625 | nizhneangarsk
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=nizhneangarsk
# processing Record 564 of Set 625 | manokwari
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=manokwari
# processing Record 565 of Set 625 | san quintin
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=san quintin
# processing Record 566 of Set 625 | bell ville
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=bell ville
# processing Record 567 of Set 625 | buckeye
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=buckeye
# processing Record 568 of Set 625 | pahrump
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=pahrump
# processing Record 569 of Set 625 | birjand
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=birjand
# processing Record 570 of Set 625 | asau
# no data available for city asau,because of HTTP Error 404: Not Found
# processing Record 570 of Set 625 | baykit
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=baykit
# processing Record 571 of Set 625 | najran
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=najran
# processing Record 572 of Set 625 | sirsilla
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=sirsilla
# processing Record 573 of Set 625 | emporia
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=emporia
# processing Record 574 of Set 625 | yanan
# no data available for city yanan,because of HTTP Error 404: Not Found

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# build a dataframe from the cities, lon,and pressure lists


weather_data = {"city": cit, 
               "Cloudiness": cloudiness, 
                "Country": country, 
                "Date": date, 
                "Humidity": humidity, 
                "Latitude": lat, 
                "Lng": lon, 
                "Max Temp": temp_max,  
                "Wind Speed": wind, 
                "Temperature": temp
            }
weather_data = pd.DataFrame(weather_data)
weather_data.head()
# Out:
#         city  Cloudiness Country        Date  Humidity  Latitude     Lng  \
# 0    Tuy Hoa          65      VN  1562717659        64     13.08  109.30
# 1      Airai           2      TL  1562717928        56     -8.93  125.41
# 2     Kodiak           1      US  1562717928        55     39.95  -94.76
# 3  Jamestown           0      AU  1562717929        50    -33.21  138.60
# 4  Mae Ramat          90      TH  1562717929       100     16.98   98.52
#
#    Max Temp  Wind Speed  Temperature
# 0     81.41       12.19        81.41
# 1     76.73        0.67        76.73
# 2     91.99        5.82        90.19
# 3     52.07       18.07        52.07
# 4     75.20        4.70        75.20

# %%
weather_data.count()
# Out:
# city           573
# Cloudiness     573
# Country        573
# Date           573
# Humidity       573
# Latitude       573
# Lng            573
# Max Temp       573
# Wind Speed     573
# Temperature    573
# dtype: int64

# %%
# Save as a csv  OK
# Note to avoid any issues later, use encoding="utf-8"
weather_data.to_csv("weatherpy.csv", encoding="utf-8", index=False)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
date = datetime.datetime.now()

# Build a scatter plot for each data type
ax= plt.scatter(weather_data["Latitude"], weather_data["Max Temp"], marker="o",facecolor="blue")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature " + (date.strftime("%x")) )
plt.ylabel("Max Temp"+"(F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Max Temperature vrs Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# Extremes latitudes in both sides (polos) the max temperature levels are in the same range betwen 30 to 80 F. As soon, you latitude is close to zero the max temperatures are the higher ones.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data["Latitude"], weather_data["Humidity"], marker="o",facecolor="b")

# Incorporate the other graph properties
plt.title("Humidity (%) vs. Latitude " + (date.strftime("%x")) )
plt.ylabel("Humidity" +"(%)")
plt.xlabel("Latitude")
plt.grid(True)

# Set the y-limits of the current axes to 100 Fahrenheit

ylim=(0, 100)

# Save the figure
plt.savefig("Humidity vs Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# Humidity is very disperse compared against Latitude.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data["Latitude"], weather_data["Cloudiness"], marker="o",facecolor="b")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness "+ (date.strftime("%x")) )
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

# Set the y-limits of the current axes to 100 Fahrenheit

xlim=(-80,100)
ylim=(0, 100)


# Save the figure
plt.savefig("Cloudiness vs Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# Latitude versus Cloudiness

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
date = datetime.datetime.now()

plt.scatter(weather_data["Latitude"], weather_data["Wind Speed"], marker="o",facecolor="b")

# Incorporate the other graph properties
plt.title("Wind Speed (mph) vs. Latitude " + (date.strftime("%x")) )
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Wind Speed vs Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# Wind Speed and Latitude

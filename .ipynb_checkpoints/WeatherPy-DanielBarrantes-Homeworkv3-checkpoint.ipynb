# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from requests.exceptions import HTTPError
import openweathermapy.core as owm
import time

# Import API key
from config2 import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

api_key
# Out:
# '9586ef608bbf0838f9b387e9d8d4b1da'

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities ok
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
cities
# Out:
# ['albany',
#  'pangnirtung',
#  'luau',
#  'rikitea',
#  'sao filipe',
#  'carnarvon',
#  'belushya guba',
#  'vaini',
#  'qui nhon',
#  'castro',
#  'maceio',
#  'ushuaia',
#  'zempoala',
#  'longyearbyen',
#  'oxford',
#  'kommunisticheskiy',
#  'abha',
#  'roquetas de mar',
#  'mackay',
#  'tsihombe',
#  'upernavik',
#  'jamestown',
#  'barrow',
#  'hithadhoo',
#  'meyungs',
#  'khatanga',
#  'arawa',
#  'mataura',
#  'illoqqortoormiut',
#  'kodiak',
#  'sao gabriel da cachoeira',
#  'amderma',
#  'hofn',
#  'kapaa',
#  'busselton',
#  'rincon',
#  'cape town',
#  'geraldton',
#  'lavrentiya',
#  'grand river south east',
#  'joao pinheiro',
#  'puerto ayora',
#  'osoyoos',
#  'meadow lake',
#  'ribeira grande',
#  'port hawkesbury',
#  'broken hill',
#  'severo-kurilsk',
#  'bluff',
#  'inhambane',
#  'coahuayana',
#  'saldanha',
#  'taolanaro',
#  'khudumelapye',
#  'cuajinicuilapa',
#  'esperance',
#  'tasiilaq',
#  'avarua',
#  'gallup',
#  'butaritari',
#  'sinnamary',
#  'coquimbo',
#  'bargal',
#  'metro',
#  'tumannyy',
#  'yarim',
#  'karaul',
#  'kavieng',
#  'lagoa',
#  'tiksi',
#  'norman wells',
#  'terrell',
#  'sur',
#  'cabo san lucas',
#  'port alfred',
#  'neiafu',
#  'urmary',
#  'shasta lake',
#  'baruun-urt',
#  'pisco',
#  'ostrovnoy',
#  'lebu',
#  'kaitangata',
#  'chuy',
#  'east london',
#  'mys shmidta',
#  'kloulklubed',
#  'mahebourg',
#  'asilah',
#  'talnakh',
#  'mayo',
#  'attawapiskat',
#  'dickinson',
#  'faanui',
#  'tautira',
#  'san patricio',
#  'quatre cocos',
#  'saint george',
#  'punta arenas',
#  'mar del plata',
#  'ahipara',
#  'tucuman',
#  'thompson',
#  'haimen',
#  'boffa',
#  'ternate',
#  'bilibino',
#  'boguchar',
#  'shirakawa',
#  'manta',
#  'luquillo',
#  'kyaikkami',
#  'nome',
#  'alice springs',
#  'hermanus',
#  'cayenne',
#  'san quintin',
#  'luanda',
#  'victoria',
#  'hasaki',
#  'muros',
#  'bilma',
#  'port blair',
#  'bose',
#  'bredasdorp',
#  'prince rupert',
#  'zalesovo',
#  'skibbereen',
#  'atuona',
#  'khilok',
#  'saleaula',
#  'hilo',
#  'nikolskoye',
#  'margate',
#  'pacific grove',
#  'ayagoz',
#  'port lincoln',
#  'constitucion',
#  'alanya',
#  'viligili',
#  'saint-pierre',
#  'souillac',
#  'ancud',
#  'arraial do cabo',
#  'leningradskiy',
#  'dauphin',
#  'yeppoon',
#  'soderhamn',
#  'saskylakh',
#  'vestmanna',
#  'katsuura',
#  'beyneu',
#  'avanigadda',
#  'san juan de los lagos',
#  'salaga',
#  'manokwari',
#  'necochea',
#  'ponta do sol',
#  'hoquiam',
#  'lakes entrance',
#  'princeton',
#  'natal',
#  'raga',
#  'barawe',
#  'alta floresta',
#  'yarega',
#  'mount gambier',
#  'kamenskoye',
#  'yellowknife',
#  'green river',
#  'hobart',
#  'quelimane',
#  'itaueira',
#  'ishigaki',
#  'rawannawi',
#  'anori',
#  'adrar',
#  'letka',
#  'bambous virieux',
#  'pascagoula',
#  'ilulissat',
#  'progreso',
#  'lavumisa',
#  'cidreira',
#  'agadez',
#  'vetluga',
#  'eura',
#  'qaqortoq',
#  'hambantota',
#  'sitka',
#  'palu',
#  'airai',
#  'yar-sale',
#  'tuktoyaktuk',
#  'east stroudsburg',
#  'new norfolk',
#  'balkhash',
#  'pochutla',
#  'sentyabrskiy',
#  'concepcion',
#  'santa lucia',
#  'georgetown',
#  'nabire',
#  'basco',
#  'wanaka',
#  'piacabucu',
#  'salacgriva',
#  'port elizabeth',
#  'saint-philippe',
#  'sinkat',
#  'bengkulu',
#  'kaabong',
#  'kawhia',
#  'pandan',
#  'te anau',
#  'kysyl-syr',
#  'araouane',
#  'amot',
#  'jabiru',
#  'sahuaripa',
#  'salinopolis',
#  'corvallis',
#  'valjala',
#  'paamiut',
#  'sobolevo',
#  'ambilobe',
#  'iracoubo',
#  'mingaora',
#  'qaanaaq',
#  'nishihara',
#  'grand gaube',
#  'la ronge',
#  'sioux lookout',
#  'kachikau',
#  'stavanger',
#  'neepawa',
#  'jibou',
#  'yulara',
#  'cairns',
#  'noumea',
#  'walvis bay',
#  'beringovskiy',
#  'hammerfest',
#  'moree',
#  'salalah',
#  'imbituba',
#  'taraz',
#  'zhuozhou',
#  'cherskiy',
#  'novita',
#  'buritis',
#  'jashpurnagar',
#  'campo maior',
#  'saint-augustin',
#  'bontang',
#  'tual',
#  'provideniya',
#  'padang',
#  'bluefields',
#  'sambava',
#  'maraba',
#  'namatanai',
#  'luorong',
#  'elat',
#  'rocha',
#  'tambun',
#  'balikpapan',
#  'mancheral',
#  'belogorsk',
#  'vao',
#  'husavik',
#  'college',
#  'laguna',
#  'lensk',
#  'kazanskaya',
#  'xixiang',
#  'catamarca',
#  'parabel',
#  'fairbanks',
#  'kahului',
#  'ornskoldsvik',
#  'gizo',
#  'dolbeau',
#  'codrington',
#  'dingle',
#  'sao jose da coroa grande',
#  'kant',
#  'sechura',
#  'hamilton',
#  'bethel',
#  'antofagasta',
#  'torbay',
#  'dikson',
#  'constantine',
#  'felanitx',
#  'usinsk',
#  'zyryanka',
#  'tiverton',
#  'malakal',
#  'tarko-sale',
#  'jam sahib',
#  'kijang',
#  'karpuninskiy',
#  'yola',
#  'deming',
#  'abiy adi',
#  'gladstone',
#  'gotsu',
#  'comodoro rivadavia',
#  'farragut',
#  'nova ushytsya',
#  'sabang',
#  'ormara',
#  'hualmay',
#  'kruisfontein',
#  'taltal',
#  'naze',
#  'palabuhanratu',
#  'huangchuan',
#  'karakendzha',
#  'galesong',
#  'milingimbi',
#  'road town',
#  'faro',
#  'piracanjuba',
#  'north bend',
#  'blagoyevo',
#  'mandera',
#  'fortuna',
#  'kidal',
#  'bonnyville',
#  'shimoda',
#  'anadyr',
#  'aurillac',
#  'chabahar',
#  'luena',
#  'nouadhibou',
#  'aksu',
#  'fernandina beach',
#  'hay river',
#  'mareeba',
#  'portobelo',
#  'sarankhola',
#  'shihezi',
#  'grindavik',
#  'canakkale',
#  'madimba',
#  'george town',
#  'palivere',
#  'farafangana',
#  'baijiantan',
#  'guerrero negro',
#  'komsomolskiy',
#  'seoul',
#  'nyurba',
#  'vaitupu',
#  'iqaluit',
#  'whitehorse',
#  'celarevo',
#  'safaga',
#  'poum',
#  'shingu',
#  'curanilahue',
#  'korla',
#  'makakilo city',
#  'igunga',
#  'impfondo',
#  'kurilsk',
#  'sakakah',
#  'marcona',
#  'kiunga',
#  'iranshahr',
#  'barentsburg',
#  'badiraguato',
#  'caiaponia',
#  'tilichiki',
#  'tiarei',
#  'portland',
#  'verkhnyaya inta',
#  'praia da vitoria',
#  'tabou',
#  'parras',
#  'koupela',
#  'brae',
#  'otane',
#  'zharkent',
#  'manjacaze',
#  'bodden town',
#  'rio grande',
#  'sindou',
#  'lata',
#  'klerksdorp',
#  'bowen',
#  'san jose',
#  'luocheng',
#  'chokurdakh',
#  'marfino',
#  'narasannapeta',
#  'san borja',
#  'faya',
#  'brainerd',
#  'lakselv',
#  'upata',
#  'chatellerault',
#  'kempele',
#  'laramie',
#  'coihaique',
#  'bolshoy tsaryn',
#  'sisimiut',
#  'vestmannaeyjar',
#  'camabatela',
#  'namibe',
#  'mao',
#  'tessalit',
#  'basoko',
#  'luderitz',
#  'jalu',
#  'atasu',
#  'conde',
#  'arraias',
#  'omboue',
#  'carndonagh',
#  'turukhansk',
#  'porvoo',
#  'henties bay',
#  'pevek',
#  'harlingen',
#  'emerald',
#  'nuuk',
#  'kirov',
#  'rundu',
#  'clyde river',
#  'alofi',
#  'bubaque',
#  'ixtapa',
#  'multai',
#  'nizhneyansk',
#  'tuy hoa',
#  'kanke',
#  'vila velha',
#  'flagstaff',
#  'kapit',
#  'puerto ayacucho',
#  'flinders',
#  'malko tarnovo',
#  'maues',
#  'anjozorobe',
#  'batemans bay',
#  'gat',
#  'buala',
#  'sangar',
#  'swan hill',
#  'broome',
#  'mecca',
#  'kununurra',
#  'halifax',
#  'port hardy',
#  'havelock',
#  'ardakan',
#  'santa fe',
#  'kharp',
#  'smithers',
#  'batagay-alyta',
#  'cananeia',
#  'vilhena',
#  'yining',
#  'naftah',
#  'shellbrook',
#  'cubara',
#  'caucaia',
#  'klaksvik',
#  'agadir',
#  'nanortalik',
#  'amga',
#  'oranjestad',
#  'san vicente',
#  'wamba',
#  'iberia',
#  'acarau',
#  'lompoc',
#  'rabak',
#  'magistralnyy',
#  'sorvag',
#  'hukuntsi',
#  'kavali',
#  'lamu',
#  'rensvik',
#  'rio gallegos',
#  'akyab',
#  'casper',
#  'fort nelson',
#  'tidore',
#  'gilgit',
#  'susanville',
#  'dawlatabad',
#  'cazaje',
#  'taybad',
#  'likasi',
#  'zhigansk',
#  'egvekinot',
#  'saint-georges',
#  'marovoay',
#  'huarmey',
#  'biak',
#  'konibodom',
#  'port hedland',
#  'acari',
#  'harper',
#  'balclutha',
#  'pinheiro',
#  'diglur',
#  'ojinaga',
#  'soyo',
#  'sombrio',
#  'vanavara',
#  'atambua',
#  'baykit',
#  'botwood',
#  'key west',
#  'guajara-mirim',
#  'cody',
#  'khania',
#  'belmonte',
#  'fremont',
#  'marawi',
#  'hami',
#  'santa cruz de tenerife',
#  'umzimvubu',
#  'jumla',
#  'san andres',
#  'vostok',
#  'cockburn town',
#  'kathu',
#  'arlit',
#  'peniche',
#  'san policarpo',
#  'chuchkovo',
#  'griffith',
#  'nam tha',
#  'waddan',
#  'baherden',
#  'kailua',
#  'puerto colombia',
#  'yunyang',
#  'mrirt',
#  'bruck an der leitha',
#  'manacapuru',
#  'kadarkut',
#  'nguiu',
#  'evensk',
#  'agboville',
#  'hervey bay',
#  'antalaha',
#  'santa isabel do rio negro',
#  'inobulan',
#  'deer lake',
#  'wulanhaote',
#  'diego de almagro',
#  'cotonou',
#  'verkhnevilyuysk',
#  'carballo',
#  'andenes',
#  'puerto escondido',
#  'kushima',
#  'kalininskaya',
#  'mana',
#  'calama',
#  'fare',
#  'bagepalli',
#  'tabiauea',
#  'orapa',
#  'high level',
#  'korogwe',
#  'zhigalovo',
#  'miyako',
#  'awbari',
#  'chapleau',
#  'tome-acu',
#  'nantucket',
#  'acajutla',
#  'lazarev',
#  'takoradi',
#  'lake station',
#  'honiara',
#  'dunedin',
#  'medicine hat',
#  'along',
#  'denizli',
#  'bolungarvik',
#  'waterloo',
#  'pinega',
#  'russell',
#  'kutum',
#  'george',
#  'bengkalis',
#  'bani',
#  'nakhon si thammarat',
#  'caravelas',
#  'boda',
#  'lolua',
#  'leh',
#  'urdzhar',
#  'sao joao da barra',
#  'mafeteng',
#  'youhao']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information. OK
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# %%
# Build partial query URL OK
query_url = f"{url}appid={api_key}&units={units}&q="
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q='

# %%
settings = {"units": "metric", "appid": api_key}
total_cities = len(cities)
weather_py = []
lat=[]
lon=[]
temp=[]
cit=[]
temp_max=[]
humidity=[]
wind=[]
date=[]
cloudiness=[]
country=[]
count=1

print('Processing Data Retrieval')
print('-----------------------------')


for city in cities:
   print(f"processing Record {count} of Set {total_cities} | " + city )
   try:
       weather_data = [owm.get_current(city, **settings)]
       lat.append(weather_py[0]["coord"]["lat"])
       lon.append(weather_py[0]["coord"]["lon"])
       temp.append(weather_py[0]["main"]["temp"])
       cit.append(weather_py[0]["name"])
       humidity.append(weather_py[0]["main"]["humidity"])
       temp_max.append(weather_py[0]["main"]["temp_max"])
       country.append(weather_py[0]["sys"]["country"])
       cloudiness.append(weather_py[0]["clouds"]["all"])
       date.append(weather_py[0]["dt"])
       wind.append(weather_py[0]["wind"]["speed"])
       print(query_url + city)   
       count=count + 1
   except Exception as e:
               print(f"no data available for city {city},because of {e}")
               #del cities[count-1]
   #except HTTPError as http_err:
    #           print(f'HTTP error occurred: {http_err}')  # Python 3.6
  # except Exception as err:
   #            print(f'Other error occurred: {err}')  # Python 3.6
  #             print(query_url)
# Out:
# Processing Data Retrieval
# -----------------------------
# processing Record 1 of Set 605 | albany
# no data available for city albany,because of list index out of range
# processing Record 1 of Set 605 | pangnirtung
# no data available for city pangnirtung,because of list index out of range
# processing Record 1 of Set 605 | luau
# no data available for city luau,because of list index out of range
# processing Record 1 of Set 605 | rikitea
# no data available for city rikitea,because of list index out of range
# processing Record 1 of Set 605 | sao filipe
# no data available for city sao filipe,because of list index out of range
# processing Record 1 of Set 605 | carnarvon
# no data available for city carnarvon,because of list index out of range
# processing Record 1 of Set 605 | belushya guba
# no data available for city belushya guba,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | vaini
# no data available for city vaini,because of list index out of range
# processing Record 1 of Set 605 | qui nhon
# no data available for city qui nhon,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | castro
# no data available for city castro,because of list index out of range
# processing Record 1 of Set 605 | maceio
# no data available for city maceio,because of list index out of range
# processing Record 1 of Set 605 | ushuaia
# no data available for city ushuaia,because of list index out of range
# processing Record 1 of Set 605 | zempoala
# no data available for city zempoala,because of list index out of range
# processing Record 1 of Set 605 | longyearbyen
# no data available for city longyearbyen,because of list index out of range
# processing Record 1 of Set 605 | oxford
# no data available for city oxford,because of list index out of range
# processing Record 1 of Set 605 | kommunisticheskiy
# no data available for city kommunisticheskiy,because of list index out of range
# processing Record 1 of Set 605 | abha
# no data available for city abha,because of list index out of range
# processing Record 1 of Set 605 | roquetas de mar
# no data available for city roquetas de mar,because of list index out of range
# processing Record 1 of Set 605 | mackay
# no data available for city mackay,because of list index out of range
# processing Record 1 of Set 605 | tsihombe
# no data available for city tsihombe,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | upernavik
# no data available for city upernavik,because of list index out of range
# processing Record 1 of Set 605 | jamestown
# no data available for city jamestown,because of list index out of range
# processing Record 1 of Set 605 | barrow
# no data available for city barrow,because of list index out of range
# processing Record 1 of Set 605 | hithadhoo
# no data available for city hithadhoo,because of list index out of range
# processing Record 1 of Set 605 | meyungs
# no data available for city meyungs,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | khatanga
# no data available for city khatanga,because of list index out of range
# processing Record 1 of Set 605 | arawa
# no data available for city arawa,because of list index out of range
# processing Record 1 of Set 605 | mataura
# no data available for city mataura,because of list index out of range
# processing Record 1 of Set 605 | illoqqortoormiut
# no data available for city illoqqortoormiut,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | kodiak
# no data available for city kodiak,because of list index out of range
# processing Record 1 of Set 605 | sao gabriel da cachoeira
# no data available for city sao gabriel da cachoeira,because of list index out of range
# processing Record 1 of Set 605 | amderma
# no data available for city amderma,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | hofn
# no data available for city hofn,because of list index out of range
# processing Record 1 of Set 605 | kapaa
# no data available for city kapaa,because of list index out of range
# processing Record 1 of Set 605 | busselton
# no data available for city busselton,because of list index out of range
# processing Record 1 of Set 605 | rincon
# no data available for city rincon,because of list index out of range
# processing Record 1 of Set 605 | cape town
# no data available for city cape town,because of list index out of range
# processing Record 1 of Set 605 | geraldton
# no data available for city geraldton,because of list index out of range
# processing Record 1 of Set 605 | lavrentiya
# no data available for city lavrentiya,because of list index out of range
# processing Record 1 of Set 605 | grand river south east
# no data available for city grand river south east,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | joao pinheiro
# no data available for city joao pinheiro,because of list index out of range
# processing Record 1 of Set 605 | puerto ayora
# no data available for city puerto ayora,because of list index out of range
# processing Record 1 of Set 605 | osoyoos
# no data available for city osoyoos,because of list index out of range
# processing Record 1 of Set 605 | meadow lake
# no data available for city meadow lake,because of list index out of range
# processing Record 1 of Set 605 | ribeira grande
# no data available for city ribeira grande,because of list index out of range
# processing Record 1 of Set 605 | port hawkesbury
# no data available for city port hawkesbury,because of list index out of range
# processing Record 1 of Set 605 | broken hill
# no data available for city broken hill,because of list index out of range
# processing Record 1 of Set 605 | severo-kurilsk
# no data available for city severo-kurilsk,because of list index out of range
# processing Record 1 of Set 605 | bluff
# no data available for city bluff,because of list index out of range
# processing Record 1 of Set 605 | inhambane
# no data available for city inhambane,because of list index out of range
# processing Record 1 of Set 605 | coahuayana
# no data available for city coahuayana,because of list index out of range
# processing Record 1 of Set 605 | saldanha
# no data available for city saldanha,because of list index out of range
# processing Record 1 of Set 605 | taolanaro
# no data available for city taolanaro,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | khudumelapye
# no data available for city khudumelapye,because of list index out of range
# processing Record 1 of Set 605 | cuajinicuilapa
# no data available for city cuajinicuilapa,because of list index out of range
# processing Record 1 of Set 605 | esperance
# no data available for city esperance,because of list index out of range
# processing Record 1 of Set 605 | tasiilaq
# no data available for city tasiilaq,because of list index out of range
# processing Record 1 of Set 605 | avarua
# no data available for city avarua,because of list index out of range
# processing Record 1 of Set 605 | gallup
# no data available for city gallup,because of list index out of range
# processing Record 1 of Set 605 | butaritari
# no data available for city butaritari,because of list index out of range
# processing Record 1 of Set 605 | sinnamary
# no data available for city sinnamary,because of list index out of range
# processing Record 1 of Set 605 | coquimbo
# no data available for city coquimbo,because of list index out of range
# processing Record 1 of Set 605 | bargal
# no data available for city bargal,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | metro
# no data available for city metro,because of list index out of range
# processing Record 1 of Set 605 | tumannyy
# no data available for city tumannyy,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | yarim
# no data available for city yarim,because of list index out of range
# processing Record 1 of Set 605 | karaul
# no data available for city karaul,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | kavieng
# no data available for city kavieng,because of list index out of range
# processing Record 1 of Set 605 | lagoa
# no data available for city lagoa,because of list index out of range
# processing Record 1 of Set 605 | tiksi
# no data available for city tiksi,because of list index out of range
# processing Record 1 of Set 605 | norman wells
# no data available for city norman wells,because of list index out of range
# processing Record 1 of Set 605 | terrell
# no data available for city terrell,because of list index out of range
# processing Record 1 of Set 605 | sur
# no data available for city sur,because of list index out of range
# processing Record 1 of Set 605 | cabo san lucas
# no data available for city cabo san lucas,because of list index out of range
# processing Record 1 of Set 605 | port alfred
# no data available for city port alfred,because of list index out of range
# processing Record 1 of Set 605 | neiafu
# no data available for city neiafu,because of list index out of range
# processing Record 1 of Set 605 | urmary
# no data available for city urmary,because of list index out of range
# processing Record 1 of Set 605 | shasta lake
# no data available for city shasta lake,because of list index out of range
# processing Record 1 of Set 605 | baruun-urt
# no data available for city baruun-urt,because of list index out of range
# processing Record 1 of Set 605 | pisco
# no data available for city pisco,because of list index out of range
# processing Record 1 of Set 605 | ostrovnoy
# no data available for city ostrovnoy,because of list index out of range
# processing Record 1 of Set 605 | lebu
# no data available for city lebu,because of list index out of range
# processing Record 1 of Set 605 | kaitangata
# no data available for city kaitangata,because of list index out of range
# processing Record 1 of Set 605 | chuy
# no data available for city chuy,because of list index out of range
# processing Record 1 of Set 605 | east london
# no data available for city east london,because of list index out of range
# processing Record 1 of Set 605 | mys shmidta
# no data available for city mys shmidta,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | kloulklubed
# no data available for city kloulklubed,because of list index out of range
# processing Record 1 of Set 605 | mahebourg
# no data available for city mahebourg,because of list index out of range
# processing Record 1 of Set 605 | asilah
# no data available for city asilah,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | talnakh
# no data available for city talnakh,because of list index out of range
# processing Record 1 of Set 605 | mayo
# no data available for city mayo,because of list index out of range
# processing Record 1 of Set 605 | attawapiskat
# no data available for city attawapiskat,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | dickinson
# no data available for city dickinson,because of list index out of range
# processing Record 1 of Set 605 | faanui
# no data available for city faanui,because of list index out of range
# processing Record 1 of Set 605 | tautira
# no data available for city tautira,because of list index out of range
# processing Record 1 of Set 605 | san patricio
# no data available for city san patricio,because of list index out of range
# processing Record 1 of Set 605 | quatre cocos
# no data available for city quatre cocos,because of list index out of range
# processing Record 1 of Set 605 | saint george
# no data available for city saint george,because of list index out of range
# processing Record 1 of Set 605 | punta arenas
# no data available for city punta arenas,because of list index out of range
# processing Record 1 of Set 605 | mar del plata
# no data available for city mar del plata,because of list index out of range
# processing Record 1 of Set 605 | ahipara
# no data available for city ahipara,because of list index out of range
# processing Record 1 of Set 605 | tucuman
# no data available for city tucuman,because of list index out of range
# processing Record 1 of Set 605 | thompson
# no data available for city thompson,because of list index out of range
# processing Record 1 of Set 605 | haimen
# no data available for city haimen,because of list index out of range
# processing Record 1 of Set 605 | boffa
# no data available for city boffa,because of list index out of range
# processing Record 1 of Set 605 | ternate
# no data available for city ternate,because of list index out of range
# processing Record 1 of Set 605 | bilibino
# no data available for city bilibino,because of list index out of range
# processing Record 1 of Set 605 | boguchar
# no data available for city boguchar,because of list index out of range
# processing Record 1 of Set 605 | shirakawa
# no data available for city shirakawa,because of list index out of range
# processing Record 1 of Set 605 | manta
# no data available for city manta,because of list index out of range
# processing Record 1 of Set 605 | luquillo
# no data available for city luquillo,because of list index out of range
# processing Record 1 of Set 605 | kyaikkami
# no data available for city kyaikkami,because of list index out of range
# processing Record 1 of Set 605 | nome
# no data available for city nome,because of list index out of range
# processing Record 1 of Set 605 | alice springs
# no data available for city alice springs,because of list index out of range
# processing Record 1 of Set 605 | hermanus
# no data available for city hermanus,because of list index out of range
# processing Record 1 of Set 605 | cayenne
# no data available for city cayenne,because of list index out of range
# processing Record 1 of Set 605 | san quintin
# no data available for city san quintin,because of list index out of range
# processing Record 1 of Set 605 | luanda
# no data available for city luanda,because of list index out of range
# processing Record 1 of Set 605 | victoria
# no data available for city victoria,because of list index out of range
# processing Record 1 of Set 605 | hasaki
# no data available for city hasaki,because of list index out of range
# processing Record 1 of Set 605 | muros
# no data available for city muros,because of list index out of range
# processing Record 1 of Set 605 | bilma
# no data available for city bilma,because of list index out of range
# processing Record 1 of Set 605 | port blair
# no data available for city port blair,because of list index out of range
# processing Record 1 of Set 605 | bose
# no data available for city bose,because of list index out of range
# processing Record 1 of Set 605 | bredasdorp
# no data available for city bredasdorp,because of list index out of range
# processing Record 1 of Set 605 | prince rupert
# no data available for city prince rupert,because of list index out of range
# processing Record 1 of Set 605 | zalesovo
# no data available for city zalesovo,because of list index out of range
# processing Record 1 of Set 605 | skibbereen
# no data available for city skibbereen,because of list index out of range
# processing Record 1 of Set 605 | atuona
# no data available for city atuona,because of list index out of range
# processing Record 1 of Set 605 | khilok
# no data available for city khilok,because of list index out of range
# processing Record 1 of Set 605 | saleaula
# no data available for city saleaula,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | hilo
# no data available for city hilo,because of list index out of range
# processing Record 1 of Set 605 | nikolskoye
# no data available for city nikolskoye,because of list index out of range
# processing Record 1 of Set 605 | margate
# no data available for city margate,because of list index out of range
# processing Record 1 of Set 605 | pacific grove
# no data available for city pacific grove,because of list index out of range
# processing Record 1 of Set 605 | ayagoz
# no data available for city ayagoz,because of list index out of range
# processing Record 1 of Set 605 | port lincoln
# no data available for city port lincoln,because of list index out of range
# processing Record 1 of Set 605 | constitucion
# no data available for city constitucion,because of list index out of range
# processing Record 1 of Set 605 | alanya
# no data available for city alanya,because of list index out of range
# processing Record 1 of Set 605 | viligili
# no data available for city viligili,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | saint-pierre
# no data available for city saint-pierre,because of list index out of range
# processing Record 1 of Set 605 | souillac
# no data available for city souillac,because of list index out of range
# processing Record 1 of Set 605 | ancud
# no data available for city ancud,because of list index out of range
# processing Record 1 of Set 605 | arraial do cabo
# no data available for city arraial do cabo,because of list index out of range
# processing Record 1 of Set 605 | leningradskiy
# no data available for city leningradskiy,because of list index out of range
# processing Record 1 of Set 605 | dauphin
# no data available for city dauphin,because of list index out of range
# processing Record 1 of Set 605 | yeppoon
# no data available for city yeppoon,because of list index out of range
# processing Record 1 of Set 605 | soderhamn
# no data available for city soderhamn,because of list index out of range
# processing Record 1 of Set 605 | saskylakh
# no data available for city saskylakh,because of list index out of range
# processing Record 1 of Set 605 | vestmanna
# no data available for city vestmanna,because of list index out of range
# processing Record 1 of Set 605 | katsuura
# no data available for city katsuura,because of list index out of range
# processing Record 1 of Set 605 | beyneu
# no data available for city beyneu,because of list index out of range
# processing Record 1 of Set 605 | avanigadda
# no data available for city avanigadda,because of list index out of range
# processing Record 1 of Set 605 | san juan de los lagos
# no data available for city san juan de los lagos,because of list index out of range
# processing Record 1 of Set 605 | salaga
# no data available for city salaga,because of list index out of range
# processing Record 1 of Set 605 | manokwari
# no data available for city manokwari,because of list index out of range
# processing Record 1 of Set 605 | necochea
# no data available for city necochea,because of list index out of range
# processing Record 1 of Set 605 | ponta do sol
# no data available for city ponta do sol,because of list index out of range
# processing Record 1 of Set 605 | hoquiam
# no data available for city hoquiam,because of list index out of range
# processing Record 1 of Set 605 | lakes entrance
# no data available for city lakes entrance,because of list index out of range
# processing Record 1 of Set 605 | princeton
# no data available for city princeton,because of list index out of range
# processing Record 1 of Set 605 | natal
# no data available for city natal,because of list index out of range
# processing Record 1 of Set 605 | raga
# no data available for city raga,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | barawe
# no data available for city barawe,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | alta floresta
# no data available for city alta floresta,because of list index out of range
# processing Record 1 of Set 605 | yarega
# no data available for city yarega,because of list index out of range
# processing Record 1 of Set 605 | mount gambier
# no data available for city mount gambier,because of list index out of range
# processing Record 1 of Set 605 | kamenskoye
# no data available for city kamenskoye,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | yellowknife
# no data available for city yellowknife,because of list index out of range
# processing Record 1 of Set 605 | green river
# no data available for city green river,because of list index out of range
# processing Record 1 of Set 605 | hobart
# no data available for city hobart,because of list index out of range
# processing Record 1 of Set 605 | quelimane
# no data available for city quelimane,because of list index out of range
# processing Record 1 of Set 605 | itaueira
# no data available for city itaueira,because of list index out of range
# processing Record 1 of Set 605 | ishigaki
# no data available for city ishigaki,because of list index out of range
# processing Record 1 of Set 605 | rawannawi
# no data available for city rawannawi,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | anori
# no data available for city anori,because of list index out of range
# processing Record 1 of Set 605 | adrar
# no data available for city adrar,because of list index out of range
# processing Record 1 of Set 605 | letka
# no data available for city letka,because of list index out of range
# processing Record 1 of Set 605 | bambous virieux
# no data available for city bambous virieux,because of list index out of range
# processing Record 1 of Set 605 | pascagoula
# no data available for city pascagoula,because of list index out of range
# processing Record 1 of Set 605 | ilulissat
# no data available for city ilulissat,because of list index out of range
# processing Record 1 of Set 605 | progreso
# no data available for city progreso,because of list index out of range
# processing Record 1 of Set 605 | lavumisa
# no data available for city lavumisa,because of list index out of range
# processing Record 1 of Set 605 | cidreira
# no data available for city cidreira,because of list index out of range
# processing Record 1 of Set 605 | agadez
# no data available for city agadez,because of list index out of range
# processing Record 1 of Set 605 | vetluga
# no data available for city vetluga,because of list index out of range
# processing Record 1 of Set 605 | eura
# no data available for city eura,because of list index out of range
# processing Record 1 of Set 605 | qaqortoq
# no data available for city qaqortoq,because of list index out of range
# processing Record 1 of Set 605 | hambantota
# no data available for city hambantota,because of list index out of range
# processing Record 1 of Set 605 | sitka
# no data available for city sitka,because of list index out of range
# processing Record 1 of Set 605 | palu
# no data available for city palu,because of list index out of range
# processing Record 1 of Set 605 | airai
# no data available for city airai,because of list index out of range
# processing Record 1 of Set 605 | yar-sale
# no data available for city yar-sale,because of list index out of range
# processing Record 1 of Set 605 | tuktoyaktuk
# no data available for city tuktoyaktuk,because of list index out of range
# processing Record 1 of Set 605 | east stroudsburg
# no data available for city east stroudsburg,because of list index out of range
# processing Record 1 of Set 605 | new norfolk
# no data available for city new norfolk,because of list index out of range
# processing Record 1 of Set 605 | balkhash
# no data available for city balkhash,because of list index out of range
# processing Record 1 of Set 605 | pochutla
# no data available for city pochutla,because of list index out of range
# processing Record 1 of Set 605 | sentyabrskiy
# no data available for city sentyabrskiy,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | concepcion
# no data available for city concepcion,because of list index out of range
# processing Record 1 of Set 605 | santa lucia
# no data available for city santa lucia,because of list index out of range
# processing Record 1 of Set 605 | georgetown
# no data available for city georgetown,because of list index out of range
# processing Record 1 of Set 605 | nabire
# no data available for city nabire,because of list index out of range
# processing Record 1 of Set 605 | basco
# no data available for city basco,because of list index out of range
# processing Record 1 of Set 605 | wanaka
# no data available for city wanaka,because of list index out of range
# processing Record 1 of Set 605 | piacabucu
# no data available for city piacabucu,because of list index out of range
# processing Record 1 of Set 605 | salacgriva
# no data available for city salacgriva,because of list index out of range
# processing Record 1 of Set 605 | port elizabeth
# no data available for city port elizabeth,because of list index out of range
# processing Record 1 of Set 605 | saint-philippe
# no data available for city saint-philippe,because of list index out of range
# processing Record 1 of Set 605 | sinkat
# no data available for city sinkat,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | bengkulu
# no data available for city bengkulu,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | kaabong
# no data available for city kaabong,because of list index out of range
# processing Record 1 of Set 605 | kawhia
# no data available for city kawhia,because of list index out of range
# processing Record 1 of Set 605 | pandan
# no data available for city pandan,because of list index out of range
# processing Record 1 of Set 605 | te anau
# no data available for city te anau,because of list index out of range
# processing Record 1 of Set 605 | kysyl-syr
# no data available for city kysyl-syr,because of list index out of range
# processing Record 1 of Set 605 | araouane
# no data available for city araouane,because of list index out of range
# processing Record 1 of Set 605 | amot
# no data available for city amot,because of list index out of range
# processing Record 1 of Set 605 | jabiru
# no data available for city jabiru,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | sahuaripa
# no data available for city sahuaripa,because of list index out of range
# processing Record 1 of Set 605 | salinopolis
# no data available for city salinopolis,because of list index out of range
# processing Record 1 of Set 605 | corvallis
# no data available for city corvallis,because of list index out of range
# processing Record 1 of Set 605 | valjala
# no data available for city valjala,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | paamiut
# no data available for city paamiut,because of list index out of range
# processing Record 1 of Set 605 | sobolevo
# no data available for city sobolevo,because of list index out of range
# processing Record 1 of Set 605 | ambilobe
# no data available for city ambilobe,because of list index out of range
# processing Record 1 of Set 605 | iracoubo
# no data available for city iracoubo,because of list index out of range
# processing Record 1 of Set 605 | mingaora
# no data available for city mingaora,because of list index out of range
# processing Record 1 of Set 605 | qaanaaq
# no data available for city qaanaaq,because of list index out of range
# processing Record 1 of Set 605 | nishihara
# no data available for city nishihara,because of list index out of range
# processing Record 1 of Set 605 | grand gaube
# no data available for city grand gaube,because of list index out of range
# processing Record 1 of Set 605 | la ronge
# no data available for city la ronge,because of list index out of range
# processing Record 1 of Set 605 | sioux lookout
# no data available for city sioux lookout,because of list index out of range
# processing Record 1 of Set 605 | kachikau
# no data available for city kachikau,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | stavanger
# no data available for city stavanger,because of list index out of range
# processing Record 1 of Set 605 | neepawa
# no data available for city neepawa,because of list index out of range
# processing Record 1 of Set 605 | jibou
# no data available for city jibou,because of list index out of range
# processing Record 1 of Set 605 | yulara
# no data available for city yulara,because of list index out of range
# processing Record 1 of Set 605 | cairns
# no data available for city cairns,because of list index out of range
# processing Record 1 of Set 605 | noumea
# no data available for city noumea,because of list index out of range
# processing Record 1 of Set 605 | walvis bay
# no data available for city walvis bay,because of list index out of range
# processing Record 1 of Set 605 | beringovskiy
# no data available for city beringovskiy,because of list index out of range
# processing Record 1 of Set 605 | hammerfest
# no data available for city hammerfest,because of list index out of range
# processing Record 1 of Set 605 | moree
# no data available for city moree,because of list index out of range
# processing Record 1 of Set 605 | salalah
# no data available for city salalah,because of list index out of range
# processing Record 1 of Set 605 | imbituba
# no data available for city imbituba,because of list index out of range
# processing Record 1 of Set 605 | taraz
# no data available for city taraz,because of list index out of range
# processing Record 1 of Set 605 | zhuozhou
# no data available for city zhuozhou,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | cherskiy
# no data available for city cherskiy,because of list index out of range
# processing Record 1 of Set 605 | novita
# no data available for city novita,because of list index out of range
# processing Record 1 of Set 605 | buritis
# no data available for city buritis,because of list index out of range
# processing Record 1 of Set 605 | jashpurnagar
# no data available for city jashpurnagar,because of list index out of range
# processing Record 1 of Set 605 | campo maior
# no data available for city campo maior,because of list index out of range
# processing Record 1 of Set 605 | saint-augustin
# no data available for city saint-augustin,because of list index out of range
# processing Record 1 of Set 605 | bontang
# no data available for city bontang,because of list index out of range
# processing Record 1 of Set 605 | tual
# no data available for city tual,because of list index out of range
# processing Record 1 of Set 605 | provideniya
# no data available for city provideniya,because of list index out of range
# processing Record 1 of Set 605 | padang
# no data available for city padang,because of list index out of range
# processing Record 1 of Set 605 | bluefields
# no data available for city bluefields,because of list index out of range
# processing Record 1 of Set 605 | sambava
# no data available for city sambava,because of list index out of range
# processing Record 1 of Set 605 | maraba
# no data available for city maraba,because of list index out of range
# processing Record 1 of Set 605 | namatanai
# no data available for city namatanai,because of list index out of range
# processing Record 1 of Set 605 | luorong
# no data available for city luorong,because of list index out of range
# processing Record 1 of Set 605 | elat
# no data available for city elat,because of list index out of range
# processing Record 1 of Set 605 | rocha
# no data available for city rocha,because of list index out of range
# processing Record 1 of Set 605 | tambun
# no data available for city tambun,because of list index out of range
# processing Record 1 of Set 605 | balikpapan
# no data available for city balikpapan,because of list index out of range
# processing Record 1 of Set 605 | mancheral
# no data available for city mancheral,because of list index out of range
# processing Record 1 of Set 605 | belogorsk
# no data available for city belogorsk,because of list index out of range
# processing Record 1 of Set 605 | vao
# no data available for city vao,because of list index out of range
# processing Record 1 of Set 605 | husavik
# no data available for city husavik,because of list index out of range
# processing Record 1 of Set 605 | college
# no data available for city college,because of list index out of range
# processing Record 1 of Set 605 | laguna
# no data available for city laguna,because of list index out of range
# processing Record 1 of Set 605 | lensk
# no data available for city lensk,because of list index out of range
# processing Record 1 of Set 605 | kazanskaya
# no data available for city kazanskaya,because of list index out of range
# processing Record 1 of Set 605 | xixiang
# no data available for city xixiang,because of list index out of range
# processing Record 1 of Set 605 | catamarca
# no data available for city catamarca,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | parabel
# no data available for city parabel,because of list index out of range
# processing Record 1 of Set 605 | fairbanks
# no data available for city fairbanks,because of list index out of range
# processing Record 1 of Set 605 | kahului
# no data available for city kahului,because of list index out of range
# processing Record 1 of Set 605 | ornskoldsvik
# no data available for city ornskoldsvik,because of list index out of range
# processing Record 1 of Set 605 | gizo
# no data available for city gizo,because of list index out of range
# processing Record 1 of Set 605 | dolbeau
# no data available for city dolbeau,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | codrington
# no data available for city codrington,because of list index out of range
# processing Record 1 of Set 605 | dingle
# no data available for city dingle,because of list index out of range
# processing Record 1 of Set 605 | sao jose da coroa grande
# no data available for city sao jose da coroa grande,because of list index out of range
# processing Record 1 of Set 605 | kant
# no data available for city kant,because of list index out of range
# processing Record 1 of Set 605 | sechura
# no data available for city sechura,because of list index out of range
# processing Record 1 of Set 605 | hamilton
# no data available for city hamilton,because of list index out of range
# processing Record 1 of Set 605 | bethel
# no data available for city bethel,because of list index out of range
# processing Record 1 of Set 605 | antofagasta
# no data available for city antofagasta,because of list index out of range
# processing Record 1 of Set 605 | torbay
# no data available for city torbay,because of list index out of range
# processing Record 1 of Set 605 | dikson
# no data available for city dikson,because of list index out of range
# processing Record 1 of Set 605 | constantine
# no data available for city constantine,because of list index out of range
# processing Record 1 of Set 605 | felanitx
# no data available for city felanitx,because of list index out of range
# processing Record 1 of Set 605 | usinsk
# no data available for city usinsk,because of list index out of range
# processing Record 1 of Set 605 | zyryanka
# no data available for city zyryanka,because of list index out of range
# processing Record 1 of Set 605 | tiverton
# no data available for city tiverton,because of list index out of range
# processing Record 1 of Set 605 | malakal
# no data available for city malakal,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | tarko-sale
# no data available for city tarko-sale,because of list index out of range
# processing Record 1 of Set 605 | jam sahib
# no data available for city jam sahib,because of list index out of range
# processing Record 1 of Set 605 | kijang
# no data available for city kijang,because of list index out of range
# processing Record 1 of Set 605 | karpuninskiy
# no data available for city karpuninskiy,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | yola
# no data available for city yola,because of list index out of range
# processing Record 1 of Set 605 | deming
# no data available for city deming,because of list index out of range
# processing Record 1 of Set 605 | abiy adi
# no data available for city abiy adi,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | gladstone
# no data available for city gladstone,because of list index out of range
# processing Record 1 of Set 605 | gotsu
# no data available for city gotsu,because of list index out of range
# processing Record 1 of Set 605 | comodoro rivadavia
# no data available for city comodoro rivadavia,because of list index out of range
# processing Record 1 of Set 605 | farragut
# no data available for city farragut,because of list index out of range
# processing Record 1 of Set 605 | nova ushytsya
# no data available for city nova ushytsya,because of list index out of range
# processing Record 1 of Set 605 | sabang
# no data available for city sabang,because of list index out of range
# processing Record 1 of Set 605 | ormara
# no data available for city ormara,because of list index out of range
# processing Record 1 of Set 605 | hualmay
# no data available for city hualmay,because of list index out of range
# processing Record 1 of Set 605 | kruisfontein
# no data available for city kruisfontein,because of list index out of range
# processing Record 1 of Set 605 | taltal
# no data available for city taltal,because of list index out of range
# processing Record 1 of Set 605 | naze
# no data available for city naze,because of list index out of range
# processing Record 1 of Set 605 | palabuhanratu
# no data available for city palabuhanratu,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | huangchuan
# no data available for city huangchuan,because of list index out of range
# processing Record 1 of Set 605 | karakendzha
# no data available for city karakendzha,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | galesong
# no data available for city galesong,because of list index out of range
# processing Record 1 of Set 605 | milingimbi
# no data available for city milingimbi,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | road town
# no data available for city road town,because of list index out of range
# processing Record 1 of Set 605 | faro
# no data available for city faro,because of list index out of range
# processing Record 1 of Set 605 | piracanjuba
# no data available for city piracanjuba,because of list index out of range
# processing Record 1 of Set 605 | north bend
# no data available for city north bend,because of list index out of range
# processing Record 1 of Set 605 | blagoyevo
# no data available for city blagoyevo,because of list index out of range
# processing Record 1 of Set 605 | mandera
# no data available for city mandera,because of list index out of range
# processing Record 1 of Set 605 | fortuna
# no data available for city fortuna,because of list index out of range
# processing Record 1 of Set 605 | kidal
# no data available for city kidal,because of list index out of range
# processing Record 1 of Set 605 | bonnyville
# no data available for city bonnyville,because of list index out of range
# processing Record 1 of Set 605 | shimoda
# no data available for city shimoda,because of list index out of range
# processing Record 1 of Set 605 | anadyr
# no data available for city anadyr,because of list index out of range
# processing Record 1 of Set 605 | aurillac
# no data available for city aurillac,because of list index out of range
# processing Record 1 of Set 605 | chabahar
# no data available for city chabahar,because of list index out of range
# processing Record 1 of Set 605 | luena
# no data available for city luena,because of list index out of range
# processing Record 1 of Set 605 | nouadhibou
# no data available for city nouadhibou,because of list index out of range
# processing Record 1 of Set 605 | aksu
# no data available for city aksu,because of list index out of range
# processing Record 1 of Set 605 | fernandina beach
# no data available for city fernandina beach,because of list index out of range
# processing Record 1 of Set 605 | hay river
# no data available for city hay river,because of list index out of range
# processing Record 1 of Set 605 | mareeba
# no data available for city mareeba,because of list index out of range
# processing Record 1 of Set 605 | portobelo
# no data available for city portobelo,because of list index out of range
# processing Record 1 of Set 605 | sarankhola
# no data available for city sarankhola,because of list index out of range
# processing Record 1 of Set 605 | shihezi
# no data available for city shihezi,because of list index out of range
# processing Record 1 of Set 605 | grindavik
# no data available for city grindavik,because of list index out of range
# processing Record 1 of Set 605 | canakkale
# no data available for city canakkale,because of list index out of range
# processing Record 1 of Set 605 | madimba
# no data available for city madimba,because of list index out of range
# processing Record 1 of Set 605 | george town
# no data available for city george town,because of list index out of range
# processing Record 1 of Set 605 | palivere
# no data available for city palivere,because of list index out of range
# processing Record 1 of Set 605 | farafangana
# no data available for city farafangana,because of list index out of range
# processing Record 1 of Set 605 | baijiantan
# no data available for city baijiantan,because of list index out of range
# processing Record 1 of Set 605 | guerrero negro
# no data available for city guerrero negro,because of list index out of range
# processing Record 1 of Set 605 | komsomolskiy
# no data available for city komsomolskiy,because of list index out of range
# processing Record 1 of Set 605 | seoul
# no data available for city seoul,because of list index out of range
# processing Record 1 of Set 605 | nyurba
# no data available for city nyurba,because of list index out of range
# processing Record 1 of Set 605 | vaitupu
# no data available for city vaitupu,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | iqaluit
# no data available for city iqaluit,because of list index out of range
# processing Record 1 of Set 605 | whitehorse
# no data available for city whitehorse,because of list index out of range
# processing Record 1 of Set 605 | celarevo
# no data available for city celarevo,because of list index out of range
# processing Record 1 of Set 605 | safaga
# no data available for city safaga,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | poum
# no data available for city poum,because of list index out of range
# processing Record 1 of Set 605 | shingu
# no data available for city shingu,because of list index out of range
# processing Record 1 of Set 605 | curanilahue
# no data available for city curanilahue,because of list index out of range
# processing Record 1 of Set 605 | korla
# no data available for city korla,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | makakilo city
# no data available for city makakilo city,because of list index out of range
# processing Record 1 of Set 605 | igunga
# no data available for city igunga,because of list index out of range
# processing Record 1 of Set 605 | impfondo
# no data available for city impfondo,because of list index out of range
# processing Record 1 of Set 605 | kurilsk
# no data available for city kurilsk,because of list index out of range
# processing Record 1 of Set 605 | sakakah
# no data available for city sakakah,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | marcona
# no data available for city marcona,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | kiunga
# no data available for city kiunga,because of list index out of range
# processing Record 1 of Set 605 | iranshahr
# no data available for city iranshahr,because of list index out of range
# processing Record 1 of Set 605 | barentsburg
# no data available for city barentsburg,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | badiraguato
# no data available for city badiraguato,because of list index out of range
# processing Record 1 of Set 605 | caiaponia
# no data available for city caiaponia,because of list index out of range
# processing Record 1 of Set 605 | tilichiki
# no data available for city tilichiki,because of list index out of range
# processing Record 1 of Set 605 | tiarei
# no data available for city tiarei,because of list index out of range
# processing Record 1 of Set 605 | portland
# no data available for city portland,because of list index out of range
# processing Record 1 of Set 605 | verkhnyaya inta
# no data available for city verkhnyaya inta,because of list index out of range
# processing Record 1 of Set 605 | praia da vitoria
# no data available for city praia da vitoria,because of list index out of range
# processing Record 1 of Set 605 | tabou
# no data available for city tabou,because of list index out of range
# processing Record 1 of Set 605 | parras
# no data available for city parras,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | koupela
# no data available for city koupela,because of list index out of range
# processing Record 1 of Set 605 | brae
# no data available for city brae,because of list index out of range
# processing Record 1 of Set 605 | otane
# no data available for city otane,because of list index out of range
# processing Record 1 of Set 605 | zharkent
# no data available for city zharkent,because of list index out of range
# processing Record 1 of Set 605 | manjacaze
# no data available for city manjacaze,because of list index out of range
# processing Record 1 of Set 605 | bodden town
# no data available for city bodden town,because of list index out of range
# processing Record 1 of Set 605 | rio grande
# no data available for city rio grande,because of list index out of range
# processing Record 1 of Set 605 | sindou
# no data available for city sindou,because of list index out of range
# processing Record 1 of Set 605 | lata
# no data available for city lata,because of list index out of range
# processing Record 1 of Set 605 | klerksdorp
# no data available for city klerksdorp,because of list index out of range
# processing Record 1 of Set 605 | bowen
# no data available for city bowen,because of list index out of range
# processing Record 1 of Set 605 | san jose
# no data available for city san jose,because of list index out of range
# processing Record 1 of Set 605 | luocheng
# no data available for city luocheng,because of list index out of range
# processing Record 1 of Set 605 | chokurdakh
# no data available for city chokurdakh,because of list index out of range
# processing Record 1 of Set 605 | marfino
# no data available for city marfino,because of list index out of range
# processing Record 1 of Set 605 | narasannapeta
# no data available for city narasannapeta,because of list index out of range
# processing Record 1 of Set 605 | san borja
# no data available for city san borja,because of list index out of range
# processing Record 1 of Set 605 | faya
# no data available for city faya,because of list index out of range
# processing Record 1 of Set 605 | brainerd
# no data available for city brainerd,because of list index out of range
# processing Record 1 of Set 605 | lakselv
# no data available for city lakselv,because of list index out of range
# processing Record 1 of Set 605 | upata
# no data available for city upata,because of list index out of range
# processing Record 1 of Set 605 | chatellerault
# no data available for city chatellerault,because of list index out of range
# processing Record 1 of Set 605 | kempele
# no data available for city kempele,because of list index out of range
# processing Record 1 of Set 605 | laramie
# no data available for city laramie,because of list index out of range
# processing Record 1 of Set 605 | coihaique
# no data available for city coihaique,because of list index out of range
# processing Record 1 of Set 605 | bolshoy tsaryn
# no data available for city bolshoy tsaryn,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | sisimiut
# no data available for city sisimiut,because of list index out of range
# processing Record 1 of Set 605 | vestmannaeyjar
# no data available for city vestmannaeyjar,because of list index out of range
# processing Record 1 of Set 605 | camabatela
# no data available for city camabatela,because of list index out of range
# processing Record 1 of Set 605 | namibe
# no data available for city namibe,because of list index out of range
# processing Record 1 of Set 605 | mao
# no data available for city mao,because of list index out of range
# processing Record 1 of Set 605 | tessalit
# no data available for city tessalit,because of list index out of range
# processing Record 1 of Set 605 | basoko
# no data available for city basoko,because of list index out of range
# processing Record 1 of Set 605 | luderitz
# no data available for city luderitz,because of list index out of range
# processing Record 1 of Set 605 | jalu
# no data available for city jalu,because of list index out of range
# processing Record 1 of Set 605 | atasu
# no data available for city atasu,because of list index out of range
# processing Record 1 of Set 605 | conde
# no data available for city conde,because of list index out of range
# processing Record 1 of Set 605 | arraias
# no data available for city arraias,because of list index out of range
# processing Record 1 of Set 605 | omboue
# ...
# processing Record 1 of Set 605 | vilhena
# no data available for city vilhena,because of list index out of range
# processing Record 1 of Set 605 | yining
# no data available for city yining,because of list index out of range
# processing Record 1 of Set 605 | naftah
# no data available for city naftah,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | shellbrook
# no data available for city shellbrook,because of list index out of range
# processing Record 1 of Set 605 | cubara
# no data available for city cubara,because of list index out of range
# processing Record 1 of Set 605 | caucaia
# no data available for city caucaia,because of list index out of range
# processing Record 1 of Set 605 | klaksvik
# no data available for city klaksvik,because of list index out of range
# processing Record 1 of Set 605 | agadir
# no data available for city agadir,because of list index out of range
# processing Record 1 of Set 605 | nanortalik
# no data available for city nanortalik,because of list index out of range
# processing Record 1 of Set 605 | amga
# no data available for city amga,because of list index out of range
# processing Record 1 of Set 605 | oranjestad
# no data available for city oranjestad,because of list index out of range
# processing Record 1 of Set 605 | san vicente
# no data available for city san vicente,because of list index out of range
# processing Record 1 of Set 605 | wamba
# no data available for city wamba,because of list index out of range
# processing Record 1 of Set 605 | iberia
# no data available for city iberia,because of list index out of range
# processing Record 1 of Set 605 | acarau
# no data available for city acarau,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | lompoc
# no data available for city lompoc,because of list index out of range
# processing Record 1 of Set 605 | rabak
# no data available for city rabak,because of list index out of range
# processing Record 1 of Set 605 | magistralnyy
# no data available for city magistralnyy,because of list index out of range
# processing Record 1 of Set 605 | sorvag
# no data available for city sorvag,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | hukuntsi
# no data available for city hukuntsi,because of list index out of range
# processing Record 1 of Set 605 | kavali
# no data available for city kavali,because of list index out of range
# processing Record 1 of Set 605 | lamu
# no data available for city lamu,because of list index out of range
# processing Record 1 of Set 605 | rensvik
# no data available for city rensvik,because of list index out of range
# processing Record 1 of Set 605 | rio gallegos
# no data available for city rio gallegos,because of list index out of range
# processing Record 1 of Set 605 | akyab
# no data available for city akyab,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | casper
# no data available for city casper,because of list index out of range
# processing Record 1 of Set 605 | fort nelson
# no data available for city fort nelson,because of list index out of range
# processing Record 1 of Set 605 | tidore
# no data available for city tidore,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | gilgit
# no data available for city gilgit,because of list index out of range
# processing Record 1 of Set 605 | susanville
# no data available for city susanville,because of list index out of range
# processing Record 1 of Set 605 | dawlatabad
# no data available for city dawlatabad,because of list index out of range
# processing Record 1 of Set 605 | cazaje
# no data available for city cazaje,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | taybad
# no data available for city taybad,because of list index out of range
# processing Record 1 of Set 605 | likasi
# no data available for city likasi,because of list index out of range
# processing Record 1 of Set 605 | zhigansk
# no data available for city zhigansk,because of list index out of range
# processing Record 1 of Set 605 | egvekinot
# no data available for city egvekinot,because of list index out of range
# processing Record 1 of Set 605 | saint-georges
# no data available for city saint-georges,because of list index out of range
# processing Record 1 of Set 605 | marovoay
# no data available for city marovoay,because of list index out of range
# processing Record 1 of Set 605 | huarmey
# no data available for city huarmey,because of list index out of range
# processing Record 1 of Set 605 | biak
# no data available for city biak,because of list index out of range
# processing Record 1 of Set 605 | konibodom
# no data available for city konibodom,because of list index out of range
# processing Record 1 of Set 605 | port hedland
# no data available for city port hedland,because of list index out of range
# processing Record 1 of Set 605 | acari
# no data available for city acari,because of list index out of range
# processing Record 1 of Set 605 | harper
# no data available for city harper,because of list index out of range
# processing Record 1 of Set 605 | balclutha
# no data available for city balclutha,because of list index out of range
# processing Record 1 of Set 605 | pinheiro
# no data available for city pinheiro,because of list index out of range
# processing Record 1 of Set 605 | diglur
# no data available for city diglur,because of list index out of range
# processing Record 1 of Set 605 | ojinaga
# no data available for city ojinaga,because of list index out of range
# processing Record 1 of Set 605 | soyo
# no data available for city soyo,because of list index out of range
# processing Record 1 of Set 605 | sombrio
# no data available for city sombrio,because of list index out of range
# processing Record 1 of Set 605 | vanavara
# no data available for city vanavara,because of list index out of range
# processing Record 1 of Set 605 | atambua
# no data available for city atambua,because of list index out of range
# processing Record 1 of Set 605 | baykit
# no data available for city baykit,because of list index out of range
# processing Record 1 of Set 605 | botwood
# no data available for city botwood,because of list index out of range
# processing Record 1 of Set 605 | key west
# no data available for city key west,because of list index out of range
# processing Record 1 of Set 605 | guajara-mirim
# no data available for city guajara-mirim,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | cody
# no data available for city cody,because of list index out of range
# processing Record 1 of Set 605 | khania
# no data available for city khania,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | belmonte
# no data available for city belmonte,because of list index out of range
# processing Record 1 of Set 605 | fremont
# no data available for city fremont,because of list index out of range
# processing Record 1 of Set 605 | marawi
# no data available for city marawi,because of list index out of range
# processing Record 1 of Set 605 | hami
# no data available for city hami,because of list index out of range
# processing Record 1 of Set 605 | santa cruz de tenerife
# no data available for city santa cruz de tenerife,because of list index out of range
# processing Record 1 of Set 605 | umzimvubu
# no data available for city umzimvubu,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | jumla
# no data available for city jumla,because of list index out of range
# processing Record 1 of Set 605 | san andres
# no data available for city san andres,because of list index out of range
# processing Record 1 of Set 605 | vostok
# no data available for city vostok,because of list index out of range
# processing Record 1 of Set 605 | cockburn town
# no data available for city cockburn town,because of list index out of range
# processing Record 1 of Set 605 | kathu
# no data available for city kathu,because of list index out of range
# processing Record 1 of Set 605 | arlit
# no data available for city arlit,because of list index out of range
# processing Record 1 of Set 605 | peniche
# no data available for city peniche,because of list index out of range
# processing Record 1 of Set 605 | san policarpo
# no data available for city san policarpo,because of list index out of range
# processing Record 1 of Set 605 | chuchkovo
# no data available for city chuchkovo,because of list index out of range
# processing Record 1 of Set 605 | griffith
# no data available for city griffith,because of list index out of range
# processing Record 1 of Set 605 | nam tha
# no data available for city nam tha,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | waddan
# no data available for city waddan,because of list index out of range
# processing Record 1 of Set 605 | baherden
# no data available for city baherden,because of list index out of range
# processing Record 1 of Set 605 | kailua
# no data available for city kailua,because of list index out of range
# processing Record 1 of Set 605 | puerto colombia
# no data available for city puerto colombia,because of list index out of range
# processing Record 1 of Set 605 | yunyang
# no data available for city yunyang,because of list index out of range
# processing Record 1 of Set 605 | mrirt
# no data available for city mrirt,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | bruck an der leitha
# no data available for city bruck an der leitha,because of list index out of range
# processing Record 1 of Set 605 | manacapuru
# no data available for city manacapuru,because of list index out of range
# processing Record 1 of Set 605 | kadarkut
# no data available for city kadarkut,because of list index out of range
# processing Record 1 of Set 605 | nguiu
# no data available for city nguiu,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | evensk
# no data available for city evensk,because of list index out of range
# processing Record 1 of Set 605 | agboville
# no data available for city agboville,because of list index out of range
# processing Record 1 of Set 605 | hervey bay
# no data available for city hervey bay,because of list index out of range
# processing Record 1 of Set 605 | antalaha
# no data available for city antalaha,because of list index out of range
# processing Record 1 of Set 605 | santa isabel do rio negro
# no data available for city santa isabel do rio negro,because of list index out of range
# processing Record 1 of Set 605 | inobulan
# no data available for city inobulan,because of list index out of range
# processing Record 1 of Set 605 | deer lake
# no data available for city deer lake,because of list index out of range
# processing Record 1 of Set 605 | wulanhaote
# no data available for city wulanhaote,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | diego de almagro
# no data available for city diego de almagro,because of list index out of range
# processing Record 1 of Set 605 | cotonou
# no data available for city cotonou,because of list index out of range
# processing Record 1 of Set 605 | verkhnevilyuysk
# no data available for city verkhnevilyuysk,because of list index out of range
# processing Record 1 of Set 605 | carballo
# no data available for city carballo,because of list index out of range
# processing Record 1 of Set 605 | andenes
# no data available for city andenes,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | puerto escondido
# no data available for city puerto escondido,because of list index out of range
# processing Record 1 of Set 605 | kushima
# no data available for city kushima,because of list index out of range
# processing Record 1 of Set 605 | kalininskaya
# no data available for city kalininskaya,because of list index out of range
# processing Record 1 of Set 605 | mana
# no data available for city mana,because of list index out of range
# processing Record 1 of Set 605 | calama
# no data available for city calama,because of list index out of range
# processing Record 1 of Set 605 | fare
# no data available for city fare,because of list index out of range
# processing Record 1 of Set 605 | bagepalli
# no data available for city bagepalli,because of list index out of range
# processing Record 1 of Set 605 | tabiauea
# no data available for city tabiauea,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | orapa
# no data available for city orapa,because of list index out of range
# processing Record 1 of Set 605 | high level
# no data available for city high level,because of list index out of range
# processing Record 1 of Set 605 | korogwe
# no data available for city korogwe,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | zhigalovo
# no data available for city zhigalovo,because of list index out of range
# processing Record 1 of Set 605 | miyako
# no data available for city miyako,because of list index out of range
# processing Record 1 of Set 605 | awbari
# no data available for city awbari,because of list index out of range
# processing Record 1 of Set 605 | chapleau
# no data available for city chapleau,because of list index out of range
# processing Record 1 of Set 605 | tome-acu
# no data available for city tome-acu,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | nantucket
# no data available for city nantucket,because of list index out of range
# processing Record 1 of Set 605 | acajutla
# no data available for city acajutla,because of list index out of range
# processing Record 1 of Set 605 | lazarev
# no data available for city lazarev,because of list index out of range
# processing Record 1 of Set 605 | takoradi
# no data available for city takoradi,because of list index out of range
# processing Record 1 of Set 605 | lake station
# no data available for city lake station,because of list index out of range
# processing Record 1 of Set 605 | honiara
# no data available for city honiara,because of list index out of range
# processing Record 1 of Set 605 | dunedin
# no data available for city dunedin,because of list index out of range
# processing Record 1 of Set 605 | medicine hat
# no data available for city medicine hat,because of list index out of range
# processing Record 1 of Set 605 | along
# no data available for city along,because of list index out of range
# processing Record 1 of Set 605 | denizli
# no data available for city denizli,because of list index out of range
# processing Record 1 of Set 605 | bolungarvik
# no data available for city bolungarvik,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | waterloo
# no data available for city waterloo,because of list index out of range
# processing Record 1 of Set 605 | pinega
# no data available for city pinega,because of list index out of range
# processing Record 1 of Set 605 | russell
# no data available for city russell,because of list index out of range
# processing Record 1 of Set 605 | kutum
# no data available for city kutum,because of list index out of range
# processing Record 1 of Set 605 | george
# no data available for city george,because of list index out of range
# processing Record 1 of Set 605 | bengkalis
# no data available for city bengkalis,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | bani
# no data available for city bani,because of list index out of range
# processing Record 1 of Set 605 | nakhon si thammarat
# no data available for city nakhon si thammarat,because of list index out of range
# processing Record 1 of Set 605 | caravelas
# no data available for city caravelas,because of list index out of range
# processing Record 1 of Set 605 | boda
# no data available for city boda,because of list index out of range
# processing Record 1 of Set 605 | lolua
# no data available for city lolua,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | leh
# no data available for city leh,because of list index out of range
# processing Record 1 of Set 605 | urdzhar
# no data available for city urdzhar,because of HTTP Error 404: Not Found
# processing Record 1 of Set 605 | sao joao da barra
# no data available for city sao joao da barra,because of list index out of range
# processing Record 1 of Set 605 | mafeteng
# no data available for city mafeteng,because of list index out of range
# processing Record 1 of Set 605 | youhao
# no data available for city youhao,because of list index out of range

# %%
weather_py.count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-23e58044a7fc> in <module>
# ----> 1 weather_py.count()
#
# TypeError: count() takes exactly one argument (0 given)

# %%
#Pandas can read unix epoch time, use unit parameter

pd.to_datetime('1562120045', unit = 's')

#Timestamp('2017-12-20 06:56:40')
#Timestamp
# Out:
# Timestamp('2019-07-03 02:14:05')

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# build a dataframe from the cities, lon,and pressure lists


city_data = {"city": cit, 
                "Cloudiness": cloudiness, 
                "Country": country, 
                "Date": date, 
                "Humidity": humidity, 
                "Latitude": lat, 
                "Lng": lon, 
                "Max Temp": temp_max,  
                "Wind Speed": speed, 
                "Temperature": temp
            }
city_data = pd.DataFrame(city_data)
city_data

# %%
city_data.count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-be7f5f6416d6> in <module>
# ----> 1 city_data.count()
#
# AttributeError: 'dict' object has no attribute 'count'

# %%
# Save as a csv  OK
# Note to avoid any issues later, use encoding="utf-8"
weather_data.to_csv("weatherpy.csv", encoding="utf-8", index=False)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
 # Build a scatter plot for each data type
plt.scatter(city_data["Max Temp"], city_data["Latitude"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max Temp"+"(F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude vs Max Temperature.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(city_data["Humidity"], city_data["Latitude"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity" +"(%)")
plt.xlabel("Latitude")
plt.grid(True)

# Set the y-limits of the current axes to 100 Fahrenheit

ylim=(0, 100)

# Save the figure
plt.savefig("Latitude vs Humidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_data["Cloudiness"], city_data["Latitude"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness ")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

# Set the y-limits of the current axes to 100 Fahrenheit

xlim=(-80,100)
ylim=(0, 100)


# Save the figure
plt.savefig("City Latitude vs Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_data["Wind Speed"], city_data["Latitude"], marker="o")

# Incorporate the other graph properties
plt.title("Wind Speed (mph) vs. Latitude")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Wind Speed vs Latitude.png")

# Show plot
plt.show()

# %%
 # Build a scatter plot for each data type
plt.scatter(city_data["Temperature"], city_data["Latitude"], marker="o")

# Incorporate the other graph properties
plt.title("Temperature (F) vs. Latitude")
plt.ylabel("Latitude")
plt.xlabel("Temperature")
plt.grid(True)

# Save the figure
plt.savefig("Temperature vrs Latitude.png")

# Show plot
plt.show()

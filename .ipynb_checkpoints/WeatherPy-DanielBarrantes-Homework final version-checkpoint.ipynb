# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from requests.exceptions import HTTPError
import openweathermapy.core as owm
import time
import datetime

# Import API key
from config2 import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

#api_key

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities ok
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 633

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# %%
# Build partial query URL OK
query_url = f"{url}appid={api_key}&units={units}&q="
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q='

# %%
# Getting weather data by city
settings = {"units": "imperial", "appid": api_key}
total_cities = len(cities)
weather_data = []
lat=[]
lon=[]
temp=[]
cit=[]
temp_max=[]
humidity=[]
wind=[]
date=[]
cloudiness=[]
country=[]
count=1

print('Processing Data Retrieval')
print('-----------------------------')


for city in cities:
   print(f"processing Record {count} of Set {total_cities} | " + city )
   try:
       weather_data = [owm.get_current(city, **settings)]
       lat.append(weather_data[0]["coord"]["lat"])
       lon.append(weather_data[0]["coord"]["lon"])
       temp.append(weather_data[0]["main"]["temp"])
       cit.append(weather_data[0]["name"])
       humidity.append(weather_data[0]["main"]["humidity"])
       temp_max.append(weather_data[0]["main"]["temp_max"])
       country.append(weather_data[0]["sys"]["country"])
       cloudiness.append(weather_data[0]["clouds"]["all"])
       date.append(weather_data[0]["dt"])
       wind.append(weather_data[0]["wind"]["speed"])
       print(query_url + city)   
       
    
       count=count + 1
   except Exception as e:
               print(f"no data available for city {city},because of {e}")
               #del cities[count-1]
# Out:
# Processing Data Retrieval
# -----------------------------
# processing Record 1 of Set 633 | loubomo
# no data available for city loubomo,because of HTTP Error 404: Not Found
# processing Record 1 of Set 633 | taolanaro
# no data available for city taolanaro,because of HTTP Error 404: Not Found
# processing Record 1 of Set 633 | tiksi
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=tiksi
# processing Record 2 of Set 633 | castro
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=castro
# processing Record 3 of Set 633 | beloha
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=beloha
# processing Record 4 of Set 633 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=puerto ayora
# processing Record 5 of Set 633 | kattivakkam
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=kattivakkam
# processing Record 6 of Set 633 | rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=rikitea
# processing Record 7 of Set 633 | warqla
# no data available for city warqla,because of HTTP Error 404: Not Found
# processing Record 7 of Set 633 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=ushuaia
# processing Record 8 of Set 633 | ostersund
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=ostersund
# processing Record 9 of Set 633 | road town
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=road town
# processing Record 10 of Set 633 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=mahebourg
# processing Record 11 of Set 633 | vung tau
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=vung tau
# processing Record 12 of Set 633 | varnavino
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=varnavino
# processing Record 13 of Set 633 | tevriz
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=tevriz
# processing Record 14 of Set 633 | vaini
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=vaini
# processing Record 15 of Set 633 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=nouadhibou
# processing Record 16 of Set 633 | mataura
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=mataura
# processing Record 17 of Set 633 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=port elizabeth
# processing Record 18 of Set 633 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=tuatapere
# processing Record 19 of Set 633 | obo
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=obo
# processing Record 20 of Set 633 | albany
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=albany
# processing Record 21 of Set 633 | bluff
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=bluff
# processing Record 22 of Set 633 | conceicao do araguaia
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=conceicao do araguaia
# processing Record 23 of Set 633 | feijo
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=feijo
# processing Record 24 of Set 633 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=qaanaaq
# processing Record 25 of Set 633 | raudeberg
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=raudeberg
# processing Record 26 of Set 633 | havoysund
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=havoysund
# processing Record 27 of Set 633 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=ribeira grande
# processing Record 28 of Set 633 | san luis
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=san luis
# processing Record 29 of Set 633 | ginda
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=ginda
# processing Record 30 of Set 633 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=yellowknife
# processing Record 31 of Set 633 | bengkulu
# no data available for city bengkulu,because of HTTP Error 404: Not Found
# processing Record 31 of Set 633 | barrow
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=barrow
# processing Record 32 of Set 633 | cape town
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=cape town
# processing Record 33 of Set 633 | pevek
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=pevek
# processing Record 34 of Set 633 | leirvik
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=leirvik
# processing Record 35 of Set 633 | kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=kapaa
# processing Record 36 of Set 633 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=new norfolk
# processing Record 37 of Set 633 | busselton
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=busselton
# processing Record 38 of Set 633 | jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=jamestown
# processing Record 39 of Set 633 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=mar del plata
# processing Record 40 of Set 633 | narsaq
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=narsaq
# processing Record 41 of Set 633 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=fairbanks
# processing Record 42 of Set 633 | saldanha
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=saldanha
# processing Record 43 of Set 633 | hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=hermanus
# processing Record 44 of Set 633 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=iqaluit
# processing Record 45 of Set 633 | itarema
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=itarema
# processing Record 46 of Set 633 | constitucion
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=constitucion
# processing Record 47 of Set 633 | avarua
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=avarua
# processing Record 48 of Set 633 | flagstaff
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=flagstaff
# processing Record 49 of Set 633 | mount isa
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=mount isa
# processing Record 50 of Set 633 | hofn
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=hofn
# processing Record 51 of Set 633 | lamar
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=lamar
# processing Record 52 of Set 633 | codrington
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=codrington
# processing Record 53 of Set 633 | boa vista
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=boa vista
# processing Record 54 of Set 633 | provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=provideniya
# processing Record 55 of Set 633 | longlac
# no data available for city longlac,because of HTTP Error 404: Not Found
# processing Record 55 of Set 633 | havelock
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=havelock
# processing Record 56 of Set 633 | cururupu
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=cururupu
# processing Record 57 of Set 633 | norman wells
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=norman wells
# processing Record 58 of Set 633 | teguise
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=teguise
# processing Record 59 of Set 633 | ushtobe
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=ushtobe
# processing Record 60 of Set 633 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=nanortalik
# processing Record 61 of Set 633 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=leningradskiy
# processing Record 62 of Set 633 | myitkyina
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=myitkyina
# processing Record 63 of Set 633 | fort nelson
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=fort nelson
# processing Record 64 of Set 633 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=bredasdorp
# processing Record 65 of Set 633 | buala
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=buala
# processing Record 66 of Set 633 | ellisras
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=ellisras
# processing Record 67 of Set 633 | khuzhir
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=khuzhir
# processing Record 68 of Set 633 | illoqqortoormiut
# no data available for city illoqqortoormiut,because of HTTP Error 404: Not Found
# processing Record 68 of Set 633 | waipawa
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=waipawa
# processing Record 69 of Set 633 | sorvag
# no data available for city sorvag,because of HTTP Error 404: Not Found
# processing Record 69 of Set 633 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=severo-kurilsk
# processing Record 70 of Set 633 | korla
# no data available for city korla,because of HTTP Error 404: Not Found
# processing Record 70 of Set 633 | hasaki
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=hasaki
# processing Record 71 of Set 633 | hoi an
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=hoi an
# processing Record 72 of Set 633 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=vila franca do campo
# processing Record 73 of Set 633 | aswan
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=aswan
# processing Record 74 of Set 633 | sar-e pul
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=sar-e pul
# processing Record 75 of Set 633 | port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=port alfred
# processing Record 76 of Set 633 | baicheng
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=baicheng
# processing Record 77 of Set 633 | shingu
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=shingu
# processing Record 78 of Set 633 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=lavrentiya
# processing Record 79 of Set 633 | salvador
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=salvador
# processing Record 80 of Set 633 | flinders
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=flinders
# processing Record 81 of Set 633 | hirara
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=hirara
# processing Record 82 of Set 633 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=longyearbyen
# processing Record 83 of Set 633 | pouebo
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=pouebo
# processing Record 84 of Set 633 | saint george
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=saint george
# processing Record 85 of Set 633 | chenzhou
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=chenzhou
# processing Record 86 of Set 633 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=punta arenas
# processing Record 87 of Set 633 | sorland
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=sorland
# processing Record 88 of Set 633 | atuona
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=atuona
# processing Record 89 of Set 633 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=arraial do cabo
# processing Record 90 of Set 633 | neiafu
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=neiafu
# processing Record 91 of Set 633 | tsihombe
# no data available for city tsihombe,because of HTTP Error 404: Not Found
# processing Record 91 of Set 633 | faanui
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=faanui
# processing Record 92 of Set 633 | van
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=van
# processing Record 93 of Set 633 | khonuu
# no data available for city khonuu,because of HTTP Error 404: Not Found
# processing Record 93 of Set 633 | dunedin
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=dunedin
# processing Record 94 of Set 633 | jiddah
# no data available for city jiddah,because of HTTP Error 404: Not Found
# processing Record 94 of Set 633 | tefe
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=tefe
# processing Record 95 of Set 633 | hobart
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=hobart
# processing Record 96 of Set 633 | saiha
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=saiha
# processing Record 97 of Set 633 | port blair
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=port blair
# processing Record 98 of Set 633 | dwarka
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=dwarka
# processing Record 99 of Set 633 | turinsk
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=turinsk
# processing Record 100 of Set 633 | belushya guba
# no data available for city belushya guba,because of HTTP Error 404: Not Found
# processing Record 100 of Set 633 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=sao filipe
# processing Record 101 of Set 633 | georgiyevka
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=georgiyevka
# processing Record 102 of Set 633 | hilo
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=hilo
# processing Record 103 of Set 633 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=saskylakh
# processing Record 104 of Set 633 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=saint-philippe
# processing Record 105 of Set 633 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=pangnirtung
# processing Record 106 of Set 633 | san miguel
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=san miguel
# processing Record 107 of Set 633 | marcona
# no data available for city marcona,because of HTTP Error 404: Not Found
# processing Record 107 of Set 633 | urucara
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=urucara
# processing Record 108 of Set 633 | chuy
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=chuy
# processing Record 109 of Set 633 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=taoudenni
# processing Record 110 of Set 633 | cayenne
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=cayenne
# processing Record 111 of Set 633 | airai
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=airai
# processing Record 112 of Set 633 | concepcion
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=concepcion
# processing Record 113 of Set 633 | tanout
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=tanout
# processing Record 114 of Set 633 | umm kaddadah
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=umm kaddadah
# processing Record 115 of Set 633 | poplar bluff
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=poplar bluff
# processing Record 116 of Set 633 | petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=petropavlovsk-kamchatskiy
# processing Record 117 of Set 633 | berdigestyakh
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=berdigestyakh
# processing Record 118 of Set 633 | victoria
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=victoria
# processing Record 119 of Set 633 | braganca
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=braganca
# processing Record 120 of Set 633 | east london
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=east london
# processing Record 121 of Set 633 | opuwo
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=opuwo
# processing Record 122 of Set 633 | georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=georgetown
# processing Record 123 of Set 633 | muriti
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=muriti
# processing Record 124 of Set 633 | clyde river
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=clyde river
# processing Record 125 of Set 633 | bethel
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=bethel
# processing Record 126 of Set 633 | havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=havre-saint-pierre
# processing Record 127 of Set 633 | saint-augustin
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=saint-augustin
# processing Record 128 of Set 633 | satitoa
# no data available for city satitoa,because of HTTP Error 404: Not Found
# processing Record 128 of Set 633 | marawi
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=marawi
# processing Record 129 of Set 633 | rio grande
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=rio grande
# processing Record 130 of Set 633 | nepomuceno
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=nepomuceno
# processing Record 131 of Set 633 | bolshoy tsaryn
# no data available for city bolshoy tsaryn,because of HTTP Error 404: Not Found
# processing Record 131 of Set 633 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=bambous virieux
# processing Record 132 of Set 633 | minot
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=minot
# processing Record 133 of Set 633 | attawapiskat
# no data available for city attawapiskat,because of HTTP Error 404: Not Found
# processing Record 133 of Set 633 | silver city
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=silver city
# processing Record 134 of Set 633 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=carnarvon
# processing Record 135 of Set 633 | nelspruit
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=nelspruit
# processing Record 136 of Set 633 | lorengau
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=lorengau
# processing Record 137 of Set 633 | broome
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=broome
# processing Record 138 of Set 633 | luderitz
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=luderitz
# processing Record 139 of Set 633 | baykit
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=baykit
# processing Record 140 of Set 633 | dong hoi
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=dong hoi
# processing Record 141 of Set 633 | brownsville
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=brownsville
# processing Record 142 of Set 633 | xuddur
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=xuddur
# processing Record 143 of Set 633 | amderma
# no data available for city amderma,because of HTTP Error 404: Not Found
# processing Record 143 of Set 633 | saint-francois
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=saint-francois
# processing Record 144 of Set 633 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=tuktoyaktuk
# processing Record 145 of Set 633 | oriximina
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=oriximina
# processing Record 146 of Set 633 | rocha
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=rocha
# processing Record 147 of Set 633 | cocobeach
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=cocobeach
# processing Record 148 of Set 633 | ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=ugoofaaru
# processing Record 149 of Set 633 | san juan nepomuceno
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=san juan nepomuceno
# processing Record 150 of Set 633 | dingle
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=dingle
# processing Record 151 of Set 633 | atherton
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=atherton
# processing Record 152 of Set 633 | henties bay
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=henties bay
# processing Record 153 of Set 633 | hay river
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=hay river
# processing Record 154 of Set 633 | hvide sande
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=hvide sande
# processing Record 155 of Set 633 | huazolotitlan
# no data available for city huazolotitlan,because of HTTP Error 404: Not Found
# processing Record 155 of Set 633 | zalari
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=zalari
# processing Record 156 of Set 633 | khash
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=khash
# processing Record 157 of Set 633 | pitimbu
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=pitimbu
# processing Record 158 of Set 633 | kieta
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=kieta
# processing Record 159 of Set 633 | antofagasta
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=antofagasta
# processing Record 160 of Set 633 | kashan
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=kashan
# processing Record 161 of Set 633 | moranbah
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=moranbah
# processing Record 162 of Set 633 | moissala
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=moissala
# processing Record 163 of Set 633 | agirish
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=agirish
# processing Record 164 of Set 633 | puqi
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=puqi
# processing Record 165 of Set 633 | jacareacanga
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=jacareacanga
# processing Record 166 of Set 633 | abu samrah
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=abu samrah
# processing Record 167 of Set 633 | kathmandu
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=kathmandu
# processing Record 168 of Set 633 | nabire
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=nabire
# processing Record 169 of Set 633 | yazykovo
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=yazykovo
# processing Record 170 of Set 633 | kuito
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=kuito
# processing Record 171 of Set 633 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=beringovskiy
# processing Record 172 of Set 633 | uniao da victoria
# no data available for city uniao da victoria,because of HTTP Error 404: Not Found
# processing Record 172 of Set 633 | linxia
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=linxia
# processing Record 173 of Set 633 | omboue
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=omboue
# processing Record 174 of Set 633 | kemijarvi
# no data available for city kemijarvi,because of HTTP Error 404: Not Found
# processing Record 174 of Set 633 | turukhansk
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=turukhansk
# processing Record 175 of Set 633 | abinsk
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=abinsk
# processing Record 176 of Set 633 | chicama
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=chicama
# processing Record 177 of Set 633 | castanos
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=castanos
# processing Record 178 of Set 633 | torbay
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=torbay
# processing Record 179 of Set 633 | burnie
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=burnie
# processing Record 180 of Set 633 | ayagoz
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=ayagoz
# processing Record 181 of Set 633 | bhadasar
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=bhadasar
# processing Record 182 of Set 633 | mys shmidta
# no data available for city mys shmidta,because of HTTP Error 404: Not Found
# processing Record 182 of Set 633 | lebu
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=lebu
# processing Record 183 of Set 633 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=port lincoln
# processing Record 184 of Set 633 | yomitan
# no data available for city yomitan,because of HTTP Error 404: Not Found
# processing Record 184 of Set 633 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=hithadhoo
# processing Record 185 of Set 633 | amecameca
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=amecameca
# processing Record 186 of Set 633 | phan rang
# no data available for city phan rang,because of HTTP Error 404: Not Found
# processing Record 186 of Set 633 | mansa
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=mansa
# processing Record 187 of Set 633 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=tasiilaq
# processing Record 188 of Set 633 | la gaulette
# no data available for city la gaulette,because of HTTP Error 404: Not Found
# processing Record 188 of Set 633 | ozgon
# no data available for city ozgon,because of HTTP Error 404: Not Found
# processing Record 188 of Set 633 | balabac
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=balabac
# processing Record 189 of Set 633 | portland
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=portland
# processing Record 190 of Set 633 | faya
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=faya
# processing Record 191 of Set 633 | sao gabriel da cachoeira
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=sao gabriel da cachoeira
# processing Record 192 of Set 633 | viransehir
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=viransehir
# processing Record 193 of Set 633 | rawannawi
# no data available for city rawannawi,because of HTTP Error 404: Not Found
# processing Record 193 of Set 633 | la roda
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=la roda
# processing Record 194 of Set 633 | la macarena
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=la macarena
# processing Record 195 of Set 633 | kankaanpaa
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=kankaanpaa
# processing Record 196 of Set 633 | grenville
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=grenville
# processing Record 197 of Set 633 | susice
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=susice
# processing Record 198 of Set 633 | samusu
# no data available for city samusu,because of HTTP Error 404: Not Found
# processing Record 198 of Set 633 | betsiamites
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=betsiamites
# processing Record 199 of Set 633 | fukue
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=fukue
# processing Record 200 of Set 633 | linqiong
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=linqiong
# processing Record 201 of Set 633 | sakakah
# no data available for city sakakah,because of HTTP Error 404: Not Found
# processing Record 201 of Set 633 | geraldton
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=geraldton
# processing Record 202 of Set 633 | okha
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=okha
# processing Record 203 of Set 633 | shchors
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=shchors
# processing Record 204 of Set 633 | sobolevo
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=sobolevo
# processing Record 205 of Set 633 | hocaba
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=hocaba
# processing Record 206 of Set 633 | anamur
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=anamur
# processing Record 207 of Set 633 | pafos
# no data available for city pafos,because of HTTP Error 404: Not Found
# processing Record 207 of Set 633 | port hardy
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=port hardy
# processing Record 208 of Set 633 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=kaitangata
# processing Record 209 of Set 633 | maniitsoq
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=maniitsoq
# processing Record 210 of Set 633 | nyurba
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=nyurba
# processing Record 211 of Set 633 | southbridge
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=southbridge
# processing Record 212 of Set 633 | lata
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=lata
# processing Record 213 of Set 633 | caravelas
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=caravelas
# processing Record 214 of Set 633 | sura
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=sura
# processing Record 215 of Set 633 | sitka
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=sitka
# processing Record 216 of Set 633 | lompoc
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=lompoc
# processing Record 217 of Set 633 | kesova gora
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=kesova gora
# processing Record 218 of Set 633 | shuangcheng
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=shuangcheng
# processing Record 219 of Set 633 | bontang
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=bontang
# processing Record 220 of Set 633 | shivrajpur
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=shivrajpur
# processing Record 221 of Set 633 | tabiauea
# no data available for city tabiauea,because of HTTP Error 404: Not Found
# processing Record 221 of Set 633 | ancud
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=ancud
# processing Record 222 of Set 633 | lagoa
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=lagoa
# processing Record 223 of Set 633 | uyuni
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=uyuni
# processing Record 224 of Set 633 | lithakia
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=lithakia
# processing Record 225 of Set 633 | aklavik
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=aklavik
# processing Record 226 of Set 633 | tilichiki
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=tilichiki
# processing Record 227 of Set 633 | merauke
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=merauke
# processing Record 228 of Set 633 | ondjiva
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=ondjiva
# processing Record 229 of Set 633 | nizhneyansk
# no data available for city nizhneyansk,because of HTTP Error 404: Not Found
# processing Record 229 of Set 633 | dikson
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=dikson
# processing Record 230 of Set 633 | souillac
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=souillac
# processing Record 231 of Set 633 | wahiawa
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=wahiawa
# processing Record 232 of Set 633 | butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=butaritari
# processing Record 233 of Set 633 | buraydah
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=buraydah
# processing Record 234 of Set 633 | paita
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=paita
# processing Record 235 of Set 633 | kununurra
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=kununurra
# processing Record 236 of Set 633 | nizhniy kuranakh
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=nizhniy kuranakh
# processing Record 237 of Set 633 | yulara
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=yulara
# processing Record 238 of Set 633 | olafsvik
# no data available for city olafsvik,because of HTTP Error 404: Not Found
# processing Record 238 of Set 633 | abonnema
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=abonnema
# processing Record 239 of Set 633 | sao jose da coroa grande
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=sao jose da coroa grande
# processing Record 240 of Set 633 | merritt island
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=merritt island
# processing Record 241 of Set 633 | shimoda
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=shimoda
# processing Record 242 of Set 633 | keuruu
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=keuruu
# processing Record 243 of Set 633 | at-bashi
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=at-bashi
# processing Record 244 of Set 633 | karamea
# no data available for city karamea,because of HTTP Error 404: Not Found
# processing Record 244 of Set 633 | isangel
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=isangel
# processing Record 245 of Set 633 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=yar-sale
# processing Record 246 of Set 633 | tateyama
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=tateyama
# processing Record 247 of Set 633 | necochea
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=necochea
# processing Record 248 of Set 633 | atbasar
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=atbasar
# processing Record 249 of Set 633 | mayo
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=mayo
# processing Record 250 of Set 633 | tautira
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=tautira
# processing Record 251 of Set 633 | madhoganj
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=madhoganj
# processing Record 252 of Set 633 | celestun
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=celestun
# processing Record 253 of Set 633 | balashikha
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=balashikha
# processing Record 254 of Set 633 | vicuna
# no data available for city vicuna,because of HTTP Error 404: Not Found
# processing Record 254 of Set 633 | mastic beach
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=mastic beach
# processing Record 255 of Set 633 | duyun
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=duyun
# processing Record 256 of Set 633 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=pacific grove
# processing Record 257 of Set 633 | kirovskaya
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=kirovskaya
# processing Record 258 of Set 633 | newtonmore
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=newtonmore
# processing Record 259 of Set 633 | mehamn
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=mehamn
# processing Record 260 of Set 633 | goderich
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=goderich
# processing Record 261 of Set 633 | bilma
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=bilma
# processing Record 262 of Set 633 | puerto escondido
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=puerto escondido
# processing Record 263 of Set 633 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=guerrero negro
# processing Record 264 of Set 633 | karaul
# no data available for city karaul,because of HTTP Error 404: Not Found
# processing Record 264 of Set 633 | katherine
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=katherine
# processing Record 265 of Set 633 | thompson
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=thompson
# processing Record 266 of Set 633 | panaba
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=panaba
# processing Record 267 of Set 633 | graaff-reinet
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=graaff-reinet
# processing Record 268 of Set 633 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=mount gambier
# processing Record 269 of Set 633 | ubinskoye
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=ubinskoye
# processing Record 270 of Set 633 | bonthe
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=bonthe
# processing Record 271 of Set 633 | batagay
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=batagay
# processing Record 272 of Set 633 | ayan
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=ayan
# processing Record 273 of Set 633 | hualmay
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=hualmay
# processing Record 274 of Set 633 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=oranjemund
# processing Record 275 of Set 633 | mounana
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=mounana
# processing Record 276 of Set 633 | caborca
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=caborca
# processing Record 277 of Set 633 | hatillo
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=hatillo
# processing Record 278 of Set 633 | bodden town
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=bodden town
# processing Record 279 of Set 633 | borovoy
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=borovoy
# processing Record 280 of Set 633 | tarboro
# ...
# processing Record 467 of Set 633 | vilhena
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=vilhena
# processing Record 468 of Set 633 | acaponeta
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=acaponeta
# processing Record 469 of Set 633 | parvatsar
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=parvatsar
# processing Record 470 of Set 633 | vestmanna
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=vestmanna
# processing Record 471 of Set 633 | kamenka
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=kamenka
# processing Record 472 of Set 633 | tual
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=tual
# processing Record 473 of Set 633 | hobyo
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=hobyo
# processing Record 474 of Set 633 | bourail
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=bourail
# processing Record 475 of Set 633 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=los llanos de aridane
# processing Record 476 of Set 633 | haines junction
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=haines junction
# processing Record 477 of Set 633 | rundu
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=rundu
# processing Record 478 of Set 633 | shubarshi
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=shubarshi
# processing Record 479 of Set 633 | port hedland
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=port hedland
# processing Record 480 of Set 633 | pangody
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=pangody
# processing Record 481 of Set 633 | tarime
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=tarime
# processing Record 482 of Set 633 | cabedelo
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=cabedelo
# processing Record 483 of Set 633 | huarmey
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=huarmey
# processing Record 484 of Set 633 | roebourne
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=roebourne
# processing Record 485 of Set 633 | tres lagoas
# no data available for city tres lagoas,because of HTTP Error 404: Not Found
# processing Record 485 of Set 633 | dalaba
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=dalaba
# processing Record 486 of Set 633 | dalvik
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=dalvik
# processing Record 487 of Set 633 | payo
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=payo
# processing Record 488 of Set 633 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=ponta do sol
# processing Record 489 of Set 633 | prince rupert
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=prince rupert
# processing Record 490 of Set 633 | ararat
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=ararat
# processing Record 491 of Set 633 | hanzhong
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=hanzhong
# processing Record 492 of Set 633 | chifeng
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=chifeng
# processing Record 493 of Set 633 | dibaya
# no data available for city dibaya,because of HTTP Error 404: Not Found
# processing Record 493 of Set 633 | thinadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=thinadhoo
# processing Record 494 of Set 633 | mergui
# no data available for city mergui,because of HTTP Error 404: Not Found
# processing Record 494 of Set 633 | wajima
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=wajima
# processing Record 495 of Set 633 | tawang
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=tawang
# processing Record 496 of Set 633 | san quintin
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=san quintin
# processing Record 497 of Set 633 | nalut
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=nalut
# processing Record 498 of Set 633 | rongcheng
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=rongcheng
# processing Record 499 of Set 633 | flin flon
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=flin flon
# processing Record 500 of Set 633 | bara
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=bara
# processing Record 501 of Set 633 | victoria point
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=victoria point
# processing Record 502 of Set 633 | komatsu
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=komatsu
# processing Record 503 of Set 633 | lae
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=lae
# processing Record 504 of Set 633 | grand river south east
# no data available for city grand river south east,because of HTTP Error 404: Not Found
# processing Record 504 of Set 633 | zyryanka
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=zyryanka
# processing Record 505 of Set 633 | olinda
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=olinda
# processing Record 506 of Set 633 | nome
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=nome
# processing Record 507 of Set 633 | kirakira
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=kirakira
# processing Record 508 of Set 633 | kavieng
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=kavieng
# processing Record 509 of Set 633 | zyryanskoye
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=zyryanskoye
# processing Record 510 of Set 633 | jiuquan
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=jiuquan
# processing Record 511 of Set 633 | gorom-gorom
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=gorom-gorom
# processing Record 512 of Set 633 | aksarka
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=aksarka
# processing Record 513 of Set 633 | filimonovo
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=filimonovo
# processing Record 514 of Set 633 | jamsa
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=jamsa
# processing Record 515 of Set 633 | zverinogolovskoye
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=zverinogolovskoye
# processing Record 516 of Set 633 | wewak
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=wewak
# processing Record 517 of Set 633 | maltahohe
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=maltahohe
# processing Record 518 of Set 633 | aitape
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=aitape
# processing Record 519 of Set 633 | myskhako
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=myskhako
# processing Record 520 of Set 633 | yershov
# no data available for city yershov,because of HTTP Error 404: Not Found
# processing Record 520 of Set 633 | kralendijk
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=kralendijk
# processing Record 521 of Set 633 | lucea
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=lucea
# processing Record 522 of Set 633 | isiolo
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=isiolo
# processing Record 523 of Set 633 | nakapiripirit
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=nakapiripirit
# processing Record 524 of Set 633 | ulladulla
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=ulladulla
# processing Record 525 of Set 633 | garm
# no data available for city garm,because of HTTP Error 404: Not Found
# processing Record 525 of Set 633 | artyom
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=artyom
# processing Record 526 of Set 633 | plessisville
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=plessisville
# processing Record 527 of Set 633 | sampit
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=sampit
# processing Record 528 of Set 633 | svetlaya
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=svetlaya
# processing Record 529 of Set 633 | kamaishi
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=kamaishi
# processing Record 530 of Set 633 | sawtell
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=sawtell
# processing Record 531 of Set 633 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=bandarbeyla
# processing Record 532 of Set 633 | bell ville
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=bell ville
# processing Record 533 of Set 633 | kalianget
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=kalianget
# processing Record 534 of Set 633 | qui nhon
# no data available for city qui nhon,because of HTTP Error 404: Not Found
# processing Record 534 of Set 633 | labutta
# no data available for city labutta,because of HTTP Error 404: Not Found
# processing Record 534 of Set 633 | vitim
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=vitim
# processing Record 535 of Set 633 | asfi
# no data available for city asfi,because of HTTP Error 404: Not Found
# processing Record 535 of Set 633 | tevaitoa
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=tevaitoa
# processing Record 536 of Set 633 | pimenta bueno
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=pimenta bueno
# processing Record 537 of Set 633 | vlagtwedde
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=vlagtwedde
# processing Record 538 of Set 633 | usakos
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=usakos
# processing Record 539 of Set 633 | saint-leu
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=saint-leu
# processing Record 540 of Set 633 | te anau
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=te anau
# processing Record 541 of Set 633 | marsh harbour
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=marsh harbour
# processing Record 542 of Set 633 | labuhan
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=labuhan
# processing Record 543 of Set 633 | tottori
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=tottori
# processing Record 544 of Set 633 | hammond
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=hammond
# processing Record 545 of Set 633 | pedernales
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=pedernales
# processing Record 546 of Set 633 | decatur
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=decatur
# processing Record 547 of Set 633 | nizwa
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=nizwa
# processing Record 548 of Set 633 | sohag
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=sohag
# processing Record 549 of Set 633 | margate
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=margate
# processing Record 550 of Set 633 | yazman
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=yazman
# processing Record 551 of Set 633 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=srednekolymsk
# processing Record 552 of Set 633 | taybad
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=taybad
# processing Record 553 of Set 633 | mana
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=mana
# processing Record 554 of Set 633 | comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=comodoro rivadavia
# processing Record 555 of Set 633 | plettenberg bay
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=plettenberg bay
# processing Record 556 of Set 633 | antakya
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=antakya
# processing Record 557 of Set 633 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=grand gaube
# processing Record 558 of Set 633 | palmer
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=palmer
# processing Record 559 of Set 633 | polunochnoye
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=polunochnoye
# processing Record 560 of Set 633 | tambilil
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=tambilil
# processing Record 561 of Set 633 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=cap malheureux

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data.count()
# Out:
# city           561
# Cloudiness     561
# Country        561
# Date           561
# Humidity       561
# Latitude       561
# Lng            561
# Max Temp       561
# Wind Speed     561
# Temperature    561
# dtype: int64

# %%
# build a dataframe from the cities, lon,and pressure lists


weather_data = {"city": cit, 
               "Cloudiness": cloudiness, 
                "Country": country, 
                "Date": date, 
                "Humidity": humidity, 
                "Latitude": lat, 
                "Lng": lon, 
                "Max Temp": temp_max,  
                "Wind Speed": wind, 
                "Temperature": temp
            }
weather_data = pd.DataFrame(weather_data)
weather_data.head()
# Out:
#            city  Cloudiness Country        Date  Humidity  Latitude     Lng  \
# 0         Tiksi          99      RU  1562644356        77     71.64  128.87
# 1        Castro          90      CL  1562644406       100    -42.48  -73.76
# 2        Beloha           0      MG  1562644406        94    -25.17   45.06
# 3  Puerto Ayora           6      EC  1562644406        96     -0.74  -90.35
# 4   Kattivakkam          40      IN  1562644407        44     13.22   80.32
#
#    Max Temp  Wind Speed  Temperature
# 0     58.59        5.14        58.59
# 1     50.00       14.99        50.00
# 2     58.29        1.30        58.29
# 3     70.00        3.00        70.00
# 4     93.20        9.17        92.05

# %%
# Save as a csv  OK
# Note to avoid any issues later, use encoding="utf-8"
weather_data.to_csv("weatherpy.csv", encoding="utf-8", index=False)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
date = datetime.datetime.now()

# Build a scatter plot for each data type
ax= plt.scatter(weather_data["Latitude"], weather_data["Max Temp"], marker="o",facecolor="blue")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature " + (date.strftime("%x")) )
plt.ylabel("Max Temp"+"(F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Max Temperature vrs Latitude.png")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-97-e9733096681e> in <module>
#      12 plt.xlabel("Latitude")
#      13 plt.grid(True)
# ---> 14 ax.set_title("'dark_background' style sheet")
#      15
#      16 # Save the figure
#
# AttributeError: 'PathCollection' object has no attribute 'set_title'

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data["Latitude"], weather_data["Humidity"], marker="o",facecolor="b")

# Incorporate the other graph properties
plt.title("Humidity (%) vs. Latitude " + (date.strftime("%x")) )
plt.ylabel("Humidity" +"(%)")
plt.xlabel("Latitude")
plt.grid(True)

# Set the y-limits of the current axes to 100 Fahrenheit

ylim=(0, 100)

# Save the figure
plt.savefig("Humidity vs Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data["Latitude"], weather_data["Cloudiness"], marker="o",facecolor="b")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness "+ (date.strftime("%x")) )
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

# Set the y-limits of the current axes to 100 Fahrenheit

xlim=(-80,100)
ylim=(0, 100)


# Save the figure
plt.savefig("Cloudiness vs Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
date = datetime.datetime.now()

plt.scatter(weather_data["Latitude"], weather_data["Wind Speed"], marker="o",facecolor="b")

# Incorporate the other graph properties
plt.title("Wind Speed (mph) vs. Latitude " + (date.strftime("%x")) )
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Wind Speed vs Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from requests.exceptions import HTTPError
import openweathermapy.core as owm
import time

# Import API key
from config2 import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

api_key
# Out:
# '9586ef608bbf0838f9b387e9d8d4b1da'

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities ok
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
cities
# Out:
# ['khatanga',
#  'georgetown',
#  'coahuayana',
#  'lebu',
#  'punta arenas',
#  'choix',
#  'altoona',
#  'jamestown',
#  'kibala',
#  'san rafael',
#  'rikitea',
#  'saint-francois',
#  'taolanaro',
#  'hermanus',
#  'mbigou',
#  'butaritari',
#  'port alfred',
#  'dikson',
#  'mataura',
#  'biryusinsk',
#  'salo',
#  'longyearbyen',
#  'bethel',
#  'ushuaia',
#  'lagoa',
#  'chipata',
#  'illoqqortoormiut',
#  'hay river',
#  'barrow',
#  'cidreira',
#  'constitucion',
#  'nuuk',
#  'atuona',
#  'amderma',
#  'albany',
#  'appiano',
#  'minab',
#  'saint stephen',
#  'san cristobal',
#  'kodiak',
#  'atbasar',
#  'arraial do cabo',
#  'chokurdakh',
#  'attawapiskat',
#  'bengkulu',
#  'sobolevo',
#  'fairbanks',
#  'puerto ayora',
#  'toliary',
#  'aden',
#  'haines junction',
#  'egvekinot',
#  'marystown',
#  'general cepeda',
#  'port-cartier',
#  'vaini',
#  'saint-philippe',
#  'awjilah',
#  'vallenar',
#  'kruisfontein',
#  'kapaa',
#  'ribeira grande',
#  'samusu',
#  'kalmunai',
#  'muros',
#  'port elizabeth',
#  'bluff',
#  'victoria',
#  'codrington',
#  'nizhneyansk',
#  'isangel',
#  'yellowknife',
#  'tasiilaq',
#  'narsaq',
#  'bambanglipuro',
#  'vao',
#  'purranque',
#  'sur',
#  'kadykchan',
#  'alvaraes',
#  'clyde river',
#  'inhambane',
#  'moyale',
#  'hobart',
#  'feijo',
#  'cristalina',
#  'avarua',
#  'busselton',
#  'grand river south east',
#  'arlit',
#  'vetlanda',
#  'jalu',
#  'ilulissat',
#  'chuy',
#  'seara',
#  'warmbad',
#  'kaseda',
#  'tiznit',
#  'marrakesh',
#  'hamilton',
#  'huicheng',
#  'petrolandia',
#  'geraldton',
#  'nizhniy odes',
#  'matli',
#  'cayhagan',
#  'tuatapere',
#  'vaitupu',
#  'kuah',
#  'viedma',
#  'mount gambier',
#  'east london',
#  'grand gaube',
#  'cape town',
#  'salalah',
#  'tandalti',
#  'pangody',
#  'sidrolandia',
#  'thompson',
#  'freeport',
#  'saint george',
#  'hithadhoo',
#  'saint anthony',
#  'tidore',
#  'qaanaaq',
#  'cabo san lucas',
#  'gollere',
#  'kaitangata',
#  'touros',
#  'lasa',
#  'adrar',
#  'aklavik',
#  'hami',
#  'aflu',
#  'dzhida',
#  'spornoye',
#  'ca mau',
#  'diffa',
#  'milkovo',
#  'kahului',
#  'bredasdorp',
#  'carnarvon',
#  'ponta do sol',
#  'lorengau',
#  'fare',
#  'jiexiu',
#  'mar del plata',
#  'ngukurr',
#  'nanortalik',
#  'rampur',
#  'chenzhou',
#  'kiama',
#  'doaba',
#  'ciudad bolivar',
#  'foumban',
#  'nikolskoye',
#  'ugoofaaru',
#  'mahebourg',
#  'devin',
#  'ybycui',
#  'karaul',
#  'itoman',
#  'cayenne',
#  'qaqortoq',
#  'baykit',
#  'achacachi',
#  'talnakh',
#  'minna',
#  'namatanai',
#  'susanville',
#  'airai',
#  'rio gallegos',
#  'yatou',
#  'japura',
#  'eyl',
#  'esperance',
#  'rochester',
#  'new norfolk',
#  'hofn',
#  'tuktoyaktuk',
#  'buraydah',
#  'klaksvik',
#  'bathsheba',
#  'upernavik',
#  'vostok',
#  'luderitz',
#  'zabol',
#  'biak',
#  'samarai',
#  'ocos',
#  'jaroslaw',
#  'grindavik',
#  'palabuhanratu',
#  'orange',
#  'velyka bahachka',
#  'cururupu',
#  'banda aceh',
#  'severo-kurilsk',
#  'kutina',
#  'hasaki',
#  'tingrela',
#  'penzance',
#  'hilo',
#  'taoudenni',
#  'igarka',
#  'tsihombe',
#  'guerrero negro',
#  'flinders',
#  'san patricio',
#  'batabano',
#  'songea',
#  'marzuq',
#  'rundu',
#  'iquique',
#  'norman wells',
#  'belushya guba',
#  'kendari',
#  'mayo',
#  'padang',
#  'leningradskiy',
#  'willowmore',
#  'castro',
#  'husavik',
#  'ahipara',
#  'borama',
#  'kavieng',
#  'maningrida',
#  'morondava',
#  'tigil',
#  'lapeer',
#  'provideniya',
#  'bambous virieux',
#  'tual',
#  'belyy yar',
#  'vawkavysk',
#  'kieta',
#  'nioro',
#  'iquitos',
#  'katobu',
#  'walvis bay',
#  'burica',
#  'saskylakh',
#  'shenzhen',
#  'ushtobe',
#  'berlevag',
#  'tarauaca',
#  'bilma',
#  'mys shmidta',
#  'muttupet',
#  'krasnoborsk',
#  'cherskiy',
#  'opuwo',
#  'roald',
#  'barentsburg',
#  'oistins',
#  'surgut',
#  'laguna',
#  'lazaro cardenas',
#  'trinidad',
#  'torbay',
#  'antofagasta',
#  'chippewa falls',
#  'katsuura',
#  'tiksi',
#  'sao filipe',
#  'paita',
#  'souillac',
#  'pedernales',
#  'rodrigues alves',
#  'penukonda',
#  'mahanje',
#  'huarmey',
#  'tumpat',
#  'forio',
#  'emerald',
#  'acarau',
#  'naze',
#  'alice springs',
#  'asyut',
#  'praya',
#  'el faiyum',
#  'poli',
#  'trairi',
#  'denpasar',
#  'juneau',
#  'lenki',
#  'channel-port aux basques',
#  'houston',
#  'los llanos de aridane',
#  'zhuhai',
#  'hirara',
#  'muncar',
#  'usti nad orlici',
#  'padilla',
#  'iqaluit',
#  'sept-iles',
#  'port blair',
#  'meulaboh',
#  'port lincoln',
#  'seoul',
#  'coffs harbour',
#  'ostrovnoy',
#  'beringovskiy',
#  'sitka',
#  'ritchie',
#  'dingle',
#  'dali',
#  'el tarra',
#  'male',
#  'college',
#  'wattegama',
#  'indramayu',
#  'yurimaguas',
#  'aykhal',
#  'hun',
#  'salinopolis',
#  'shuya',
#  'alofi',
#  'van buren',
#  'blyth',
#  'alexandria',
#  'san luis obispo',
#  'rosa zarate',
#  'sola',
#  'kadhan',
#  'christchurch',
#  'malanje',
#  'lavrentiya',
#  'zhigansk',
#  'galiwinku',
#  'nantucket',
#  'sijunjung',
#  'iberia',
#  'matara',
#  'san vicente',
#  'kletskaya',
#  'vila velha',
#  'carson city',
#  'manali',
#  'kamenskoye',
#  'ust-tsilma',
#  'orchard homes',
#  'sentyabrskiy',
#  'zelenets',
#  'la ronge',
#  'lyambir',
#  'tungkang',
#  'ponta delgada',
#  'sechura',
#  'cabedelo',
#  'olafsvik',
#  'mitu',
#  'saint-andre-les-vergers',
#  'krasnoshchekovo',
#  'catalina',
#  'marshall',
#  'issia',
#  'nara',
#  'ormara',
#  'grootfontein',
#  'thinadhoo',
#  'igis',
#  'sibiti',
#  'bull savanna',
#  'tura',
#  'doctor pedro p. pena',
#  'visnes',
#  'kualakapuas',
#  'poum',
#  'nemuro',
#  'tazovskiy',
#  'tornio',
#  'raudeberg',
#  'tarudant',
#  'mareeba',
#  'vredendal',
#  'udachnyy',
#  'faanui',
#  'leiyang',
#  'chaozhou',
#  'teknaf',
#  'pangnirtung',
#  'porto franco',
#  'pinotepa nacional',
#  'caravelas',
#  'sabaudia',
#  'yaan',
#  'buchanan',
#  'terre-de-bas',
#  'onguday',
#  'boa vista',
#  'general teran',
#  'wahran',
#  'luganville',
#  'adwa',
#  'anju',
#  'londiani',
#  'agadir',
#  'labutta',
#  'qui nhon',
#  'burkhala',
#  'coihaique',
#  'bahir dar',
#  'zhangye',
#  'kushima',
#  'namibe',
#  'jiuquan',
#  'libenge',
#  'meadow lake',
#  'valenca do piaui',
#  'effingham',
#  'musoma',
#  'maniitsoq',
#  'ishigaki',
#  'iraucuba',
#  'madera',
#  'troitsko-pechorsk',
#  'the valley',
#  'paamiut',
#  'voh',
#  'buin',
#  'soyo',
#  'wadhwan',
#  'ancud',
#  'shingu',
#  'rio pardo de minas',
#  'suez',
#  'privolzhye',
#  'deputatskiy',
#  'korla',
#  'ducheng',
#  'krasnomayskiy',
#  'sorland',
#  'mogadishu',
#  'rafraf',
#  'kjollefjord',
#  'victor harbor',
#  'vila franca do campo',
#  'paka',
#  'jiayuguan',
#  'esmeralda',
#  'lujan',
#  'haapiti',
#  'yar-sale',
#  'ignacio de la llave',
#  'bom jesus',
#  'sibolga',
#  'asau',
#  'itarema',
#  'chatrapur',
#  'macduff',
#  'sinnamary',
#  'san andres',
#  'nizhnevartovsk',
#  'mananjary',
#  'banikoara',
#  'hays',
#  'rawannawi',
#  'rorvik',
#  'keetmanshoop',
#  'carutapera',
#  'maceio',
#  'yumen',
#  'grand-santi',
#  'axim',
#  'pitimbu',
#  'zolotinka',
#  'itaituba',
#  'natal',
#  'qitaihe',
#  'hovd',
#  'sasovo',
#  'viligili',
#  'kamenka',
#  'wanning',
#  'okha',
#  'baruun-urt',
#  'marinette',
#  'killybegs',
#  'omsukchan',
#  'broome',
#  'saint-louis',
#  'rio grande',
#  'kuusankoski',
#  'bassila',
#  'half moon bay',
#  'shalakusha',
#  'kudahuvadhoo',
#  'pisco',
#  'najran',
#  'louisbourg',
#  'samalaeulu',
#  'kazalinsk',
#  'petropavlovsk-kamchatskiy',
#  'coquimbo',
#  'dunedin',
#  'winterberg',
#  'brigantine',
#  'mounana',
#  'halalo',
#  'amahai',
#  'shenjiamen',
#  'sabha',
#  'san jose de guanipa',
#  'fortuna',
#  'saldanha',
#  'nagato',
#  'saint-leu',
#  'balkhash',
#  'skegness',
#  'muzhi',
#  'belmonte',
#  'oum hadjer',
#  'skibbereen',
#  'ahuimanu',
#  'gizo',
#  'komsomolskiy',
#  'nome',
#  'port hedland',
#  'victoria point',
#  'corrente',
#  'meyungs',
#  'zyryanka',
#  'santa isabel do rio negro',
#  'termini imerese',
#  'west bay',
#  'marsa matruh',
#  'urusha',
#  'nelson bay',
#  'bogo',
#  'kroya',
#  'beaverlodge',
#  'boguchany',
#  'kuche',
#  'aljezur',
#  'palu',
#  'jacareacanga',
#  'srednekolymsk',
#  'beidao',
#  'bukachacha',
#  'yulara',
#  'cruzilia',
#  'lerwick',
#  'kavaratti',
#  'gerash',
#  'ye',
#  'sohag',
#  'kuhestan',
#  'areosa',
#  'mukono',
#  'vardo',
#  'zachagansk',
#  'punta alta',
#  'abha',
#  'kloulklubed',
#  'umzimvubu',
#  'aiken',
#  'tarnobrzeg',
#  'ginda',
#  'kedougou',
#  'elmira',
#  'ambilobe',
#  'mirnyy',
#  'darhan',
#  'agva',
#  'lakes entrance',
#  'rafaela',
#  'ankang',
#  'dekar',
#  'havelock',
#  'kijang',
#  'lingao',
#  'teluknaga',
#  'oksfjord',
#  'suntar',
#  'kysyl-syr',
#  'slavonice',
#  'othaya',
#  'solovetskiy',
#  'goldap',
#  'jishui',
#  'rodos',
#  'vilhena',
#  'duvan',
#  'tabiauea',
#  'svetlyy',
#  'tasbuget',
#  'krasnoselkup',
#  'akdepe',
#  'camacha',
#  'port victoria',
#  'saint-pierre',
#  'karasburg',
#  'aripuana',
#  'pocatello',
#  'poso',
#  'sioux lookout',
#  'valparaiso',
#  'basco',
#  'wageningen']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information. OK
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# %%
# Build partial query URL OK
query_url = f"{url}appid={api_key}&units={units}&q="
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q='

# %%
settings = {"units": "metric", "appid": api_key}
weather_data = []
lat=[]
lon=[]
temp=[]
cit=[]
temp_max=[]
humidity=[]
wind=[]
date=[]
cloudiness=[]
country=[]

record=1
for city in cities:
   try:
       weather_data = [owm.get_current(city, **settings)]
       lat.append(weather_data[0]["coord"]["lat"])
       lon.append(weather_data[0]["coord"]["lon"])
       temp.append(weather_data[0]["main"]["temp"])
       cit.append(weather_data[0]["name"])
       humidity.append(weather_data[0]["main"]["humidity"])
       temp_max.append(weather_data[0]["main"]["temp_max"])
       country.append(weather_data[0]["sys"]["country"])
       cloudiness.append(weather_data[0]["clouds"]["all"])
       date.append(weather_data[0]["dt"])
       wind.append(weather_data[0]["wind"]["speed"])
       print(f"Processing Record {record} of Set 1 | {city}")
       #pprint(weather_data)
       record=record + 1
   except Exception as e:
               print(f"no Data avaiable for city {city},because of {e}")
# Out:
# Processing Record 1 of Set 1 | khatanga
# Processing Record 2 of Set 1 | georgetown
# Processing Record 3 of Set 1 | coahuayana
# Processing Record 4 of Set 1 | lebu
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | choix
# Processing Record 7 of Set 1 | altoona
# Processing Record 8 of Set 1 | jamestown
# Processing Record 9 of Set 1 | kibala
# Processing Record 10 of Set 1 | san rafael
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | saint-francois
# no Data avaiable for city taolanaro,because of HTTP Error 404: Not Found
# Processing Record 13 of Set 1 | hermanus
# Processing Record 14 of Set 1 | mbigou
# Processing Record 15 of Set 1 | butaritari
# Processing Record 16 of Set 1 | port alfred
# Processing Record 17 of Set 1 | dikson
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | biryusinsk
# Processing Record 20 of Set 1 | salo
# Processing Record 21 of Set 1 | longyearbyen
# Processing Record 22 of Set 1 | bethel
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | lagoa
# Processing Record 25 of Set 1 | chipata
# no Data avaiable for city illoqqortoormiut,because of HTTP Error 404: Not Found
# Processing Record 26 of Set 1 | hay river
# Processing Record 27 of Set 1 | barrow
# Processing Record 28 of Set 1 | cidreira
# Processing Record 29 of Set 1 | constitucion
# Processing Record 30 of Set 1 | nuuk
# Processing Record 31 of Set 1 | atuona
# no Data avaiable for city amderma,because of HTTP Error 404: Not Found
# Processing Record 32 of Set 1 | albany
# no Data avaiable for city appiano,because of HTTP Error 404: Not Found
# Processing Record 33 of Set 1 | minab
# Processing Record 34 of Set 1 | saint stephen
# Processing Record 35 of Set 1 | san cristobal
# Processing Record 36 of Set 1 | kodiak
# Processing Record 37 of Set 1 | atbasar
# Processing Record 38 of Set 1 | arraial do cabo
# Processing Record 39 of Set 1 | chokurdakh
# no Data avaiable for city attawapiskat,because of HTTP Error 404: Not Found
# no Data avaiable for city bengkulu,because of HTTP Error 404: Not Found
# Processing Record 40 of Set 1 | sobolevo
# Processing Record 41 of Set 1 | fairbanks
# Processing Record 42 of Set 1 | puerto ayora
# no Data avaiable for city toliary,because of HTTP Error 404: Not Found
# Processing Record 43 of Set 1 | aden
# Processing Record 44 of Set 1 | haines junction
# Processing Record 45 of Set 1 | egvekinot
# Processing Record 46 of Set 1 | marystown
# Processing Record 47 of Set 1 | general cepeda
# Processing Record 48 of Set 1 | port-cartier
# Processing Record 49 of Set 1 | vaini
# Processing Record 50 of Set 1 | saint-philippe
# Processing Record 51 of Set 1 | awjilah
# Processing Record 52 of Set 1 | vallenar
# Processing Record 53 of Set 1 | kruisfontein
# Processing Record 54 of Set 1 | kapaa
# Processing Record 55 of Set 1 | ribeira grande
# no Data avaiable for city samusu,because of HTTP Error 404: Not Found
# Processing Record 56 of Set 1 | kalmunai
# Processing Record 57 of Set 1 | muros
# Processing Record 58 of Set 1 | port elizabeth
# Processing Record 59 of Set 1 | bluff
# Processing Record 60 of Set 1 | victoria
# Processing Record 61 of Set 1 | codrington
# no Data avaiable for city nizhneyansk,because of HTTP Error 404: Not Found
# Processing Record 62 of Set 1 | isangel
# Processing Record 63 of Set 1 | yellowknife
# Processing Record 64 of Set 1 | tasiilaq
# Processing Record 65 of Set 1 | narsaq
# Processing Record 66 of Set 1 | bambanglipuro
# Processing Record 67 of Set 1 | vao
# Processing Record 68 of Set 1 | purranque
# Processing Record 69 of Set 1 | sur
# no Data avaiable for city kadykchan,because of HTTP Error 404: Not Found
# Processing Record 70 of Set 1 | alvaraes
# Processing Record 71 of Set 1 | clyde river
# Processing Record 72 of Set 1 | inhambane
# Processing Record 73 of Set 1 | moyale
# Processing Record 74 of Set 1 | hobart
# Processing Record 75 of Set 1 | feijo
# Processing Record 76 of Set 1 | cristalina
# Processing Record 77 of Set 1 | avarua
# Processing Record 78 of Set 1 | busselton
# no Data avaiable for city grand river south east,because of HTTP Error 404: Not Found
# Processing Record 79 of Set 1 | arlit
# Processing Record 80 of Set 1 | vetlanda
# Processing Record 81 of Set 1 | jalu
# Processing Record 82 of Set 1 | ilulissat
# Processing Record 83 of Set 1 | chuy
# Processing Record 84 of Set 1 | seara
# Processing Record 85 of Set 1 | warmbad
# Processing Record 86 of Set 1 | kaseda
# Processing Record 87 of Set 1 | tiznit
# Processing Record 88 of Set 1 | marrakesh
# Processing Record 89 of Set 1 | hamilton
# Processing Record 90 of Set 1 | huicheng
# no Data avaiable for city petrolandia,because of HTTP Error 404: Not Found
# Processing Record 91 of Set 1 | geraldton
# Processing Record 92 of Set 1 | nizhniy odes
# Processing Record 93 of Set 1 | matli
# Processing Record 94 of Set 1 | cayhagan
# Processing Record 95 of Set 1 | tuatapere
# no Data avaiable for city vaitupu,because of HTTP Error 404: Not Found
# no Data avaiable for city kuah,because of HTTP Error 404: Not Found
# Processing Record 96 of Set 1 | viedma
# Processing Record 97 of Set 1 | mount gambier
# Processing Record 98 of Set 1 | east london
# Processing Record 99 of Set 1 | grand gaube
# Processing Record 100 of Set 1 | cape town
# Processing Record 101 of Set 1 | salalah
# Processing Record 102 of Set 1 | tandalti
# Processing Record 103 of Set 1 | pangody
# Processing Record 104 of Set 1 | sidrolandia
# Processing Record 105 of Set 1 | thompson
# Processing Record 106 of Set 1 | freeport
# Processing Record 107 of Set 1 | saint george
# Processing Record 108 of Set 1 | hithadhoo
# Processing Record 109 of Set 1 | saint anthony
# no Data avaiable for city tidore,because of HTTP Error 404: Not Found
# Processing Record 110 of Set 1 | qaanaaq
# Processing Record 111 of Set 1 | cabo san lucas
# no Data avaiable for city gollere,because of HTTP Error 404: Not Found
# Processing Record 112 of Set 1 | kaitangata
# Processing Record 113 of Set 1 | touros
# Processing Record 114 of Set 1 | lasa
# Processing Record 115 of Set 1 | adrar
# Processing Record 116 of Set 1 | aklavik
# Processing Record 117 of Set 1 | hami
# no Data avaiable for city aflu,because of HTTP Error 404: Not Found
# Processing Record 118 of Set 1 | dzhida
# Processing Record 119 of Set 1 | spornoye
# Processing Record 120 of Set 1 | ca mau
# Processing Record 121 of Set 1 | diffa
# Processing Record 122 of Set 1 | milkovo
# Processing Record 123 of Set 1 | kahului
# Processing Record 124 of Set 1 | bredasdorp
# Processing Record 125 of Set 1 | carnarvon
# Processing Record 126 of Set 1 | ponta do sol
# Processing Record 127 of Set 1 | lorengau
# Processing Record 128 of Set 1 | fare
# Processing Record 129 of Set 1 | jiexiu
# Processing Record 130 of Set 1 | mar del plata
# no Data avaiable for city ngukurr,because of HTTP Error 404: Not Found
# Processing Record 131 of Set 1 | nanortalik
# Processing Record 132 of Set 1 | rampur
# Processing Record 133 of Set 1 | chenzhou
# Processing Record 134 of Set 1 | kiama
# Processing Record 135 of Set 1 | doaba
# Processing Record 136 of Set 1 | ciudad bolivar
# Processing Record 137 of Set 1 | foumban
# Processing Record 138 of Set 1 | nikolskoye
# Processing Record 139 of Set 1 | ugoofaaru
# Processing Record 140 of Set 1 | mahebourg
# Processing Record 141 of Set 1 | devin
# Processing Record 142 of Set 1 | ybycui
# no Data avaiable for city karaul,because of HTTP Error 404: Not Found
# Processing Record 143 of Set 1 | itoman
# Processing Record 144 of Set 1 | cayenne
# Processing Record 145 of Set 1 | qaqortoq
# Processing Record 146 of Set 1 | baykit
# Processing Record 147 of Set 1 | achacachi
# Processing Record 148 of Set 1 | talnakh
# Processing Record 149 of Set 1 | minna
# Processing Record 150 of Set 1 | namatanai
# Processing Record 151 of Set 1 | susanville
# Processing Record 152 of Set 1 | airai
# Processing Record 153 of Set 1 | rio gallegos
# Processing Record 154 of Set 1 | yatou
# Processing Record 155 of Set 1 | japura
# Processing Record 156 of Set 1 | eyl
# Processing Record 157 of Set 1 | esperance
# Processing Record 158 of Set 1 | rochester
# Processing Record 159 of Set 1 | new norfolk
# Processing Record 160 of Set 1 | hofn
# Processing Record 161 of Set 1 | tuktoyaktuk
# Processing Record 162 of Set 1 | buraydah
# Processing Record 163 of Set 1 | klaksvik
# Processing Record 164 of Set 1 | bathsheba
# Processing Record 165 of Set 1 | upernavik
# Processing Record 166 of Set 1 | vostok
# Processing Record 167 of Set 1 | luderitz
# Processing Record 168 of Set 1 | zabol
# Processing Record 169 of Set 1 | biak
# Processing Record 170 of Set 1 | samarai
# Processing Record 171 of Set 1 | ocos
# Processing Record 172 of Set 1 | jaroslaw
# Processing Record 173 of Set 1 | grindavik
# no Data avaiable for city palabuhanratu,because of HTTP Error 404: Not Found
# Processing Record 174 of Set 1 | orange
# Processing Record 175 of Set 1 | velyka bahachka
# Processing Record 176 of Set 1 | cururupu
# Processing Record 177 of Set 1 | banda aceh
# Processing Record 178 of Set 1 | severo-kurilsk
# Processing Record 179 of Set 1 | kutina
# Processing Record 180 of Set 1 | hasaki
# no Data avaiable for city tingrela,because of HTTP Error 404: Not Found
# Processing Record 181 of Set 1 | penzance
# Processing Record 182 of Set 1 | hilo
# Processing Record 183 of Set 1 | taoudenni
# Processing Record 184 of Set 1 | igarka
# no Data avaiable for city tsihombe,because of HTTP Error 404: Not Found
# Processing Record 185 of Set 1 | guerrero negro
# Processing Record 186 of Set 1 | flinders
# Processing Record 187 of Set 1 | san patricio
# Processing Record 188 of Set 1 | batabano
# Processing Record 189 of Set 1 | songea
# Processing Record 190 of Set 1 | marzuq
# Processing Record 191 of Set 1 | rundu
# Processing Record 192 of Set 1 | iquique
# Processing Record 193 of Set 1 | norman wells
# no Data avaiable for city belushya guba,because of HTTP Error 404: Not Found
# Processing Record 194 of Set 1 | kendari
# Processing Record 195 of Set 1 | mayo
# Processing Record 196 of Set 1 | padang
# Processing Record 197 of Set 1 | leningradskiy
# Processing Record 198 of Set 1 | willowmore
# Processing Record 199 of Set 1 | castro
# Processing Record 200 of Set 1 | husavik
# Processing Record 201 of Set 1 | ahipara
# no Data avaiable for city borama,because of HTTP Error 404: Not Found
# Processing Record 202 of Set 1 | kavieng
# Processing Record 203 of Set 1 | maningrida
# Processing Record 204 of Set 1 | morondava
# Processing Record 205 of Set 1 | tigil
# Processing Record 206 of Set 1 | lapeer
# Processing Record 207 of Set 1 | provideniya
# Processing Record 208 of Set 1 | bambous virieux
# Processing Record 209 of Set 1 | tual
# Processing Record 210 of Set 1 | belyy yar
# Processing Record 211 of Set 1 | vawkavysk
# Processing Record 212 of Set 1 | kieta
# Processing Record 213 of Set 1 | nioro
# Processing Record 214 of Set 1 | iquitos
# Processing Record 215 of Set 1 | katobu
# Processing Record 216 of Set 1 | walvis bay
# no Data avaiable for city burica,because of HTTP Error 404: Not Found
# Processing Record 217 of Set 1 | saskylakh
# Processing Record 218 of Set 1 | shenzhen
# Processing Record 219 of Set 1 | ushtobe
# Processing Record 220 of Set 1 | berlevag
# Processing Record 221 of Set 1 | tarauaca
# Processing Record 222 of Set 1 | bilma
# no Data avaiable for city mys shmidta,because of HTTP Error 404: Not Found
# Processing Record 223 of Set 1 | muttupet
# Processing Record 224 of Set 1 | krasnoborsk
# Processing Record 225 of Set 1 | cherskiy
# Processing Record 226 of Set 1 | opuwo
# Processing Record 227 of Set 1 | roald
# no Data avaiable for city barentsburg,because of HTTP Error 404: Not Found
# Processing Record 228 of Set 1 | oistins
# Processing Record 229 of Set 1 | surgut
# Processing Record 230 of Set 1 | laguna
# Processing Record 231 of Set 1 | lazaro cardenas
# Processing Record 232 of Set 1 | trinidad
# Processing Record 233 of Set 1 | torbay
# Processing Record 234 of Set 1 | antofagasta
# Processing Record 235 of Set 1 | chippewa falls
# Processing Record 236 of Set 1 | katsuura
# Processing Record 237 of Set 1 | tiksi
# Processing Record 238 of Set 1 | sao filipe
# Processing Record 239 of Set 1 | paita
# Processing Record 240 of Set 1 | souillac
# Processing Record 241 of Set 1 | pedernales
# Processing Record 242 of Set 1 | rodrigues alves
# Processing Record 243 of Set 1 | penukonda
# no Data avaiable for city mahanje,because of HTTP Error 404: Not Found
# Processing Record 244 of Set 1 | huarmey
# Processing Record 245 of Set 1 | tumpat
# Processing Record 246 of Set 1 | forio
# Processing Record 247 of Set 1 | emerald
# no Data avaiable for city acarau,because of HTTP Error 404: Not Found
# Processing Record 248 of Set 1 | naze
# Processing Record 249 of Set 1 | alice springs
# Processing Record 250 of Set 1 | asyut
# Processing Record 251 of Set 1 | praya
# no Data avaiable for city el faiyum,because of HTTP Error 404: Not Found
# Processing Record 252 of Set 1 | poli
# Processing Record 253 of Set 1 | trairi
# Processing Record 254 of Set 1 | denpasar
# Processing Record 255 of Set 1 | juneau
# no Data avaiable for city lenki,because of HTTP Error 404: Not Found
# Processing Record 256 of Set 1 | channel-port aux basques
# Processing Record 257 of Set 1 | houston
# Processing Record 258 of Set 1 | los llanos de aridane
# Processing Record 259 of Set 1 | zhuhai
# Processing Record 260 of Set 1 | hirara
# Processing Record 261 of Set 1 | muncar
# Processing Record 262 of Set 1 | usti nad orlici
# Processing Record 263 of Set 1 | padilla
# Processing Record 264 of Set 1 | iqaluit
# Processing Record 265 of Set 1 | sept-iles
# Processing Record 266 of Set 1 | port blair
# Processing Record 267 of Set 1 | meulaboh
# Processing Record 268 of Set 1 | port lincoln
# Processing Record 269 of Set 1 | seoul
# Processing Record 270 of Set 1 | coffs harbour
# Processing Record 271 of Set 1 | ostrovnoy
# Processing Record 272 of Set 1 | beringovskiy
# Processing Record 273 of Set 1 | sitka
# Processing Record 274 of Set 1 | ritchie
# Processing Record 275 of Set 1 | dingle
# Processing Record 276 of Set 1 | dali
# Processing Record 277 of Set 1 | el tarra
# Processing Record 278 of Set 1 | male
# Processing Record 279 of Set 1 | college
# Processing Record 280 of Set 1 | wattegama
# Processing Record 281 of Set 1 | indramayu
# Processing Record 282 of Set 1 | yurimaguas
# Processing Record 283 of Set 1 | aykhal
# Processing Record 284 of Set 1 | hun
# Processing Record 285 of Set 1 | salinopolis
# Processing Record 286 of Set 1 | shuya
# Processing Record 287 of Set 1 | alofi
# Processing Record 288 of Set 1 | van buren
# Processing Record 289 of Set 1 | blyth
# Processing Record 290 of Set 1 | alexandria
# Processing Record 291 of Set 1 | san luis obispo
# Processing Record 292 of Set 1 | rosa zarate
# Processing Record 293 of Set 1 | sola
# Processing Record 294 of Set 1 | kadhan
# Processing Record 295 of Set 1 | christchurch
# Processing Record 296 of Set 1 | malanje
# Processing Record 297 of Set 1 | lavrentiya
# Processing Record 298 of Set 1 | zhigansk
# no Data avaiable for city galiwinku,because of HTTP Error 404: Not Found
# Processing Record 299 of Set 1 | nantucket
# Processing Record 300 of Set 1 | sijunjung
# Processing Record 301 of Set 1 | iberia
# Processing Record 302 of Set 1 | matara
# Processing Record 303 of Set 1 | san vicente
# Processing Record 304 of Set 1 | kletskaya
# Processing Record 305 of Set 1 | vila velha
# Processing Record 306 of Set 1 | carson city
# Processing Record 307 of Set 1 | manali
# no Data avaiable for city kamenskoye,because of HTTP Error 404: Not Found
# Processing Record 308 of Set 1 | ust-tsilma
# Processing Record 309 of Set 1 | orchard homes
# no Data avaiable for city sentyabrskiy,because of HTTP Error 404: Not Found
# Processing Record 310 of Set 1 | zelenets
# Processing Record 311 of Set 1 | la ronge
# Processing Record 312 of Set 1 | lyambir
# no Data avaiable for city tungkang,because of HTTP Error 404: Not Found
# Processing Record 313 of Set 1 | ponta delgada
# Processing Record 314 of Set 1 | sechura
# Processing Record 315 of Set 1 | cabedelo
# no Data avaiable for city olafsvik,because of HTTP Error 404: Not Found
# Processing Record 316 of Set 1 | mitu
# Processing Record 317 of Set 1 | saint-andre-les-vergers
# Processing Record 318 of Set 1 | krasnoshchekovo
# Processing Record 319 of Set 1 | catalina
# Processing Record 320 of Set 1 | marshall
# Processing Record 321 of Set 1 | issia
# Processing Record 322 of Set 1 | nara
# Processing Record 323 of Set 1 | ormara
# Processing Record 324 of Set 1 | grootfontein
# Processing Record 325 of Set 1 | thinadhoo
# Processing Record 326 of Set 1 | igis
# Processing Record 327 of Set 1 | sibiti
# Processing Record 328 of Set 1 | bull savanna
# Processing Record 329 of Set 1 | tura
# no Data avaiable for city doctor pedro p. pena,because of HTTP Error 404: Not Found
# Processing Record 330 of Set 1 | visnes
# Processing Record 331 of Set 1 | kualakapuas
# Processing Record 332 of Set 1 | poum
# Processing Record 333 of Set 1 | nemuro
# Processing Record 334 of Set 1 | tazovskiy
# Processing Record 335 of Set 1 | tornio
# Processing Record 336 of Set 1 | raudeberg
# no Data avaiable for city tarudant,because of HTTP Error 404: Not Found
# Processing Record 337 of Set 1 | mareeba
# Processing Record 338 of Set 1 | vredendal
# Processing Record 339 of Set 1 | udachnyy
# Processing Record 340 of Set 1 | faanui
# Processing Record 341 of Set 1 | leiyang
# Processing Record 342 of Set 1 | chaozhou
# Processing Record 343 of Set 1 | teknaf
# Processing Record 344 of Set 1 | pangnirtung
# Processing Record 345 of Set 1 | porto franco
# no Data avaiable for city pinotepa nacional,because of HTTP Error 404: Not Found
# Processing Record 346 of Set 1 | caravelas
# Processing Record 347 of Set 1 | sabaudia
# Processing Record 348 of Set 1 | yaan
# Processing Record 349 of Set 1 | buchanan
# Processing Record 350 of Set 1 | terre-de-bas
# Processing Record 351 of Set 1 | onguday
# Processing Record 352 of Set 1 | boa vista
# Processing Record 353 of Set 1 | general teran
# no Data avaiable for city wahran,because of HTTP Error 404: Not Found
# Processing Record 354 of Set 1 | luganville
# Processing Record 355 of Set 1 | adwa
# Processing Record 356 of Set 1 | anju
# Processing Record 357 of Set 1 | londiani
# Processing Record 358 of Set 1 | agadir
# no Data avaiable for city labutta,because of HTTP Error 404: Not Found
# no Data avaiable for city qui nhon,because of HTTP Error 404: Not Found
# no Data avaiable for city burkhala,because of HTTP Error 404: Not Found
# Processing Record 359 of Set 1 | coihaique
# Processing Record 360 of Set 1 | bahir dar
# Processing Record 361 of Set 1 | zhangye
# Processing Record 362 of Set 1 | kushima
# Processing Record 363 of Set 1 | namibe
# Processing Record 364 of Set 1 | jiuquan
# Processing Record 365 of Set 1 | libenge
# Processing Record 366 of Set 1 | meadow lake
# Processing Record 367 of Set 1 | valenca do piaui
# Processing Record 368 of Set 1 | effingham
# Processing Record 369 of Set 1 | musoma
# Processing Record 370 of Set 1 | maniitsoq
# Processing Record 371 of Set 1 | ishigaki
# Processing Record 372 of Set 1 | iraucuba
# Processing Record 373 of Set 1 | madera
# Processing Record 374 of Set 1 | troitsko-pechorsk
# Processing Record 375 of Set 1 | the valley
# Processing Record 376 of Set 1 | paamiut
# Processing Record 377 of Set 1 | voh
# Processing Record 378 of Set 1 | buin
# Processing Record 379 of Set 1 | soyo
# no Data avaiable for city wadhwan,because of HTTP Error 404: Not Found
# Processing Record 380 of Set 1 | ancud
# Processing Record 381 of Set 1 | shingu
# Processing Record 382 of Set 1 | rio pardo de minas
# Processing Record 383 of Set 1 | suez
# Processing Record 384 of Set 1 | privolzhye
# Processing Record 385 of Set 1 | deputatskiy
# no Data avaiable for city korla,because of HTTP Error 404: Not Found
# Processing Record 386 of Set 1 | ducheng
# Processing Record 387 of Set 1 | krasnomayskiy
# Processing Record 388 of Set 1 | sorland
# Processing Record 389 of Set 1 | mogadishu
# Processing Record 390 of Set 1 | rafraf
# Processing Record 391 of Set 1 | kjollefjord
# Processing Record 392 of Set 1 | victor harbor
# Processing Record 393 of Set 1 | vila franca do campo
# Processing Record 394 of Set 1 | paka
# Processing Record 395 of Set 1 | jiayuguan
# Processing Record 396 of Set 1 | esmeralda
# Processing Record 397 of Set 1 | lujan
# Processing Record 398 of Set 1 | haapiti
# Processing Record 399 of Set 1 | yar-sale
# Processing Record 400 of Set 1 | ignacio de la llave
# Processing Record 401 of Set 1 | bom jesus
# Processing Record 402 of Set 1 | sibolga
# no Data avaiable for city asau,because of HTTP Error 404: Not Found
# Processing Record 403 of Set 1 | itarema
# Processing Record 404 of Set 1 | chatrapur
# Processing Record 405 of Set 1 | macduff
# Processing Record 406 of Set 1 | sinnamary
# Processing Record 407 of Set 1 | san andres
# Processing Record 408 of Set 1 | nizhnevartovsk
# Processing Record 409 of Set 1 | mananjary
# Processing Record 410 of Set 1 | banikoara
# Processing Record 411 of Set 1 | hays
# no Data avaiable for city rawannawi,because of HTTP Error 404: Not Found
# Processing Record 412 of Set 1 | rorvik
# Processing Record 413 of Set 1 | keetmanshoop
# Processing Record 414 of Set 1 | carutapera
# Processing Record 415 of Set 1 | maceio
# Processing Record 416 of Set 1 | yumen
# Processing Record 417 of Set 1 | grand-santi
# Processing Record 418 of Set 1 | axim
# Processing Record 419 of Set 1 | pitimbu
# no Data avaiable for city zolotinka,because of HTTP Error 404: Not Found
# Processing Record 420 of Set 1 | itaituba
# Processing Record 421 of Set 1 | natal
# Processing Record 422 of Set 1 | qitaihe
# Processing Record 423 of Set 1 | hovd
# Processing Record 424 of Set 1 | sasovo
# no Data avaiable for city viligili,because of HTTP Error 404: Not Found
# Processing Record 425 of Set 1 | kamenka
# Processing Record 426 of Set 1 | wanning
# Processing Record 427 of Set 1 | okha
# Processing Record 428 of Set 1 | baruun-urt
# Processing Record 429 of Set 1 | marinette
# Processing Record 430 of Set 1 | killybegs
# Processing Record 431 of Set 1 | omsukchan
# Processing Record 432 of Set 1 | broome
# Processing Record 433 of Set 1 | saint-louis
# Processing Record 434 of Set 1 | rio grande
# Processing Record 435 of Set 1 | kuusankoski
# Processing Record 436 of Set 1 | bassila
# Processing Record 437 of Set 1 | half moon bay
# Processing Record 438 of Set 1 | shalakusha
# Processing Record 439 of Set 1 | kudahuvadhoo
# Processing Record 440 of Set 1 | pisco
# Processing Record 441 of Set 1 | najran
# no Data avaiable for city louisbourg,because of HTTP Error 404: Not Found
# no Data avaiable for city samalaeulu,because of HTTP Error 404: Not Found
# no Data avaiable for city kazalinsk,because of HTTP Error 404: Not Found
# Processing Record 442 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 443 of Set 1 | coquimbo
# Processing Record 444 of Set 1 | dunedin
# Processing Record 445 of Set 1 | winterberg
# Processing Record 446 of Set 1 | brigantine
# Processing Record 447 of Set 1 | mounana
# no Data avaiable for city halalo,because of HTTP Error 404: Not Found
# Processing Record 448 of Set 1 | amahai
# Processing Record 449 of Set 1 | shenjiamen
# Processing Record 450 of Set 1 | sabha
# Processing Record 451 of Set 1 | san jose de guanipa
# Processing Record 452 of Set 1 | fortuna
# Processing Record 453 of Set 1 | saldanha
# Processing Record 454 of Set 1 | nagato
# Processing Record 455 of Set 1 | saint-leu
# Processing Record 456 of Set 1 | balkhash
# Processing Record 457 of Set 1 | skegness
# Processing Record 458 of Set 1 | muzhi
# Processing Record 459 of Set 1 | belmonte
# Processing Record 460 of Set 1 | oum hadjer
# Processing Record 461 of Set 1 | skibbereen
# Processing Record 462 of Set 1 | ahuimanu
# Processing Record 463 of Set 1 | gizo
# Processing Record 464 of Set 1 | komsomolskiy
# Processing Record 465 of Set 1 | nome
# Processing Record 466 of Set 1 | port hedland
# Processing Record 467 of Set 1 | victoria point
# Processing Record 468 of Set 1 | corrente
# no Data avaiable for city meyungs,because of HTTP Error 404: Not Found
# Processing Record 469 of Set 1 | zyryanka
# Processing Record 470 of Set 1 | santa isabel do rio negro
# Processing Record 471 of Set 1 | termini imerese
# Processing Record 472 of Set 1 | west bay
# Processing Record 473 of Set 1 | marsa matruh
# Processing Record 474 of Set 1 | urusha
# Processing Record 475 of Set 1 | nelson bay
# Processing Record 476 of Set 1 | bogo
# Processing Record 477 of Set 1 | kroya
# Processing Record 478 of Set 1 | beaverlodge
# Processing Record 479 of Set 1 | boguchany
# no Data avaiable for city kuche,because of HTTP Error 404: Not Found
# Processing Record 480 of Set 1 | aljezur
# Processing Record 481 of Set 1 | palu
# Processing Record 482 of Set 1 | jacareacanga
# Processing Record 483 of Set 1 | srednekolymsk
# Processing Record 484 of Set 1 | beidao
# Processing Record 485 of Set 1 | bukachacha
# Processing Record 486 of Set 1 | yulara
# Processing Record 487 of Set 1 | cruzilia
# Processing Record 488 of Set 1 | lerwick
# Processing Record 489 of Set 1 | kavaratti
# Processing Record 490 of Set 1 | gerash
# no Data avaiable for city ye,because of HTTP Error 404: Not Found
# Processing Record 491 of Set 1 | sohag
# no Data avaiable for city kuhestan,because of HTTP Error 404: Not Found
# Processing Record 492 of Set 1 | areosa
# Processing Record 493 of Set 1 | mukono
# Processing Record 494 of Set 1 | vardo
# no Data avaiable for city zachagansk,because of HTTP Error 404: Not Found
# Processing Record 495 of Set 1 | punta alta
# Processing Record 496 of Set 1 | abha
# Processing Record 497 of Set 1 | kloulklubed
# no Data avaiable for city umzimvubu,because of HTTP Error 404: Not Found
# Processing Record 498 of Set 1 | aiken
# Processing Record 499 of Set 1 | tarnobrzeg
# Processing Record 500 of Set 1 | ginda
# Processing Record 501 of Set 1 | kedougou
# Processing Record 502 of Set 1 | elmira
# Processing Record 503 of Set 1 | ambilobe
# Processing Record 504 of Set 1 | mirnyy
# Processing Record 505 of Set 1 | darhan
# no Data avaiable for city agva,because of HTTP Error 404: Not Found
# Processing Record 506 of Set 1 | lakes entrance
# Processing Record 507 of Set 1 | rafaela
# Processing Record 508 of Set 1 | ankang
# Processing Record 509 of Set 1 | dekar

# %%
weather_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-6c0953ae58e8> in <module>
# ----> 1 weather_data
#
# NameError: name 'weather_data' is not defined

# %%
# List for holding lat_lngs and cities ok
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)


# list for response results
total_cities = len(cities)
lat = []
temp = []
humidity = []
clouds = []
speed = []
main = []
cloudiness = []
city_number = []
lon = []
country = []
maxtemp = []
date = []
count = 1
results = []

print('Processing Data Retrieval')
print('-----------------------------')



for city in cities:
        response = requests.get(query_url + city, stream=True).json()
        # loop through cities, make API request, and append desired results

        #print(cities)
        cloudiness.append(response['weather'][0]['description'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        temp.append(response['main']['temp'])
        humidity.append(response['main']['humidity'])
        country.append(response['sys']['country'])
        date.append(response["dt"])
        maxtemp.append(response['main']['temp_max'])
        speed.append(response['wind']['speed'])
        print(query_url + city)
        print(f"processing Record {count} of Set {total_cities} | " + city )
        count = count + 1

    
    # extract results
     #   results = response({results})

# %%
# List for holding lat_lngs and cities ok
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)


# list for response results
settings = {"units": "Imperial", "appid": api_key}
weather_py = []
response = []
total_cities = len(cities)
lat = []
temp = []
humidity = []
clouds = []
speed = []
main = []
cloudiness = []
city_number = []
lon = []
country = []
temp_max = []
date = []
count = 1
results = []
cit = []
print('Processing Data Retrieval')
print('-----------------------------')


#for url in [query_url]:
for city in cities:
    try:
        #response = requests.get(url)
        weather_py = [owm.get_current(city, **settings)]
        #response = requests.get(query_url + city, stream=True)
        lat.append(weather_py[0]["coord"]["lat"])
        lon.append(weather_py[0]["coord"]["lon"])
        temp.append(weather_py[0]["main"]["temp"])
        cit.append(weather_py[0]["name"])
        cloudiness.append(weather_py[0]['weather']['description'])
        humidity.append(weather_py[0]["main"]["humidity"])
        temp_max.append(weather_py[0]["main"]["temp_max"])
        country.append(weather_py[0]["sys"]["country"])
        cloudiness.append(weather_py[0]["clouds"]["all"])
        date.append(weather_py[0]["dt"])
        wind.append(weather_py[0]["wind"]["speed"])
    # If the response was successful, no Exception will be raised
       # response.raise_for_status()
        print(query_url + city)
        print(f"processing Record {count} of Set {total_cities} | " + city )
        count = count + 1
        #print('Success!')
        #count = count + 1
    except HTTPError as http_err:
        print(f'HTTP error occurred: {http_err}')  # Python 3.6
    except Exception as err:
        print(f'Other error occurred: {err}')  # Python 3.6
        print(query_url)
# Out:
# Processing Data Retrieval
# -----------------------------
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: HTTP Error 404: Not Found
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: HTTP Error 404: Not Found
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: HTTP Error 404: Not Found
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: HTTP Error 404: Not Found
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: HTTP Error 404: Not Found
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: HTTP Error 404: Not Found
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: HTTP Error 404: Not Found
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: HTTP Error 404: Not Found
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: HTTP Error 404: Not Found
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: HTTP Error 404: Not Found
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: HTTP Error 404: Not Found
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: HTTP Error 404: Not Found
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: HTTP Error 404: Not Found
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: HTTP Error 404: Not Found
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: HTTP Error 404: Not Found
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: HTTP Error 404: Not Found
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: HTTP Error 404: Not Found
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: HTTP Error 404: Not Found
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: HTTP Error 404: Not Found
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: HTTP Error 404: Not Found
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: HTTP Error 404: Not Found
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: HTTP Error 404: Not Found
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: HTTP Error 404: Not Found
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: HTTP Error 404: Not Found
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: HTTP Error 404: Not Found
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: HTTP Error 404: Not Found
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: HTTP Error 404: Not Found
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# ...
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: HTTP Error 404: Not Found
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: HTTP Error 404: Not Found
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: HTTP Error 404: Not Found
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: HTTP Error 404: Not Found
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: HTTP Error 404: Not Found
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: HTTP Error 404: Not Found
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: HTTP Error 404: Not Found
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: HTTP Error 404: Not Found
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: HTTP Error 404: Not Found
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: list indices must be integers or slices, not str
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=
# Other error occurred: HTTP Error 404: Not Found
# http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q=

# %%
weather_py
# Out:
# [{'coord': {'lon': -54.98, 'lat': 5.06},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 80.6,
#    'pressure': 1009,
#    'humidity': 78,
#    'temp_min': 80.6,
#    'temp_max': 80.6},
#   'visibility': 10000,
#   'wind': {'speed': 5.82, 'deg': 30},
#   'clouds': {'all': 40},
#   'dt': 1562103931,
#   'sys': {'type': 1,
#    'id': 8663,
#    'message': 0.0065,
#    'country': 'SR',
#    'sunrise': 1562059890,
#    'sunset': 1562104561},
#   'timezone': -10800,
#   'id': 3384482,
#   'name': 'Brokopondo',
#   'cod': 200}]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# build a dataframe from the cities, lon,and pressure lists


city_data = {"city": cities, 
               # "Cloudiness": cloudiness, 
                "Country": country, 
                "Date": date, 
                "Humidity": humidity, 
                "Latitude": lat, 
                "Lng": lon, 
                "Max Temp": temp_max,  
                "Wind Speed": speed, 
                "Temperature": temp
            }
city_data = pd.DataFrame(city_data)
city_data

# %%
print(len(cities), len(country), len(date), len(cloudiness), len(humidity), len(lat), len(lon), len(temp_max), len(speed), len(temp))
# Out:
# 602 0 0 0 0 524 524 0 0 524

# %%
city_data.count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-be7f5f6416d6> in <module>
# ----> 1 city_data.count()
#
# AttributeError: 'dict' object has no attribute 'count'

# %%
# Save as a csv  OK
# Note to avoid any issues later, use encoding="utf-8"
weather_data.to_csv("weatherpy.csv", encoding="utf-8", index=False)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
 # Build a scatter plot for each data type
plt.scatter(city_data["Max Temp"], city_data["Latitude"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max Temp"+"(F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude vs Max Temperature.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(city_data["Humidity"], city_data["Latitude"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity" +"(%)")
plt.xlabel("Latitude")
plt.grid(True)

# Set the y-limits of the current axes to 100 Fahrenheit

ylim=(0, 100)

# Save the figure
plt.savefig("Latitude vs Humidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_data["Cloudiness"], city_data["Latitude"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness ")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

# Set the y-limits of the current axes to 100 Fahrenheit

xlim=(-80,100)
ylim=(0, 100)


# Save the figure
plt.savefig("City Latitude vs Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_data["Wind Speed"], city_data["Latitude"], marker="o")

# Incorporate the other graph properties
plt.title("Wind Speed (mph) vs. Latitude")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Wind Speed vs Latitude.png")

# Show plot
plt.show()

# %%
 # Build a scatter plot for each data type
plt.scatter(city_data["Temperature"], city_data["Latitude"], marker="o")

# Incorporate the other graph properties
plt.title("Temperature (F) vs. Latitude")
plt.ylabel("Latitude")
plt.xlabel("Temperature")
plt.grid(True)

# Save the figure
plt.savefig("Temperature vrs Latitude.png")

# Show plot
plt.show()

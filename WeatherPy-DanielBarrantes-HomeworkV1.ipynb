# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from requests.exceptions import HTTPError
import openweathermapy.core as owm
import time

# Import API key
from config2 import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

api_key
# Out:
# '9586ef608bbf0838f9b387e9d8d4b1da'

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities ok
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
cities
# Out:
# ['taolanaro',
#  'port elizabeth',
#  'punta arenas',
#  'chuy',
#  'atuona',
#  'tunduru',
#  'mount gambier',
#  'bargal',
#  'arraial do cabo',
#  'albany',
#  'hilo',
#  'avarua',
#  'severo-kurilsk',
#  'jamestown',
#  'kuche',
#  'boshnyakovo',
#  'ancud',
#  'ballina',
#  'bubaque',
#  'satitoa',
#  'chicama',
#  'biak',
#  'shingu',
#  'iquique',
#  'puerto ayora',
#  'ratnagiri',
#  'illoqqortoormiut',
#  'butaritari',
#  'busselton',
#  'mataura',
#  'qaanaaq',
#  'nacala',
#  'sao filipe',
#  'inhambane',
#  'cherskiy',
#  'touros',
#  'seddon',
#  'tuktoyaktuk',
#  'qorveh',
#  'grand gaube',
#  'bellevue',
#  'launceston',
#  'nouadhibou',
#  'kadiri',
#  'miles city',
#  'sola',
#  'praia da vitoria',
#  'port blair',
#  'belushya guba',
#  'iqaluit',
#  'ferme-neuve',
#  'eureka',
#  'alta floresta',
#  'saskylakh',
#  'new norfolk',
#  'toliary',
#  'kinango',
#  'tahta',
#  'adrar',
#  'puro',
#  'guerrero negro',
#  'alakurtti',
#  'hasaki',
#  'sao felix do xingu',
#  'medicine hat',
#  'bredasdorp',
#  'pacific grove',
#  'la ronge',
#  'esperance',
#  'funadhoo',
#  'rikitea',
#  'cape town',
#  'mount isa',
#  'vardo',
#  'provideniya',
#  'lorengau',
#  'itarema',
#  'nizhneyansk',
#  'hithadhoo',
#  'east london',
#  'shenjiamen',
#  'norman wells',
#  'vaini',
#  'paita',
#  'haapiti',
#  'port hardy',
#  'ponta do sol',
#  'hermanus',
#  'sivaki',
#  'warqla',
#  'komsomolskiy',
#  'attawapiskat',
#  'malwan',
#  'vaitupu',
#  'rock sound',
#  'isangel',
#  'verkhoyansk',
#  'mahebourg',
#  'nemuro',
#  'ilulissat',
#  'ushuaia',
#  'qasigiannguit',
#  'walvis bay',
#  'takayama',
#  'haines junction',
#  'sechura',
#  'nanortalik',
#  'rawson',
#  'navirai',
#  'yellowknife',
#  'arteaga',
#  'ambilobe',
#  'tasiilaq',
#  'pevek',
#  'bluff',
#  'kapaa',
#  'igrim',
#  'bengkulu',
#  'narsaq',
#  'bambous virieux',
#  'ardistan',
#  'naugarzan',
#  'talara',
#  'aklavik',
#  'mehamn',
#  'kuandian',
#  'bethel',
#  'san matias',
#  'nome',
#  'mazagao',
#  'belyy yar',
#  'terrace',
#  'leningradskiy',
#  'saint-denis',
#  'beloha',
#  'lakes entrance',
#  'daura',
#  'sentyabrskiy',
#  'vagur',
#  'alofi',
#  'port-gentil',
#  'bakchar',
#  'nikolayevsk-na-amure',
#  'karkaralinsk',
#  'port lincoln',
#  'guatire',
#  'bom jardim',
#  'victoria',
#  'teguise',
#  'luderitz',
#  'vulcan',
#  'barbosa ferraz',
#  'tigil',
#  'awjilah',
#  'sao joao da barra',
#  'kichera',
#  'tessalit',
#  'el dovio',
#  'thompson',
#  'saint-philippe',
#  'paradwip',
#  'lagoa',
#  'constitucion',
#  'louisbourg',
#  'dikson',
#  'nicoya',
#  'giyani',
#  'menongue',
#  'mar del plata',
#  'nuuk',
#  'dudinka',
#  'flinders',
#  'prince george',
#  'hobart',
#  'mys shmidta',
#  'pangnirtung',
#  'tiksi',
#  'hun',
#  'naze',
#  'bor',
#  'ulladulla',
#  'maltahohe',
#  'petropavlovsk-kamchatskiy',
#  'marsh harbour',
#  'taoudenni',
#  'shipunovo',
#  'hobyo',
#  'ostrovnoy',
#  'tuatapere',
#  'tibati',
#  'san pedro de macoris',
#  'catalina',
#  'laguna',
#  'revda',
#  'anadyr',
#  'douentza',
#  'srednekolymsk',
#  'banjar',
#  'tsihombe',
#  'enterprise',
#  'igarka',
#  'urengoy',
#  'healdsburg',
#  'nelson',
#  'dingle',
#  'trelew',
#  'aketi',
#  'te anau',
#  'bolshaya chernigovka',
#  'tornio',
#  'carman',
#  'bilibino',
#  'mersing',
#  'meulaboh',
#  'otradnoye',
#  'torbay',
#  'fort nelson',
#  'alyangula',
#  'doha',
#  'saldanha',
#  'kilrush',
#  'port hedland',
#  'tianmen',
#  'bolshaya orlovka',
#  'bien hoa',
#  'sur',
#  'samusu',
#  'pitimbu',
#  'colac',
#  'tabiauea',
#  'port alfred',
#  'burica',
#  'nipawin',
#  'bac lieu',
#  'moree',
#  'castro',
#  'souillac',
#  'barranca',
#  'bartica',
#  'skibbereen',
#  'umm kaddadah',
#  'sept-iles',
#  'gravdal',
#  'minas',
#  'nanakuli',
#  'saint george',
#  'rocha',
#  'kholodnyy',
#  'natal',
#  'benguela',
#  'santa rosa',
#  'berlevag',
#  'sinnamary',
#  'middelburg',
#  'muroto',
#  'beringovskiy',
#  'kashi',
#  'ararat',
#  'manyana',
#  'tura',
#  'kaitangata',
#  'lebu',
#  'palu',
#  'nikolskoye',
#  'airai',
#  'salisbury',
#  'visby',
#  'petrolandia',
#  'cidreira',
#  'georgiyevka',
#  'coihaique',
#  'fayaoue',
#  'karaul',
#  'san quintin',
#  'upernavik',
#  'sindhnur',
#  'gamba',
#  'teluk nibung',
#  'fortuna',
#  'klaksvik',
#  'ola',
#  'quatre cocos',
#  'meadow lake',
#  'porto santo',
#  'luang prabang',
#  'tonstad',
#  'lidorikion',
#  'caraguatatuba',
#  'takoradi',
#  'korla',
#  'omboue',
#  'shache',
#  'aykhal',
#  'limeira',
#  'otjiwarongo',
#  'labuhan',
#  'goderich',
#  'mumbwa',
#  'baena',
#  'cache creek',
#  'clarence town',
#  'angoche',
#  'puerto escondido',
#  'kirensk',
#  'grandview',
#  'sitka',
#  'north branch',
#  'baykit',
#  'ribeira grande',
#  'coquimbo',
#  'santa cruz',
#  'iranshahr',
#  'sovik',
#  'sirkali',
#  'auki',
#  'gimli',
#  'marcona',
#  'mackay',
#  'salalah',
#  'kudahuvadhoo',
#  'sisimiut',
#  'wanning',
#  'gushikawa',
#  'namatanai',
#  'chagda',
#  'barrow',
#  'vestmannaeyjar',
#  'chokurdakh',
#  'kahului',
#  'winnemucca',
#  'olafsvik',
#  'kismayo',
#  'bathsheba',
#  'miranda',
#  'ariquemes',
#  'dien bien',
#  'bom jesus',
#  'rio grande',
#  'praia',
#  'kalmunai',
#  'faanui',
#  'ambodifototra',
#  'sumbe',
#  'ahipara',
#  'vuktyl',
#  'matara',
#  'tilichiki',
#  'kirakira',
#  'kilifi',
#  'codrington',
#  'yar-sale',
#  'cayenne',
#  'barentsburg',
#  'asau',
#  'mullaitivu',
#  'constantine',
#  'lavrentiya',
#  'deniliquin',
#  'mercedes',
#  'caconda',
#  'sobolevo',
#  'zhigansk',
#  'buraydah',
#  'burghausen',
#  'almaznyy',
#  'kavieng',
#  'dhidhdhoo',
#  'kumluca',
#  'kaiyuan',
#  'vitim',
#  'monte santo',
#  'zheleznodorozhnyy',
#  'san carlos de bariloche',
#  'katsuura',
#  'termoli',
#  'rio gallegos',
#  'warka',
#  'gizo',
#  'baneh',
#  'georgetown',
#  'dukhovnitskoye',
#  'uwayl',
#  'marsaxlokk',
#  'moose factory',
#  'carnarvon',
#  'aleksandrovsk-sakhalinskiy',
#  'ust-koksa',
#  'capitao poco',
#  'genhe',
#  'high level',
#  'mildura',
#  'pangai',
#  'nanding',
#  'behat',
#  'pangkalanbuun',
#  'icusesti',
#  'khatanga',
#  'vanimo',
#  'boca do acre',
#  'waw',
#  'los llanos de aridane',
#  'khani',
#  'trairi',
#  'vostok',
#  'denton',
#  'gibsons',
#  'nantucket',
#  'namibe',
#  'zaysan',
#  'husavik',
#  'north bend',
#  'nuevitas',
#  'saleaula',
#  'durant',
#  'derzhavinsk',
#  'svetlaya',
#  'torres',
#  'naryan-mar',
#  'malaryta',
#  'grand river south east',
#  'saint-leu',
#  'joshimath',
#  'halifax',
#  'quime',
#  'miranda do corvo',
#  'kodiak',
#  'neryungri',
#  'riyadh',
#  'ejura',
#  'college',
#  'alice springs',
#  'tezu',
#  'chaykovskiy',
#  'saint-pierre',
#  'chandler',
#  'paamiut',
#  'minsk',
#  'antofagasta',
#  'ambon',
#  'kamenka',
#  'longlac',
#  'mrirt',
#  'marienburg',
#  'broken hill',
#  'grao mogol',
#  'sattahip',
#  'kiparissia',
#  'kavaratti',
#  'amapa',
#  'longyearbyen',
#  'karwar',
#  'ramsi',
#  'saint-augustin',
#  'kulti',
#  'geraldton',
#  'avesta',
#  'gat',
#  'sakakah',
#  'aflu',
#  'mitu',
#  'dunedin',
#  'teguldet',
#  'mutsamudu',
#  'nambucca heads',
#  'kloulklubed',
#  'amderma',
#  'okhotsk',
#  'leo',
#  'xinxiang',
#  'yatou',
#  'shirokiy',
#  'wschowa',
#  'nedjo',
#  'rugby',
#  'betioky',
#  'karratha',
#  'mayo',
#  'garowe',
#  'frutal',
#  'cabo san lucas',
#  'phan rang',
#  'dhamtari',
#  'wukari',
#  'lasa',
#  'volkhovskiy',
#  'dawei',
#  'ust-bolsheretsk',
#  'zdvinsk',
#  'asfi',
#  'timmins',
#  'clyde river',
#  'baltatesti',
#  'cayambe',
#  'henties bay',
#  'huntsville',
#  'celestun',
#  'lompoc',
#  'surt',
#  'koslan',
#  'yulara',
#  'otukpo',
#  'bonnyville',
#  'guiuan',
#  'dukat',
#  'weyburn',
#  'azimur',
#  'yeppoon',
#  'birao',
#  'soyo',
#  'zyryanovsk',
#  'sao joao de pirabas',
#  'msanga',
#  'bindura',
#  'kasempa',
#  'kalianget',
#  'vanino',
#  'schwabmunchen',
#  'almeirim',
#  'sharkan',
#  'vilhena',
#  'picos',
#  'huntington',
#  'necochea',
#  'khonuu',
#  'ouadda',
#  'sunrise manor',
#  'torit',
#  'chisec',
#  'cassilandia',
#  'tulsipur',
#  'manggar',
#  'manta',
#  'karauzyak',
#  'chincha alta',
#  'acapulco',
#  'muros',
#  'mumford',
#  'wanaka',
#  'lianyuan',
#  'tumannyy',
#  'varhaug',
#  'pisco',
#  'catamarca',
#  'cururupu',
#  'massa marittima',
#  'rosarito',
#  'padang',
#  'neustrelitz',
#  'fugen',
#  'farafangana',
#  'barcelos',
#  'romilly-sur-seine',
#  'viedma',
#  'ponta delgada',
#  'toba',
#  'half moon bay',
#  'hamilton',
#  'antalaha',
#  'price',
#  'tasbuget',
#  'vikersund',
#  'ewa beach',
#  'hambantota',
#  'thyolo',
#  'kidal',
#  'cranbrook',
#  'verkhnevilyuysk',
#  'khalkhal',
#  'chirilagua',
#  'atengo',
#  'lages',
#  'bosaso',
#  'litoral del san juan',
#  'tabas',
#  'acarau',
#  'mujiayingzi',
#  'bristol',
#  'pandan',
#  'aquiraz',
#  'urumqi',
#  'mogadishu',
#  'kamenskoye',
#  'hofn',
#  'oranjestad',
#  'ornskoldsvik',
#  'neulengbach',
#  'moerai',
#  'maceio',
#  'dunmore town',
#  'don sak',
#  'atima',
#  'chippewa falls',
#  'mendahara',
#  'zhovkva',
#  'terney',
#  'rottingdean',
#  'wuwei',
#  'longhua',
#  'jining',
#  'palabuhanratu',
#  'russell',
#  'kasongo-lunda',
#  'omsukchan',
#  'horsham',
#  'manokwari',
#  'interlaken',
#  'pozo colorado',
#  'bandundu',
#  'tautira',
#  'mwinilunga',
#  'hohhot',
#  'warrington',
#  'klishkivtsi',
#  'mugumu',
#  'mokokchung',
#  'mahajanga',
#  'pochutla',
#  'nowogard',
#  'show low',
#  'posse',
#  'goryachegorsk',
#  'puerto padre',
#  'yarmouth',
#  'dongsheng',
#  'moron',
#  'jacareacanga',
#  'camacha',
#  'daru',
#  'tamandare',
#  'dwarka',
#  'amasya',
#  'yinchuan',
#  'belgrade',
#  'jiaocheng',
#  'teya',
#  'sao miguel do araguaia',
#  'druzhnaya gorka',
#  'obihiro',
#  'skjervoy',
#  'saint anthony',
#  'ambulu',
#  'kazachinskoye',
#  'riaba',
#  'papetoai',
#  'presidencia roque saenz pena',
#  'odweyne',
#  'chumikan',
#  'boa vista',
#  'arlit',
#  'artyk']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# %%
# Build partial query URL OK
query_url = f"{url}appid={api_key}&units={units}&q="
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=9586ef608bbf0838f9b387e9d8d4b1da&units=imperial&q='

# %%
settings = {"units": "imperial", "appid": api_key}
total_cities = len(cities)
weather_data = []
lat=[]
lon=[]
temp=[]
cit=[]
temp_max=[]
humidity=[]
wind=[]
date=[]
cloudiness=[]
country=[]
count=1

print('Processing Data Retrieval')
print('-----------------------------')


for city in cities:
   print(f"processing Record {count} of Set {total_cities} | " + city )
   try:
       weather_data = [owm.get_current(city, **settings)]
       lat.append(weather_data[0]["coord"]["lat"])
       lon.append(weather_data[0]["coord"]["lon"])
       temp.append(weather_data[0]["main"]["temp"])
       cit.append(weather_data[0]["name"])
       humidity.append(weather_data[0]["main"]["humidity"])
       temp_max.append(weather_data[0]["main"]["temp_max"])
       country.append(weather_data[0]["sys"]["country"])
       cloudiness.append(weather_data[0]["clouds"]["all"])
       date.append(weather_data[0]["dt"])
       wind.append(weather_data[0]["wind"]["speed"])
       print(query_url + city)   
       
    
      # print(f"Processing Record {record} of Set 1 | {city}")
       #pprint(weather_data)
       count=count + 1
   except Exception as e:
               print(f"no data available for city {city},because of {e}")
               #del cities[count-1]
# Out:
# Processing Data Retrieval
# -----------------------------
# processing Record 1 of Set 650 | taolanaro
# no data available for city taolanaro,because of HTTP Error 429:
# processing Record 1 of Set 650 | port elizabeth
# no data available for city port elizabeth,because of HTTP Error 429:
# processing Record 1 of Set 650 | punta arenas
# no data available for city punta arenas,because of HTTP Error 429:
# processing Record 1 of Set 650 | chuy
# no data available for city chuy,because of HTTP Error 429:
# processing Record 1 of Set 650 | atuona
# no data available for city atuona,because of HTTP Error 429:
# processing Record 1 of Set 650 | tunduru
# no data available for city tunduru,because of HTTP Error 429:
# processing Record 1 of Set 650 | mount gambier
# no data available for city mount gambier,because of HTTP Error 429:
# processing Record 1 of Set 650 | bargal
# no data available for city bargal,because of HTTP Error 429:
# processing Record 1 of Set 650 | arraial do cabo
# no data available for city arraial do cabo,because of HTTP Error 429:
# processing Record 1 of Set 650 | albany
# no data available for city albany,because of HTTP Error 429:
# processing Record 1 of Set 650 | hilo
# no data available for city hilo,because of HTTP Error 429:
# processing Record 1 of Set 650 | avarua
# no data available for city avarua,because of HTTP Error 429:
# processing Record 1 of Set 650 | severo-kurilsk
# no data available for city severo-kurilsk,because of HTTP Error 429:
# processing Record 1 of Set 650 | jamestown
# no data available for city jamestown,because of HTTP Error 429:
# processing Record 1 of Set 650 | kuche
# no data available for city kuche,because of HTTP Error 429:
# processing Record 1 of Set 650 | boshnyakovo
# no data available for city boshnyakovo,because of HTTP Error 429:
# processing Record 1 of Set 650 | ancud
# no data available for city ancud,because of HTTP Error 429:
# processing Record 1 of Set 650 | ballina
# no data available for city ballina,because of HTTP Error 429:
# processing Record 1 of Set 650 | bubaque
# no data available for city bubaque,because of HTTP Error 429:
# processing Record 1 of Set 650 | satitoa
# no data available for city satitoa,because of HTTP Error 429:
# processing Record 1 of Set 650 | chicama
# no data available for city chicama,because of HTTP Error 429:
# processing Record 1 of Set 650 | biak
# no data available for city biak,because of HTTP Error 429:
# processing Record 1 of Set 650 | shingu
# no data available for city shingu,because of HTTP Error 429:
# processing Record 1 of Set 650 | iquique
# no data available for city iquique,because of HTTP Error 429:
# processing Record 1 of Set 650 | puerto ayora
# no data available for city puerto ayora,because of HTTP Error 429:
# processing Record 1 of Set 650 | ratnagiri
# no data available for city ratnagiri,because of HTTP Error 429:
# processing Record 1 of Set 650 | illoqqortoormiut
# no data available for city illoqqortoormiut,because of HTTP Error 429:
# processing Record 1 of Set 650 | butaritari
# no data available for city butaritari,because of HTTP Error 429:
# processing Record 1 of Set 650 | busselton
# no data available for city busselton,because of HTTP Error 429:
# processing Record 1 of Set 650 | mataura
# no data available for city mataura,because of HTTP Error 429:
# processing Record 1 of Set 650 | qaanaaq
# no data available for city qaanaaq,because of HTTP Error 429:
# processing Record 1 of Set 650 | nacala
# no data available for city nacala,because of HTTP Error 429:
# processing Record 1 of Set 650 | sao filipe
# no data available for city sao filipe,because of HTTP Error 429:
# processing Record 1 of Set 650 | inhambane
# no data available for city inhambane,because of HTTP Error 429:
# processing Record 1 of Set 650 | cherskiy
# no data available for city cherskiy,because of HTTP Error 429:
# processing Record 1 of Set 650 | touros
# no data available for city touros,because of HTTP Error 429:
# processing Record 1 of Set 650 | seddon
# no data available for city seddon,because of HTTP Error 429:
# processing Record 1 of Set 650 | tuktoyaktuk
# no data available for city tuktoyaktuk,because of HTTP Error 429:
# processing Record 1 of Set 650 | qorveh
# no data available for city qorveh,because of HTTP Error 429:
# processing Record 1 of Set 650 | grand gaube
# no data available for city grand gaube,because of HTTP Error 429:
# processing Record 1 of Set 650 | bellevue
# no data available for city bellevue,because of HTTP Error 429:
# processing Record 1 of Set 650 | launceston
# no data available for city launceston,because of HTTP Error 429:
# processing Record 1 of Set 650 | nouadhibou
# no data available for city nouadhibou,because of HTTP Error 429:
# processing Record 1 of Set 650 | kadiri
# no data available for city kadiri,because of HTTP Error 429:
# processing Record 1 of Set 650 | miles city
# no data available for city miles city,because of HTTP Error 429:
# processing Record 1 of Set 650 | sola
# no data available for city sola,because of HTTP Error 429:
# processing Record 1 of Set 650 | praia da vitoria
# no data available for city praia da vitoria,because of HTTP Error 429:
# processing Record 1 of Set 650 | port blair
# no data available for city port blair,because of HTTP Error 429:
# processing Record 1 of Set 650 | belushya guba
# no data available for city belushya guba,because of HTTP Error 429:
# processing Record 1 of Set 650 | iqaluit
# no data available for city iqaluit,because of HTTP Error 429:
# processing Record 1 of Set 650 | ferme-neuve
# no data available for city ferme-neuve,because of HTTP Error 429:
# processing Record 1 of Set 650 | eureka
# no data available for city eureka,because of HTTP Error 429:
# processing Record 1 of Set 650 | alta floresta
# no data available for city alta floresta,because of HTTP Error 429:
# processing Record 1 of Set 650 | saskylakh
# no data available for city saskylakh,because of HTTP Error 429:
# processing Record 1 of Set 650 | new norfolk
# no data available for city new norfolk,because of HTTP Error 429:
# processing Record 1 of Set 650 | toliary
# no data available for city toliary,because of HTTP Error 429:
# processing Record 1 of Set 650 | kinango
# no data available for city kinango,because of HTTP Error 429:
# processing Record 1 of Set 650 | tahta
# no data available for city tahta,because of HTTP Error 429:
# processing Record 1 of Set 650 | adrar
# no data available for city adrar,because of HTTP Error 429:
# processing Record 1 of Set 650 | puro
# no data available for city puro,because of HTTP Error 429:
# processing Record 1 of Set 650 | guerrero negro
# no data available for city guerrero negro,because of HTTP Error 429:
# processing Record 1 of Set 650 | alakurtti
# no data available for city alakurtti,because of HTTP Error 429:
# processing Record 1 of Set 650 | hasaki
# no data available for city hasaki,because of HTTP Error 429:
# processing Record 1 of Set 650 | sao felix do xingu
# no data available for city sao felix do xingu,because of HTTP Error 429:
# processing Record 1 of Set 650 | medicine hat
# no data available for city medicine hat,because of HTTP Error 429:
# processing Record 1 of Set 650 | bredasdorp
# no data available for city bredasdorp,because of HTTP Error 429:
# processing Record 1 of Set 650 | pacific grove
# no data available for city pacific grove,because of HTTP Error 429:
# processing Record 1 of Set 650 | la ronge
# no data available for city la ronge,because of HTTP Error 429:
# processing Record 1 of Set 650 | esperance
# no data available for city esperance,because of HTTP Error 429:
# processing Record 1 of Set 650 | funadhoo
# no data available for city funadhoo,because of HTTP Error 429:
# processing Record 1 of Set 650 | rikitea
# no data available for city rikitea,because of HTTP Error 429:
# processing Record 1 of Set 650 | cape town
# no data available for city cape town,because of HTTP Error 429:
# processing Record 1 of Set 650 | mount isa
# no data available for city mount isa,because of HTTP Error 429:
# processing Record 1 of Set 650 | vardo
# no data available for city vardo,because of HTTP Error 429:
# processing Record 1 of Set 650 | provideniya
# no data available for city provideniya,because of HTTP Error 429:
# processing Record 1 of Set 650 | lorengau
# no data available for city lorengau,because of HTTP Error 429:
# processing Record 1 of Set 650 | itarema
# no data available for city itarema,because of HTTP Error 429:
# processing Record 1 of Set 650 | nizhneyansk
# no data available for city nizhneyansk,because of HTTP Error 429:
# processing Record 1 of Set 650 | hithadhoo
# no data available for city hithadhoo,because of HTTP Error 429:
# processing Record 1 of Set 650 | east london
# no data available for city east london,because of HTTP Error 429:
# processing Record 1 of Set 650 | shenjiamen
# no data available for city shenjiamen,because of HTTP Error 429:
# processing Record 1 of Set 650 | norman wells
# no data available for city norman wells,because of HTTP Error 429:
# processing Record 1 of Set 650 | vaini
# no data available for city vaini,because of HTTP Error 429:
# processing Record 1 of Set 650 | paita
# no data available for city paita,because of HTTP Error 429:
# processing Record 1 of Set 650 | haapiti
# no data available for city haapiti,because of HTTP Error 429:
# processing Record 1 of Set 650 | port hardy
# no data available for city port hardy,because of HTTP Error 429:
# processing Record 1 of Set 650 | ponta do sol
# no data available for city ponta do sol,because of HTTP Error 429:
# processing Record 1 of Set 650 | hermanus
# no data available for city hermanus,because of HTTP Error 429:
# processing Record 1 of Set 650 | sivaki
# no data available for city sivaki,because of HTTP Error 429:
# processing Record 1 of Set 650 | warqla
# no data available for city warqla,because of HTTP Error 429:
# processing Record 1 of Set 650 | komsomolskiy
# no data available for city komsomolskiy,because of HTTP Error 429:
# processing Record 1 of Set 650 | attawapiskat
# no data available for city attawapiskat,because of HTTP Error 429:
# processing Record 1 of Set 650 | malwan
# no data available for city malwan,because of HTTP Error 429:
# processing Record 1 of Set 650 | vaitupu
# no data available for city vaitupu,because of HTTP Error 429:
# processing Record 1 of Set 650 | rock sound
# no data available for city rock sound,because of HTTP Error 429:
# processing Record 1 of Set 650 | isangel
# no data available for city isangel,because of HTTP Error 429:
# processing Record 1 of Set 650 | verkhoyansk
# no data available for city verkhoyansk,because of HTTP Error 429:
# processing Record 1 of Set 650 | mahebourg
# no data available for city mahebourg,because of HTTP Error 429:
# processing Record 1 of Set 650 | nemuro
# no data available for city nemuro,because of HTTP Error 429:
# processing Record 1 of Set 650 | ilulissat
# no data available for city ilulissat,because of HTTP Error 429:
# processing Record 1 of Set 650 | ushuaia
# no data available for city ushuaia,because of HTTP Error 429:
# processing Record 1 of Set 650 | qasigiannguit
# no data available for city qasigiannguit,because of HTTP Error 429:
# processing Record 1 of Set 650 | walvis bay
# no data available for city walvis bay,because of HTTP Error 429:
# processing Record 1 of Set 650 | takayama
# no data available for city takayama,because of HTTP Error 429:
# processing Record 1 of Set 650 | haines junction
# no data available for city haines junction,because of HTTP Error 429:
# processing Record 1 of Set 650 | sechura
# no data available for city sechura,because of HTTP Error 429:
# processing Record 1 of Set 650 | nanortalik
# no data available for city nanortalik,because of HTTP Error 429:
# processing Record 1 of Set 650 | rawson
# no data available for city rawson,because of HTTP Error 429:
# processing Record 1 of Set 650 | navirai
# no data available for city navirai,because of HTTP Error 429:
# processing Record 1 of Set 650 | yellowknife
# no data available for city yellowknife,because of HTTP Error 429:
# processing Record 1 of Set 650 | arteaga
# no data available for city arteaga,because of HTTP Error 429:
# processing Record 1 of Set 650 | ambilobe
# no data available for city ambilobe,because of HTTP Error 429:
# processing Record 1 of Set 650 | tasiilaq
# no data available for city tasiilaq,because of HTTP Error 429:
# processing Record 1 of Set 650 | pevek
# no data available for city pevek,because of HTTP Error 429:
# processing Record 1 of Set 650 | bluff
# no data available for city bluff,because of HTTP Error 429:
# processing Record 1 of Set 650 | kapaa
# no data available for city kapaa,because of HTTP Error 429:
# processing Record 1 of Set 650 | igrim
# no data available for city igrim,because of HTTP Error 429:
# processing Record 1 of Set 650 | bengkulu
# no data available for city bengkulu,because of HTTP Error 429:
# processing Record 1 of Set 650 | narsaq
# no data available for city narsaq,because of HTTP Error 429:
# processing Record 1 of Set 650 | bambous virieux
# no data available for city bambous virieux,because of HTTP Error 429:
# processing Record 1 of Set 650 | ardistan
# no data available for city ardistan,because of HTTP Error 429:
# processing Record 1 of Set 650 | naugarzan
# no data available for city naugarzan,because of HTTP Error 429:
# processing Record 1 of Set 650 | talara
# no data available for city talara,because of HTTP Error 429:
# processing Record 1 of Set 650 | aklavik
# no data available for city aklavik,because of HTTP Error 429:
# processing Record 1 of Set 650 | mehamn
# no data available for city mehamn,because of HTTP Error 429:
# processing Record 1 of Set 650 | kuandian
# no data available for city kuandian,because of HTTP Error 429:
# processing Record 1 of Set 650 | bethel
# no data available for city bethel,because of HTTP Error 429:
# processing Record 1 of Set 650 | san matias
# no data available for city san matias,because of HTTP Error 429:
# processing Record 1 of Set 650 | nome
# no data available for city nome,because of HTTP Error 429:
# processing Record 1 of Set 650 | mazagao
# no data available for city mazagao,because of HTTP Error 429:
# processing Record 1 of Set 650 | belyy yar
# no data available for city belyy yar,because of HTTP Error 429:
# processing Record 1 of Set 650 | terrace
# no data available for city terrace,because of HTTP Error 429:
# processing Record 1 of Set 650 | leningradskiy
# no data available for city leningradskiy,because of HTTP Error 429:
# processing Record 1 of Set 650 | saint-denis
# no data available for city saint-denis,because of HTTP Error 429:
# processing Record 1 of Set 650 | beloha
# no data available for city beloha,because of HTTP Error 429:
# processing Record 1 of Set 650 | lakes entrance
# no data available for city lakes entrance,because of HTTP Error 429:
# processing Record 1 of Set 650 | daura
# no data available for city daura,because of HTTP Error 429:
# processing Record 1 of Set 650 | sentyabrskiy
# no data available for city sentyabrskiy,because of HTTP Error 429:
# processing Record 1 of Set 650 | vagur
# no data available for city vagur,because of HTTP Error 429:
# processing Record 1 of Set 650 | alofi
# no data available for city alofi,because of HTTP Error 429:
# processing Record 1 of Set 650 | port-gentil
# no data available for city port-gentil,because of HTTP Error 429:
# processing Record 1 of Set 650 | bakchar
# no data available for city bakchar,because of HTTP Error 429:
# processing Record 1 of Set 650 | nikolayevsk-na-amure
# no data available for city nikolayevsk-na-amure,because of HTTP Error 429:
# processing Record 1 of Set 650 | karkaralinsk
# no data available for city karkaralinsk,because of HTTP Error 429:
# processing Record 1 of Set 650 | port lincoln
# no data available for city port lincoln,because of HTTP Error 429:
# processing Record 1 of Set 650 | guatire
# no data available for city guatire,because of HTTP Error 429:
# processing Record 1 of Set 650 | bom jardim
# no data available for city bom jardim,because of HTTP Error 429:
# processing Record 1 of Set 650 | victoria
# no data available for city victoria,because of HTTP Error 429:
# processing Record 1 of Set 650 | teguise
# no data available for city teguise,because of HTTP Error 429:
# processing Record 1 of Set 650 | luderitz
# no data available for city luderitz,because of HTTP Error 429:
# processing Record 1 of Set 650 | vulcan
# no data available for city vulcan,because of HTTP Error 429:
# processing Record 1 of Set 650 | barbosa ferraz
# no data available for city barbosa ferraz,because of HTTP Error 429:
# processing Record 1 of Set 650 | tigil
# no data available for city tigil,because of HTTP Error 429:
# processing Record 1 of Set 650 | awjilah
# no data available for city awjilah,because of HTTP Error 429:
# processing Record 1 of Set 650 | sao joao da barra
# no data available for city sao joao da barra,because of HTTP Error 429:
# processing Record 1 of Set 650 | kichera
# no data available for city kichera,because of HTTP Error 429:
# processing Record 1 of Set 650 | tessalit
# no data available for city tessalit,because of HTTP Error 429:
# processing Record 1 of Set 650 | el dovio
# no data available for city el dovio,because of HTTP Error 429:
# processing Record 1 of Set 650 | thompson
# no data available for city thompson,because of HTTP Error 429:
# processing Record 1 of Set 650 | saint-philippe
# no data available for city saint-philippe,because of HTTP Error 429:
# processing Record 1 of Set 650 | paradwip
# no data available for city paradwip,because of HTTP Error 429:
# processing Record 1 of Set 650 | lagoa
# no data available for city lagoa,because of HTTP Error 429:
# processing Record 1 of Set 650 | constitucion
# no data available for city constitucion,because of HTTP Error 429:
# processing Record 1 of Set 650 | louisbourg
# no data available for city louisbourg,because of HTTP Error 429:
# processing Record 1 of Set 650 | dikson
# no data available for city dikson,because of HTTP Error 429:
# processing Record 1 of Set 650 | nicoya
# no data available for city nicoya,because of HTTP Error 429:
# processing Record 1 of Set 650 | giyani
# no data available for city giyani,because of HTTP Error 429:
# processing Record 1 of Set 650 | menongue
# no data available for city menongue,because of HTTP Error 429:
# processing Record 1 of Set 650 | mar del plata
# no data available for city mar del plata,because of HTTP Error 429:
# processing Record 1 of Set 650 | nuuk
# no data available for city nuuk,because of HTTP Error 429:
# processing Record 1 of Set 650 | dudinka
# no data available for city dudinka,because of HTTP Error 429:
# processing Record 1 of Set 650 | flinders
# no data available for city flinders,because of HTTP Error 429:
# processing Record 1 of Set 650 | prince george
# no data available for city prince george,because of HTTP Error 429:
# processing Record 1 of Set 650 | hobart
# no data available for city hobart,because of HTTP Error 429:
# processing Record 1 of Set 650 | mys shmidta
# no data available for city mys shmidta,because of HTTP Error 429:
# processing Record 1 of Set 650 | pangnirtung
# no data available for city pangnirtung,because of HTTP Error 429:
# processing Record 1 of Set 650 | tiksi
# no data available for city tiksi,because of HTTP Error 429:
# processing Record 1 of Set 650 | hun
# no data available for city hun,because of HTTP Error 429:
# processing Record 1 of Set 650 | naze
# no data available for city naze,because of HTTP Error 429:
# processing Record 1 of Set 650 | bor
# no data available for city bor,because of HTTP Error 429:
# processing Record 1 of Set 650 | ulladulla
# no data available for city ulladulla,because of HTTP Error 429:
# processing Record 1 of Set 650 | maltahohe
# no data available for city maltahohe,because of HTTP Error 429:
# processing Record 1 of Set 650 | petropavlovsk-kamchatskiy
# no data available for city petropavlovsk-kamchatskiy,because of HTTP Error 429:
# processing Record 1 of Set 650 | marsh harbour
# no data available for city marsh harbour,because of HTTP Error 429:
# processing Record 1 of Set 650 | taoudenni
# no data available for city taoudenni,because of HTTP Error 429:
# processing Record 1 of Set 650 | shipunovo
# no data available for city shipunovo,because of HTTP Error 429:
# processing Record 1 of Set 650 | hobyo
# no data available for city hobyo,because of HTTP Error 429:
# processing Record 1 of Set 650 | ostrovnoy
# no data available for city ostrovnoy,because of HTTP Error 429:
# processing Record 1 of Set 650 | tuatapere
# no data available for city tuatapere,because of HTTP Error 429:
# processing Record 1 of Set 650 | tibati
# no data available for city tibati,because of HTTP Error 429:
# processing Record 1 of Set 650 | san pedro de macoris
# no data available for city san pedro de macoris,because of HTTP Error 429:
# processing Record 1 of Set 650 | catalina
# no data available for city catalina,because of HTTP Error 429:
# processing Record 1 of Set 650 | laguna
# no data available for city laguna,because of HTTP Error 429:
# processing Record 1 of Set 650 | revda
# no data available for city revda,because of HTTP Error 429:
# processing Record 1 of Set 650 | anadyr
# no data available for city anadyr,because of HTTP Error 429:
# processing Record 1 of Set 650 | douentza
# no data available for city douentza,because of HTTP Error 429:
# processing Record 1 of Set 650 | srednekolymsk
# no data available for city srednekolymsk,because of HTTP Error 429:
# processing Record 1 of Set 650 | banjar
# no data available for city banjar,because of HTTP Error 429:
# processing Record 1 of Set 650 | tsihombe
# no data available for city tsihombe,because of HTTP Error 429:
# processing Record 1 of Set 650 | enterprise
# no data available for city enterprise,because of HTTP Error 429:
# processing Record 1 of Set 650 | igarka
# no data available for city igarka,because of HTTP Error 429:
# processing Record 1 of Set 650 | urengoy
# no data available for city urengoy,because of HTTP Error 429:
# processing Record 1 of Set 650 | healdsburg
# no data available for city healdsburg,because of HTTP Error 429:
# processing Record 1 of Set 650 | nelson
# no data available for city nelson,because of HTTP Error 429:
# processing Record 1 of Set 650 | dingle
# no data available for city dingle,because of HTTP Error 429:
# processing Record 1 of Set 650 | trelew
# no data available for city trelew,because of HTTP Error 429:
# processing Record 1 of Set 650 | aketi
# no data available for city aketi,because of HTTP Error 429:
# processing Record 1 of Set 650 | te anau
# no data available for city te anau,because of HTTP Error 429:
# processing Record 1 of Set 650 | bolshaya chernigovka
# no data available for city bolshaya chernigovka,because of HTTP Error 429:
# processing Record 1 of Set 650 | tornio
# no data available for city tornio,because of HTTP Error 429:
# processing Record 1 of Set 650 | carman
# no data available for city carman,because of HTTP Error 429:
# processing Record 1 of Set 650 | bilibino
# no data available for city bilibino,because of HTTP Error 429:
# processing Record 1 of Set 650 | mersing
# no data available for city mersing,because of HTTP Error 429:
# processing Record 1 of Set 650 | meulaboh
# no data available for city meulaboh,because of HTTP Error 429:
# processing Record 1 of Set 650 | otradnoye
# no data available for city otradnoye,because of HTTP Error 429:
# processing Record 1 of Set 650 | torbay
# no data available for city torbay,because of HTTP Error 429:
# processing Record 1 of Set 650 | fort nelson
# no data available for city fort nelson,because of HTTP Error 429:
# processing Record 1 of Set 650 | alyangula
# no data available for city alyangula,because of HTTP Error 429:
# processing Record 1 of Set 650 | doha
# no data available for city doha,because of HTTP Error 429:
# processing Record 1 of Set 650 | saldanha
# no data available for city saldanha,because of HTTP Error 429:
# processing Record 1 of Set 650 | kilrush
# no data available for city kilrush,because of HTTP Error 429:
# processing Record 1 of Set 650 | port hedland
# no data available for city port hedland,because of HTTP Error 429:
# processing Record 1 of Set 650 | tianmen
# no data available for city tianmen,because of HTTP Error 429:
# processing Record 1 of Set 650 | bolshaya orlovka
# no data available for city bolshaya orlovka,because of HTTP Error 429:
# processing Record 1 of Set 650 | bien hoa
# no data available for city bien hoa,because of HTTP Error 429:
# processing Record 1 of Set 650 | sur
# no data available for city sur,because of HTTP Error 429:
# processing Record 1 of Set 650 | samusu
# no data available for city samusu,because of HTTP Error 429:
# processing Record 1 of Set 650 | pitimbu
# no data available for city pitimbu,because of HTTP Error 429:
# processing Record 1 of Set 650 | colac
# no data available for city colac,because of HTTP Error 429:
# processing Record 1 of Set 650 | tabiauea
# no data available for city tabiauea,because of HTTP Error 429:
# processing Record 1 of Set 650 | port alfred
# no data available for city port alfred,because of HTTP Error 429:
# processing Record 1 of Set 650 | burica
# no data available for city burica,because of HTTP Error 429:
# processing Record 1 of Set 650 | nipawin
# no data available for city nipawin,because of HTTP Error 429:
# processing Record 1 of Set 650 | bac lieu
# no data available for city bac lieu,because of HTTP Error 429:
# processing Record 1 of Set 650 | moree
# no data available for city moree,because of HTTP Error 429:
# processing Record 1 of Set 650 | castro
# no data available for city castro,because of HTTP Error 429:
# processing Record 1 of Set 650 | souillac
# no data available for city souillac,because of HTTP Error 429:
# processing Record 1 of Set 650 | barranca
# no data available for city barranca,because of HTTP Error 429:
# processing Record 1 of Set 650 | bartica
# no data available for city bartica,because of HTTP Error 429:
# processing Record 1 of Set 650 | skibbereen
# no data available for city skibbereen,because of HTTP Error 429:
# processing Record 1 of Set 650 | umm kaddadah
# no data available for city umm kaddadah,because of HTTP Error 429:
# processing Record 1 of Set 650 | sept-iles
# no data available for city sept-iles,because of HTTP Error 429:
# processing Record 1 of Set 650 | gravdal
# no data available for city gravdal,because of HTTP Error 429:
# processing Record 1 of Set 650 | minas
# no data available for city minas,because of HTTP Error 429:
# processing Record 1 of Set 650 | nanakuli
# no data available for city nanakuli,because of HTTP Error 429:
# processing Record 1 of Set 650 | saint george
# no data available for city saint george,because of HTTP Error 429:
# processing Record 1 of Set 650 | rocha
# no data available for city rocha,because of HTTP Error 429:
# processing Record 1 of Set 650 | kholodnyy
# no data available for city kholodnyy,because of HTTP Error 429:
# processing Record 1 of Set 650 | natal
# no data available for city natal,because of HTTP Error 429:
# processing Record 1 of Set 650 | benguela
# no data available for city benguela,because of HTTP Error 429:
# processing Record 1 of Set 650 | santa rosa
# no data available for city santa rosa,because of HTTP Error 429:
# processing Record 1 of Set 650 | berlevag
# no data available for city berlevag,because of HTTP Error 429:
# processing Record 1 of Set 650 | sinnamary
# no data available for city sinnamary,because of HTTP Error 429:
# processing Record 1 of Set 650 | middelburg
# no data available for city middelburg,because of HTTP Error 429:
# processing Record 1 of Set 650 | muroto
# no data available for city muroto,because of HTTP Error 429:
# processing Record 1 of Set 650 | beringovskiy
# no data available for city beringovskiy,because of HTTP Error 429:
# processing Record 1 of Set 650 | kashi
# no data available for city kashi,because of HTTP Error 429:
# processing Record 1 of Set 650 | ararat
# no data available for city ararat,because of HTTP Error 429:
# processing Record 1 of Set 650 | manyana
# no data available for city manyana,because of HTTP Error 429:
# processing Record 1 of Set 650 | tura
# no data available for city tura,because of HTTP Error 429:
# processing Record 1 of Set 650 | kaitangata
# no data available for city kaitangata,because of HTTP Error 429:
# processing Record 1 of Set 650 | lebu
# no data available for city lebu,because of HTTP Error 429:
# processing Record 1 of Set 650 | palu
# no data available for city palu,because of HTTP Error 429:
# processing Record 1 of Set 650 | nikolskoye
# no data available for city nikolskoye,because of HTTP Error 429:
# processing Record 1 of Set 650 | airai
# no data available for city airai,because of HTTP Error 429:
# processing Record 1 of Set 650 | salisbury
# no data available for city salisbury,because of HTTP Error 429:
# processing Record 1 of Set 650 | visby
# no data available for city visby,because of HTTP Error 429:
# processing Record 1 of Set 650 | petrolandia
# no data available for city petrolandia,because of HTTP Error 429:
# processing Record 1 of Set 650 | cidreira
# no data available for city cidreira,because of HTTP Error 429:
# processing Record 1 of Set 650 | georgiyevka
# no data available for city georgiyevka,because of HTTP Error 429:
# processing Record 1 of Set 650 | coihaique
# no data available for city coihaique,because of HTTP Error 429:
# processing Record 1 of Set 650 | fayaoue
# no data available for city fayaoue,because of HTTP Error 429:
# processing Record 1 of Set 650 | karaul
# no data available for city karaul,because of HTTP Error 429:
# processing Record 1 of Set 650 | san quintin
# no data available for city san quintin,because of HTTP Error 429:
# processing Record 1 of Set 650 | upernavik
# no data available for city upernavik,because of HTTP Error 429:
# processing Record 1 of Set 650 | sindhnur
# no data available for city sindhnur,because of HTTP Error 429:
# processing Record 1 of Set 650 | gamba
# no data available for city gamba,because of HTTP Error 429:
# processing Record 1 of Set 650 | teluk nibung
# no data available for city teluk nibung,because of HTTP Error 429:
# processing Record 1 of Set 650 | fortuna
# no data available for city fortuna,because of HTTP Error 429:
# processing Record 1 of Set 650 | klaksvik
# no data available for city klaksvik,because of HTTP Error 429:
# processing Record 1 of Set 650 | ola
# no data available for city ola,because of HTTP Error 429:
# processing Record 1 of Set 650 | quatre cocos
# no data available for city quatre cocos,because of HTTP Error 429:
# processing Record 1 of Set 650 | meadow lake
# no data available for city meadow lake,because of HTTP Error 429:
# processing Record 1 of Set 650 | porto santo
# no data available for city porto santo,because of HTTP Error 429:
# processing Record 1 of Set 650 | luang prabang
# no data available for city luang prabang,because of HTTP Error 429:
# processing Record 1 of Set 650 | tonstad
# no data available for city tonstad,because of HTTP Error 429:
# processing Record 1 of Set 650 | lidorikion
# no data available for city lidorikion,because of HTTP Error 429:
# processing Record 1 of Set 650 | caraguatatuba
# no data available for city caraguatatuba,because of HTTP Error 429:
# processing Record 1 of Set 650 | takoradi
# no data available for city takoradi,because of HTTP Error 429:
# processing Record 1 of Set 650 | korla
# no data available for city korla,because of HTTP Error 429:
# processing Record 1 of Set 650 | omboue
# no data available for city omboue,because of HTTP Error 429:
# processing Record 1 of Set 650 | shache
# no data available for city shache,because of HTTP Error 429:
# processing Record 1 of Set 650 | aykhal
# no data available for city aykhal,because of HTTP Error 429:
# processing Record 1 of Set 650 | limeira
# no data available for city limeira,because of HTTP Error 429:
# processing Record 1 of Set 650 | otjiwarongo
# no data available for city otjiwarongo,because of HTTP Error 429:
# processing Record 1 of Set 650 | labuhan
# no data available for city labuhan,because of HTTP Error 429:
# processing Record 1 of Set 650 | goderich
# no data available for city goderich,because of HTTP Error 429:
# processing Record 1 of Set 650 | mumbwa
# no data available for city mumbwa,because of HTTP Error 429:
# processing Record 1 of Set 650 | baena
# no data available for city baena,because of HTTP Error 429:
# processing Record 1 of Set 650 | cache creek
# no data available for city cache creek,because of HTTP Error 429:
# processing Record 1 of Set 650 | clarence town
# no data available for city clarence town,because of HTTP Error 429:
# processing Record 1 of Set 650 | angoche
# no data available for city angoche,because of HTTP Error 429:
# processing Record 1 of Set 650 | puerto escondido
# no data available for city puerto escondido,because of HTTP Error 429:
# processing Record 1 of Set 650 | kirensk
# no data available for city kirensk,because of HTTP Error 429:
# processing Record 1 of Set 650 | grandview
# no data available for city grandview,because of HTTP Error 429:
# processing Record 1 of Set 650 | sitka
# no data available for city sitka,because of HTTP Error 429:
# processing Record 1 of Set 650 | north branch
# no data available for city north branch,because of HTTP Error 429:
# processing Record 1 of Set 650 | baykit
# no data available for city baykit,because of HTTP Error 429:
# processing Record 1 of Set 650 | ribeira grande
# no data available for city ribeira grande,because of HTTP Error 429:
# processing Record 1 of Set 650 | coquimbo
# no data available for city coquimbo,because of HTTP Error 429:
# processing Record 1 of Set 650 | santa cruz
# no data available for city santa cruz,because of HTTP Error 429:
# processing Record 1 of Set 650 | iranshahr
# no data available for city iranshahr,because of HTTP Error 429:
# processing Record 1 of Set 650 | sovik
# no data available for city sovik,because of HTTP Error 429:
# processing Record 1 of Set 650 | sirkali
# no data available for city sirkali,because of HTTP Error 429:
# processing Record 1 of Set 650 | auki
# no data available for city auki,because of HTTP Error 429:
# processing Record 1 of Set 650 | gimli
# no data available for city gimli,because of HTTP Error 429:
# processing Record 1 of Set 650 | marcona
# no data available for city marcona,because of HTTP Error 429:
# processing Record 1 of Set 650 | mackay
# no data available for city mackay,because of HTTP Error 429:
# processing Record 1 of Set 650 | salalah
# no data available for city salalah,because of HTTP Error 429:
# processing Record 1 of Set 650 | kudahuvadhoo
# no data available for city kudahuvadhoo,because of HTTP Error 429:
# processing Record 1 of Set 650 | sisimiut
# no data available for city sisimiut,because of HTTP Error 429:
# processing Record 1 of Set 650 | wanning
# no data available for city wanning,because of HTTP Error 429:
# processing Record 1 of Set 650 | gushikawa
# no data available for city gushikawa,because of HTTP Error 429:
# processing Record 1 of Set 650 | namatanai
# no data available for city namatanai,because of HTTP Error 429:
# processing Record 1 of Set 650 | chagda
# no data available for city chagda,because of HTTP Error 429:
# processing Record 1 of Set 650 | barrow
# no data available for city barrow,because of HTTP Error 429:
# processing Record 1 of Set 650 | vestmannaeyjar
# no data available for city vestmannaeyjar,because of HTTP Error 429:
# processing Record 1 of Set 650 | chokurdakh
# no data available for city chokurdakh,because of HTTP Error 429:
# processing Record 1 of Set 650 | kahului
# no data available for city kahului,because of HTTP Error 429:
# processing Record 1 of Set 650 | winnemucca
# no data available for city winnemucca,because of HTTP Error 429:
# processing Record 1 of Set 650 | olafsvik
# no data available for city olafsvik,because of HTTP Error 429:
# processing Record 1 of Set 650 | kismayo
# no data available for city kismayo,because of HTTP Error 429:
# processing Record 1 of Set 650 | bathsheba
# no data available for city bathsheba,because of HTTP Error 429:
# processing Record 1 of Set 650 | miranda
# no data available for city miranda,because of HTTP Error 429:
# processing Record 1 of Set 650 | ariquemes
# no data available for city ariquemes,because of HTTP Error 429:
# processing Record 1 of Set 650 | dien bien
# no data available for city dien bien,because of HTTP Error 429:
# processing Record 1 of Set 650 | bom jesus
# no data available for city bom jesus,because of HTTP Error 429:
# processing Record 1 of Set 650 | rio grande
# no data available for city rio grande,because of HTTP Error 429:
# processing Record 1 of Set 650 | praia
# no data available for city praia,because of HTTP Error 429:
# processing Record 1 of Set 650 | kalmunai
# no data available for city kalmunai,because of HTTP Error 429:
# processing Record 1 of Set 650 | faanui
# no data available for city faanui,because of HTTP Error 429:
# processing Record 1 of Set 650 | ambodifototra
# no data available for city ambodifototra,because of HTTP Error 429:
# processing Record 1 of Set 650 | sumbe
# no data available for city sumbe,because of HTTP Error 429:
# processing Record 1 of Set 650 | ahipara
# no data available for city ahipara,because of HTTP Error 429:
# processing Record 1 of Set 650 | vuktyl
# no data available for city vuktyl,because of HTTP Error 429:
# processing Record 1 of Set 650 | matara
# no data available for city matara,because of HTTP Error 429:
# processing Record 1 of Set 650 | tilichiki
# no data available for city tilichiki,because of HTTP Error 429:
# processing Record 1 of Set 650 | kirakira
# no data available for city kirakira,because of HTTP Error 429:
# processing Record 1 of Set 650 | kilifi
# no data available for city kilifi,because of HTTP Error 429:
# processing Record 1 of Set 650 | codrington
# no data available for city codrington,because of HTTP Error 429:
# processing Record 1 of Set 650 | yar-sale
# no data available for city yar-sale,because of HTTP Error 429:
# processing Record 1 of Set 650 | cayenne
# no data available for city cayenne,because of HTTP Error 429:
# processing Record 1 of Set 650 | barentsburg
# no data available for city barentsburg,because of HTTP Error 429:
# processing Record 1 of Set 650 | asau
# no data available for city asau,because of HTTP Error 429:
# processing Record 1 of Set 650 | mullaitivu
# no data available for city mullaitivu,because of HTTP Error 429:
# processing Record 1 of Set 650 | constantine
# no data available for city constantine,because of HTTP Error 429:
# processing Record 1 of Set 650 | lavrentiya
# no data available for city lavrentiya,because of HTTP Error 429:
# processing Record 1 of Set 650 | deniliquin
# no data available for city deniliquin,because of HTTP Error 429:
# processing Record 1 of Set 650 | mercedes
# no data available for city mercedes,because of HTTP Error 429:
# processing Record 1 of Set 650 | caconda
# no data available for city caconda,because of HTTP Error 429:
# processing Record 1 of Set 650 | sobolevo
# no data available for city sobolevo,because of HTTP Error 429:
# processing Record 1 of Set 650 | zhigansk
# no data available for city zhigansk,because of HTTP Error 429:
# processing Record 1 of Set 650 | buraydah
# no data available for city buraydah,because of HTTP Error 429:
# processing Record 1 of Set 650 | burghausen
# no data available for city burghausen,because of HTTP Error 429:
# processing Record 1 of Set 650 | almaznyy
# no data available for city almaznyy,because of HTTP Error 429:
# processing Record 1 of Set 650 | kavieng
# no data available for city kavieng,because of HTTP Error 429:
# processing Record 1 of Set 650 | dhidhdhoo
# no data available for city dhidhdhoo,because of HTTP Error 429:
# processing Record 1 of Set 650 | kumluca
# no data available for city kumluca,because of HTTP Error 429:
# processing Record 1 of Set 650 | kaiyuan
# no data available for city kaiyuan,because of HTTP Error 429:
# processing Record 1 of Set 650 | vitim
# no data available for city vitim,because of HTTP Error 429:
# processing Record 1 of Set 650 | monte santo
# no data available for city monte santo,because of HTTP Error 429:
# processing Record 1 of Set 650 | zheleznodorozhnyy
# no data available for city zheleznodorozhnyy,because of HTTP Error 429:
# processing Record 1 of Set 650 | san carlos de bariloche
# no data available for city san carlos de bariloche,because of HTTP Error 429:
# processing Record 1 of Set 650 | katsuura
# no data available for city katsuura,because of HTTP Error 429:
# processing Record 1 of Set 650 | termoli
# no data available for city termoli,because of HTTP Error 429:
# processing Record 1 of Set 650 | rio gallegos
# no data available for city rio gallegos,because of HTTP Error 429:
# processing Record 1 of Set 650 | warka
# no data available for city warka,because of HTTP Error 429:
# processing Record 1 of Set 650 | gizo
# no data available for city gizo,because of HTTP Error 429:
# processing Record 1 of Set 650 | baneh
# no data available for city baneh,because of HTTP Error 429:
# processing Record 1 of Set 650 | georgetown
# no data available for city georgetown,because of HTTP Error 429:
# processing Record 1 of Set 650 | dukhovnitskoye
# no data available for city dukhovnitskoye,because of HTTP Error 429:
# processing Record 1 of Set 650 | uwayl
# no data available for city uwayl,because of HTTP Error 429:
# processing Record 1 of Set 650 | marsaxlokk
# no data available for city marsaxlokk,because of HTTP Error 429:
# processing Record 1 of Set 650 | moose factory
# no data available for city moose factory,because of HTTP Error 429:
# processing Record 1 of Set 650 | carnarvon
# no data available for city carnarvon,because of HTTP Error 429:
# processing Record 1 of Set 650 | aleksandrovsk-sakhalinskiy
# no data available for city aleksandrovsk-sakhalinskiy,because of HTTP Error 429:
# processing Record 1 of Set 650 | ust-koksa
# no data available for city ust-koksa,because of HTTP Error 429:
# processing Record 1 of Set 650 | capitao poco
# no data available for city capitao poco,because of HTTP Error 429:
# processing Record 1 of Set 650 | genhe
# no data available for city genhe,because of HTTP Error 429:
# processing Record 1 of Set 650 | high level
# no data available for city high level,because of HTTP Error 429:
# processing Record 1 of Set 650 | mildura
# no data available for city mildura,because of HTTP Error 429:
# processing Record 1 of Set 650 | pangai
# no data available for city pangai,because of HTTP Error 429:
# processing Record 1 of Set 650 | nanding
# no data available for city nanding,because of HTTP Error 429:
# processing Record 1 of Set 650 | behat
# no data available for city behat,because of HTTP Error 429:
# processing Record 1 of Set 650 | pangkalanbuun
# no data available for city pangkalanbuun,because of HTTP Error 429:
# processing Record 1 of Set 650 | icusesti
# no data available for city icusesti,because of HTTP Error 429:
# processing Record 1 of Set 650 | khatanga
# no data available for city khatanga,because of HTTP Error 429:
# processing Record 1 of Set 650 | vanimo
# no data available for city vanimo,because of HTTP Error 429:
# processing Record 1 of Set 650 | boca do acre
# no data available for city boca do acre,because of HTTP Error 429:
# processing Record 1 of Set 650 | waw
# no data available for city waw,because of HTTP Error 429:
# processing Record 1 of Set 650 | los llanos de aridane
# no data available for city los llanos de aridane,because of HTTP Error 429:
# processing Record 1 of Set 650 | khani
# no data available for city khani,because of HTTP Error 429:
# processing Record 1 of Set 650 | trairi
# no data available for city trairi,because of HTTP Error 429:
# processing Record 1 of Set 650 | vostok
# no data available for city vostok,because of HTTP Error 429:
# processing Record 1 of Set 650 | denton
# no data available for city denton,because of HTTP Error 429:
# processing Record 1 of Set 650 | gibsons
# no data available for city gibsons,because of HTTP Error 429:
# processing Record 1 of Set 650 | nantucket
# no data available for city nantucket,because of HTTP Error 429:
# processing Record 1 of Set 650 | namibe
# no data available for city namibe,because of HTTP Error 429:
# processing Record 1 of Set 650 | zaysan
# no data available for city zaysan,because of HTTP Error 429:
# processing Record 1 of Set 650 | husavik
# no data available for city husavik,because of HTTP Error 429:
# processing Record 1 of Set 650 | north bend
# no data available for city north bend,because of HTTP Error 429:
# processing Record 1 of Set 650 | nuevitas
# no data available for city nuevitas,because of HTTP Error 429:
# processing Record 1 of Set 650 | saleaula
# no data available for city saleaula,because of HTTP Error 429:
# processing Record 1 of Set 650 | durant
# no data available for city durant,because of HTTP Error 429:
# processing Record 1 of Set 650 | derzhavinsk
# no data available for city derzhavinsk,because of HTTP Error 429:
# processing Record 1 of Set 650 | svetlaya
# no data available for city svetlaya,because of HTTP Error 429:
# processing Record 1 of Set 650 | torres
# no data available for city torres,because of HTTP Error 429:
# processing Record 1 of Set 650 | naryan-mar
# no data available for city naryan-mar,because of HTTP Error 429:
# processing Record 1 of Set 650 | malaryta
# no data available for city malaryta,because of HTTP Error 429:
# processing Record 1 of Set 650 | grand river south east
# no data available for city grand river south east,because of HTTP Error 429:
# processing Record 1 of Set 650 | saint-leu
# no data available for city saint-leu,because of HTTP Error 429:
# processing Record 1 of Set 650 | joshimath
# no data available for city joshimath,because of HTTP Error 429:
# processing Record 1 of Set 650 | halifax
# no data available for city halifax,because of HTTP Error 429:
# processing Record 1 of Set 650 | quime
# no data available for city quime,because of HTTP Error 429:
# processing Record 1 of Set 650 | miranda do corvo
# no data available for city miranda do corvo,because of HTTP Error 429:
# processing Record 1 of Set 650 | kodiak
# no data available for city kodiak,because of HTTP Error 429:
# processing Record 1 of Set 650 | neryungri
# no data available for city neryungri,because of HTTP Error 429:
# processing Record 1 of Set 650 | riyadh
# no data available for city riyadh,because of HTTP Error 429:
# processing Record 1 of Set 650 | ejura
# no data available for city ejura,because of HTTP Error 429:
# processing Record 1 of Set 650 | college
# no data available for city college,because of HTTP Error 429:
# processing Record 1 of Set 650 | alice springs
# no data available for city alice springs,because of HTTP Error 429:
# processing Record 1 of Set 650 | tezu
# no data available for city tezu,because of HTTP Error 429:
# processing Record 1 of Set 650 | chaykovskiy
# no data available for city chaykovskiy,because of HTTP Error 429:
# processing Record 1 of Set 650 | saint-pierre
# no data available for city saint-pierre,because of HTTP Error 429:
# processing Record 1 of Set 650 | chandler
# no data available for city chandler,because of HTTP Error 429:
# processing Record 1 of Set 650 | paamiut
# no data available for city paamiut,because of HTTP Error 429:
# processing Record 1 of Set 650 | minsk
# no data available for city minsk,because of HTTP Error 429:
# processing Record 1 of Set 650 | antofagasta
# no data available for city antofagasta,because of HTTP Error 429:
# processing Record 1 of Set 650 | ambon
# no data available for city ambon,because of HTTP Error 429:
# processing Record 1 of Set 650 | kamenka
# no data available for city kamenka,because of HTTP Error 429:
# processing Record 1 of Set 650 | longlac
# no data available for city longlac,because of HTTP Error 429:
# processing Record 1 of Set 650 | mrirt
# no data available for city mrirt,because of HTTP Error 429:
# processing Record 1 of Set 650 | marienburg
# no data available for city marienburg,because of HTTP Error 429:
# processing Record 1 of Set 650 | broken hill
# no data available for city broken hill,because of HTTP Error 429:
# processing Record 1 of Set 650 | grao mogol
# no data available for city grao mogol,because of HTTP Error 429:
# processing Record 1 of Set 650 | sattahip
# no data available for city sattahip,because of HTTP Error 429:
# processing Record 1 of Set 650 | kiparissia
# no data available for city kiparissia,because of HTTP Error 429:
# processing Record 1 of Set 650 | kavaratti
# no data available for city kavaratti,because of HTTP Error 429:
# ...
# processing Record 1 of Set 650 | bonnyville
# no data available for city bonnyville,because of HTTP Error 429:
# processing Record 1 of Set 650 | guiuan
# no data available for city guiuan,because of HTTP Error 429:
# processing Record 1 of Set 650 | dukat
# no data available for city dukat,because of HTTP Error 429:
# processing Record 1 of Set 650 | weyburn
# no data available for city weyburn,because of HTTP Error 429:
# processing Record 1 of Set 650 | azimur
# no data available for city azimur,because of HTTP Error 429:
# processing Record 1 of Set 650 | yeppoon
# no data available for city yeppoon,because of HTTP Error 429:
# processing Record 1 of Set 650 | birao
# no data available for city birao,because of HTTP Error 429:
# processing Record 1 of Set 650 | soyo
# no data available for city soyo,because of HTTP Error 429:
# processing Record 1 of Set 650 | zyryanovsk
# no data available for city zyryanovsk,because of HTTP Error 429:
# processing Record 1 of Set 650 | sao joao de pirabas
# no data available for city sao joao de pirabas,because of HTTP Error 429:
# processing Record 1 of Set 650 | msanga
# no data available for city msanga,because of HTTP Error 429:
# processing Record 1 of Set 650 | bindura
# no data available for city bindura,because of HTTP Error 429:
# processing Record 1 of Set 650 | kasempa
# no data available for city kasempa,because of HTTP Error 429:
# processing Record 1 of Set 650 | kalianget
# no data available for city kalianget,because of HTTP Error 429:
# processing Record 1 of Set 650 | vanino
# no data available for city vanino,because of HTTP Error 429:
# processing Record 1 of Set 650 | schwabmunchen
# no data available for city schwabmunchen,because of HTTP Error 429:
# processing Record 1 of Set 650 | almeirim
# no data available for city almeirim,because of HTTP Error 429:
# processing Record 1 of Set 650 | sharkan
# no data available for city sharkan,because of HTTP Error 429:
# processing Record 1 of Set 650 | vilhena
# no data available for city vilhena,because of HTTP Error 429:
# processing Record 1 of Set 650 | picos
# no data available for city picos,because of HTTP Error 429:
# processing Record 1 of Set 650 | huntington
# no data available for city huntington,because of HTTP Error 429:
# processing Record 1 of Set 650 | necochea
# no data available for city necochea,because of HTTP Error 429:
# processing Record 1 of Set 650 | khonuu
# no data available for city khonuu,because of HTTP Error 429:
# processing Record 1 of Set 650 | ouadda
# no data available for city ouadda,because of HTTP Error 429:
# processing Record 1 of Set 650 | sunrise manor
# no data available for city sunrise manor,because of HTTP Error 429:
# processing Record 1 of Set 650 | torit
# no data available for city torit,because of HTTP Error 429:
# processing Record 1 of Set 650 | chisec
# no data available for city chisec,because of HTTP Error 429:
# processing Record 1 of Set 650 | cassilandia
# no data available for city cassilandia,because of HTTP Error 429:
# processing Record 1 of Set 650 | tulsipur
# no data available for city tulsipur,because of HTTP Error 429:
# processing Record 1 of Set 650 | manggar
# no data available for city manggar,because of HTTP Error 429:
# processing Record 1 of Set 650 | manta
# no data available for city manta,because of HTTP Error 429:
# processing Record 1 of Set 650 | karauzyak
# no data available for city karauzyak,because of HTTP Error 429:
# processing Record 1 of Set 650 | chincha alta
# no data available for city chincha alta,because of HTTP Error 429:
# processing Record 1 of Set 650 | acapulco
# no data available for city acapulco,because of HTTP Error 429:
# processing Record 1 of Set 650 | muros
# no data available for city muros,because of HTTP Error 429:
# processing Record 1 of Set 650 | mumford
# no data available for city mumford,because of HTTP Error 429:
# processing Record 1 of Set 650 | wanaka
# no data available for city wanaka,because of HTTP Error 429:
# processing Record 1 of Set 650 | lianyuan
# no data available for city lianyuan,because of HTTP Error 429:
# processing Record 1 of Set 650 | tumannyy
# no data available for city tumannyy,because of HTTP Error 429:
# processing Record 1 of Set 650 | varhaug
# no data available for city varhaug,because of HTTP Error 429:
# processing Record 1 of Set 650 | pisco
# no data available for city pisco,because of HTTP Error 429:
# processing Record 1 of Set 650 | catamarca
# no data available for city catamarca,because of HTTP Error 429:
# processing Record 1 of Set 650 | cururupu
# no data available for city cururupu,because of HTTP Error 429:
# processing Record 1 of Set 650 | massa marittima
# no data available for city massa marittima,because of HTTP Error 429:
# processing Record 1 of Set 650 | rosarito
# no data available for city rosarito,because of HTTP Error 429:
# processing Record 1 of Set 650 | padang
# no data available for city padang,because of HTTP Error 429:
# processing Record 1 of Set 650 | neustrelitz
# no data available for city neustrelitz,because of HTTP Error 429:
# processing Record 1 of Set 650 | fugen
# no data available for city fugen,because of HTTP Error 429:
# processing Record 1 of Set 650 | farafangana
# no data available for city farafangana,because of HTTP Error 429:
# processing Record 1 of Set 650 | barcelos
# no data available for city barcelos,because of HTTP Error 429:
# processing Record 1 of Set 650 | romilly-sur-seine
# no data available for city romilly-sur-seine,because of HTTP Error 429:
# processing Record 1 of Set 650 | viedma
# no data available for city viedma,because of HTTP Error 429:
# processing Record 1 of Set 650 | ponta delgada
# no data available for city ponta delgada,because of HTTP Error 429:
# processing Record 1 of Set 650 | toba
# no data available for city toba,because of HTTP Error 429:
# processing Record 1 of Set 650 | half moon bay
# no data available for city half moon bay,because of HTTP Error 429:
# processing Record 1 of Set 650 | hamilton
# no data available for city hamilton,because of HTTP Error 429:
# processing Record 1 of Set 650 | antalaha
# no data available for city antalaha,because of HTTP Error 429:
# processing Record 1 of Set 650 | price
# no data available for city price,because of HTTP Error 429:
# processing Record 1 of Set 650 | tasbuget
# no data available for city tasbuget,because of HTTP Error 429:
# processing Record 1 of Set 650 | vikersund
# no data available for city vikersund,because of HTTP Error 429:
# processing Record 1 of Set 650 | ewa beach
# no data available for city ewa beach,because of HTTP Error 429:
# processing Record 1 of Set 650 | hambantota
# no data available for city hambantota,because of HTTP Error 429:
# processing Record 1 of Set 650 | thyolo
# no data available for city thyolo,because of HTTP Error 429:
# processing Record 1 of Set 650 | kidal
# no data available for city kidal,because of HTTP Error 429:
# processing Record 1 of Set 650 | cranbrook
# no data available for city cranbrook,because of HTTP Error 429:
# processing Record 1 of Set 650 | verkhnevilyuysk
# no data available for city verkhnevilyuysk,because of HTTP Error 429:
# processing Record 1 of Set 650 | khalkhal
# no data available for city khalkhal,because of HTTP Error 429:
# processing Record 1 of Set 650 | chirilagua
# no data available for city chirilagua,because of HTTP Error 429:
# processing Record 1 of Set 650 | atengo
# no data available for city atengo,because of HTTP Error 429:
# processing Record 1 of Set 650 | lages
# no data available for city lages,because of HTTP Error 429:
# processing Record 1 of Set 650 | bosaso
# no data available for city bosaso,because of HTTP Error 429:
# processing Record 1 of Set 650 | litoral del san juan
# no data available for city litoral del san juan,because of HTTP Error 429:
# processing Record 1 of Set 650 | tabas
# no data available for city tabas,because of HTTP Error 429:
# processing Record 1 of Set 650 | acarau
# no data available for city acarau,because of HTTP Error 429:
# processing Record 1 of Set 650 | mujiayingzi
# no data available for city mujiayingzi,because of HTTP Error 429:
# processing Record 1 of Set 650 | bristol
# no data available for city bristol,because of HTTP Error 429:
# processing Record 1 of Set 650 | pandan
# no data available for city pandan,because of HTTP Error 429:
# processing Record 1 of Set 650 | aquiraz
# no data available for city aquiraz,because of HTTP Error 429:
# processing Record 1 of Set 650 | urumqi
# no data available for city urumqi,because of HTTP Error 429:
# processing Record 1 of Set 650 | mogadishu
# no data available for city mogadishu,because of HTTP Error 429:
# processing Record 1 of Set 650 | kamenskoye
# no data available for city kamenskoye,because of HTTP Error 429:
# processing Record 1 of Set 650 | hofn
# no data available for city hofn,because of HTTP Error 429:
# processing Record 1 of Set 650 | oranjestad
# no data available for city oranjestad,because of HTTP Error 429:
# processing Record 1 of Set 650 | ornskoldsvik
# no data available for city ornskoldsvik,because of HTTP Error 429:
# processing Record 1 of Set 650 | neulengbach
# no data available for city neulengbach,because of HTTP Error 429:
# processing Record 1 of Set 650 | moerai
# no data available for city moerai,because of HTTP Error 429:
# processing Record 1 of Set 650 | maceio
# no data available for city maceio,because of HTTP Error 429:
# processing Record 1 of Set 650 | dunmore town
# no data available for city dunmore town,because of HTTP Error 429:
# processing Record 1 of Set 650 | don sak
# no data available for city don sak,because of HTTP Error 429:
# processing Record 1 of Set 650 | atima
# no data available for city atima,because of HTTP Error 429:
# processing Record 1 of Set 650 | chippewa falls
# no data available for city chippewa falls,because of HTTP Error 429:
# processing Record 1 of Set 650 | mendahara
# no data available for city mendahara,because of HTTP Error 429:
# processing Record 1 of Set 650 | zhovkva
# no data available for city zhovkva,because of HTTP Error 429:
# processing Record 1 of Set 650 | terney
# no data available for city terney,because of HTTP Error 429:
# processing Record 1 of Set 650 | rottingdean
# no data available for city rottingdean,because of HTTP Error 429:
# processing Record 1 of Set 650 | wuwei
# no data available for city wuwei,because of HTTP Error 429:
# processing Record 1 of Set 650 | longhua
# no data available for city longhua,because of HTTP Error 429:
# processing Record 1 of Set 650 | jining
# no data available for city jining,because of HTTP Error 429:
# processing Record 1 of Set 650 | palabuhanratu
# no data available for city palabuhanratu,because of HTTP Error 429:
# processing Record 1 of Set 650 | russell
# no data available for city russell,because of HTTP Error 429:
# processing Record 1 of Set 650 | kasongo-lunda
# no data available for city kasongo-lunda,because of HTTP Error 429:
# processing Record 1 of Set 650 | omsukchan
# no data available for city omsukchan,because of HTTP Error 429:
# processing Record 1 of Set 650 | horsham
# no data available for city horsham,because of HTTP Error 429:
# processing Record 1 of Set 650 | manokwari
# no data available for city manokwari,because of HTTP Error 429:
# processing Record 1 of Set 650 | interlaken
# no data available for city interlaken,because of HTTP Error 429:
# processing Record 1 of Set 650 | pozo colorado
# no data available for city pozo colorado,because of HTTP Error 429:
# processing Record 1 of Set 650 | bandundu
# no data available for city bandundu,because of HTTP Error 429:
# processing Record 1 of Set 650 | tautira
# no data available for city tautira,because of HTTP Error 429:
# processing Record 1 of Set 650 | mwinilunga
# no data available for city mwinilunga,because of HTTP Error 429:
# processing Record 1 of Set 650 | hohhot
# no data available for city hohhot,because of HTTP Error 429:
# processing Record 1 of Set 650 | warrington
# no data available for city warrington,because of HTTP Error 429:
# processing Record 1 of Set 650 | klishkivtsi
# no data available for city klishkivtsi,because of HTTP Error 429:
# processing Record 1 of Set 650 | mugumu
# no data available for city mugumu,because of HTTP Error 429:
# processing Record 1 of Set 650 | mokokchung
# no data available for city mokokchung,because of HTTP Error 429:
# processing Record 1 of Set 650 | mahajanga
# no data available for city mahajanga,because of HTTP Error 429:
# processing Record 1 of Set 650 | pochutla
# no data available for city pochutla,because of HTTP Error 429:
# processing Record 1 of Set 650 | nowogard
# no data available for city nowogard,because of HTTP Error 429:
# processing Record 1 of Set 650 | show low
# no data available for city show low,because of HTTP Error 429:
# processing Record 1 of Set 650 | posse
# no data available for city posse,because of HTTP Error 429:
# processing Record 1 of Set 650 | goryachegorsk
# no data available for city goryachegorsk,because of HTTP Error 429:
# processing Record 1 of Set 650 | puerto padre
# no data available for city puerto padre,because of HTTP Error 429:
# processing Record 1 of Set 650 | yarmouth
# no data available for city yarmouth,because of HTTP Error 429:
# processing Record 1 of Set 650 | dongsheng
# no data available for city dongsheng,because of HTTP Error 429:
# processing Record 1 of Set 650 | moron
# no data available for city moron,because of HTTP Error 429:
# processing Record 1 of Set 650 | jacareacanga
# no data available for city jacareacanga,because of HTTP Error 429:
# processing Record 1 of Set 650 | camacha
# no data available for city camacha,because of HTTP Error 429:
# processing Record 1 of Set 650 | daru
# no data available for city daru,because of HTTP Error 429:
# processing Record 1 of Set 650 | tamandare
# no data available for city tamandare,because of HTTP Error 429:
# processing Record 1 of Set 650 | dwarka
# no data available for city dwarka,because of HTTP Error 429:
# processing Record 1 of Set 650 | amasya
# no data available for city amasya,because of HTTP Error 429:
# processing Record 1 of Set 650 | yinchuan
# no data available for city yinchuan,because of HTTP Error 429:
# processing Record 1 of Set 650 | belgrade
# no data available for city belgrade,because of HTTP Error 429:
# processing Record 1 of Set 650 | jiaocheng
# no data available for city jiaocheng,because of HTTP Error 429:
# processing Record 1 of Set 650 | teya
# no data available for city teya,because of HTTP Error 429:
# processing Record 1 of Set 650 | sao miguel do araguaia
# no data available for city sao miguel do araguaia,because of HTTP Error 429:
# processing Record 1 of Set 650 | druzhnaya gorka
# no data available for city druzhnaya gorka,because of HTTP Error 429:
# processing Record 1 of Set 650 | obihiro
# no data available for city obihiro,because of HTTP Error 429:
# processing Record 1 of Set 650 | skjervoy
# no data available for city skjervoy,because of HTTP Error 429:
# processing Record 1 of Set 650 | saint anthony
# no data available for city saint anthony,because of HTTP Error 429:
# processing Record 1 of Set 650 | ambulu
# no data available for city ambulu,because of HTTP Error 429:
# processing Record 1 of Set 650 | kazachinskoye
# no data available for city kazachinskoye,because of HTTP Error 429:
# processing Record 1 of Set 650 | riaba
# no data available for city riaba,because of HTTP Error 429:
# processing Record 1 of Set 650 | papetoai
# no data available for city papetoai,because of HTTP Error 429:
# processing Record 1 of Set 650 | presidencia roque saenz pena
# no data available for city presidencia roque saenz pena,because of HTTP Error 429:
# processing Record 1 of Set 650 | odweyne
# no data available for city odweyne,because of HTTP Error 429:
# processing Record 1 of Set 650 | chumikan
# no data available for city chumikan,because of HTTP Error 429:
# processing Record 1 of Set 650 | boa vista
# no data available for city boa vista,because of HTTP Error 429:
# processing Record 1 of Set 650 | arlit
# no data available for city arlit,because of HTTP Error 429:
# processing Record 1 of Set 650 | artyk
# no data available for city artyk,because of HTTP Error 429:

# %%
weather_data
# Out:
# Empty DataFrame
# Columns: [city, Cloudiness, Country, Date, Humidity, Latitude, Lng, Max Temp, Wind Speed, Temperature]
# Index: []

# %%
weather_data.Timestamp('1562119588')
Timestamp
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-68-5891cdc661a3> in <module>
# ----> 1 weather_data.Timestamp('1562119588')
#       2 Timestamp
#
# ~\anaconda\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Timestamp'

# %%
# build a dataframe from the cities, lon,and pressure lists

weather_data = {"city": cit, 
                "Cloudiness": cloudiness, 
                "Country": country, 
                "Date": date, 
                "Humidity": humidity, 
                "Latitude": lat, 
                "Lng": lon, 
                "Max Temp": temp_max,  
                "Wind Speed": wind, 
                "Temperature": temp}
weather_data = pd.DataFrame(weather_data)
weather_data.head()
# Out:
# Empty DataFrame
# Columns: [city, Cloudiness, Country, Date, Humidity, Latitude, Lng, Max Temp, Wind Speed, Temperature]
# Index: []

# %%
 # Build a scatter plot for each data type
plt.scatter(weather_data["Temperature"], weather_data["Latitude"], marker="o")

# Incorporate the other graph properties
plt.title("Temperature (F) vs. Latitude")
plt.ylabel("Latitude")
plt.xlabel("Temperature")
plt.grid(True)

# Save the figure
plt.savefig("Temperature vrs Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Save as a csv  OK
# Note to avoid any issues later, use encoding="utf-8"
weather_data.to_csv("weatherpy.csv", encoding="utf-8", index=False)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
 # Build a scatter plot for each data type
plt.scatter(weather_data["Max Temp"], weather_data["Latitude"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature", )
plt.ylabel("Max Temp"+"(F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Max Temperature vrs Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data["Humidity"], weather_data["Latitude"], marker="o")

# Incorporate the other graph properties
plt.title("Humidity (%) vs. Latitude")
plt.ylabel("Humidity" +"(%)")
plt.xlabel("Latitude")
plt.grid(True)

# Set the y-limits of the current axes to 100 Fahrenheit

ylim=(0, 100)

# Save the figure
plt.savefig("Humidity vs Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data["Cloudiness"], weather_data["Latitude"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness ")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

# Set the y-limits of the current axes to 100 Fahrenheit

xlim=(-80,100)
ylim=(0, 100)


# Save the figure
plt.savefig("Cloudiness vs Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data["Wind Speed"], weather_data["Latitude"], marker="o")

# Incorporate the other graph properties
plt.title("Wind Speed (mph) vs. Latitude")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Wind Speed vs Latitude.png")

# Show plot
plt.show()
